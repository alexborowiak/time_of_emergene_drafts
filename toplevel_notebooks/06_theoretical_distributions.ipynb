# %%
import pandas as pd
import xarray as xr
import matplotlib.gridspec as gridspec
import dask
from dask import delayed, compute
from itertools import product
from importlib import reload
from functools import partial
# Out:
# Matplotlib created a temporary cache directory at /jobfs/140306106.gadi-pbs/matplotlib-ue6zeumz because the default path (/home/563/ab2313/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import lfilter

# My imports
import os, sys
sys.path.append(os.path.join(os.getcwd(), 'Documents', 'time_of_emergene_drafts'))
sys.path.append(os.path.join(os.getcwd(), 'Documents', 'time_of_emergene_drafts', 'src'))
import my_stats
import toe_calc
import toe_calc_variations
import toe_constants as toe_const

# %%
import toe_plots

# %%
xr.set_options(display_expand_data=False)

# %%
from dask.distributed import wait

# %%
from dask.distributed import Client
# client.close()  # Close existing client
client = Client(n_workers=100, threads_per_worker=1, memory_limit=None)
client
# Out:
#  - State start
#  -   Scheduler at:     tcp://127.0.0.1:38683
#  -   dashboard at:         /proxy/8787/status
#  - Registering Worker plugin shuffle
#  -         Start Nanny at: 'tcp://127.0.0.1:43511'
#  -         Start Nanny at: 'tcp://127.0.0.1:33755'
#  -         Start Nanny at: 'tcp://127.0.0.1:42261'
#  -         Start Nanny at: 'tcp://127.0.0.1:37015'
#  -         Start Nanny at: 'tcp://127.0.0.1:41809'
#  -         Start Nanny at: 'tcp://127.0.0.1:40831'
#  -         Start Nanny at: 'tcp://127.0.0.1:35719'
#  -         Start Nanny at: 'tcp://127.0.0.1:34185'
#  -         Start Nanny at: 'tcp://127.0.0.1:36317'
#  -         Start Nanny at: 'tcp://127.0.0.1:42979'
#  -         Start Nanny at: 'tcp://127.0.0.1:42769'
#  -         Start Nanny at: 'tcp://127.0.0.1:37001'
#  -         Start Nanny at: 'tcp://127.0.0.1:39911'
#  -         Start Nanny at: 'tcp://127.0.0.1:41459'
#  -         Start Nanny at: 'tcp://127.0.0.1:36447'
#  -         Start Nanny at: 'tcp://127.0.0.1:34237'
#  -         Start Nanny at: 'tcp://127.0.0.1:43705'
#  -         Start Nanny at: 'tcp://127.0.0.1:44965'
#  -         Start Nanny at: 'tcp://127.0.0.1:32871'
#  -         Start Nanny at: 'tcp://127.0.0.1:39905'
#  -         Start Nanny at: 'tcp://127.0.0.1:41945'
#  -         Start Nanny at: 'tcp://127.0.0.1:37729'
#  -         Start Nanny at: 'tcp://127.0.0.1:40449'
#  -         Start Nanny at: 'tcp://127.0.0.1:35747'
#  -         Start Nanny at: 'tcp://127.0.0.1:46353'
#  -         Start Nanny at: 'tcp://127.0.0.1:42787'
#  -         Start Nanny at: 'tcp://127.0.0.1:43405'
#  -         Start Nanny at: 'tcp://127.0.0.1:45287'
#  -         Start Nanny at: 'tcp://127.0.0.1:36841'
#  -         Start Nanny at: 'tcp://127.0.0.1:39187'
#  -         Start Nanny at: 'tcp://127.0.0.1:32801'
#  -         Start Nanny at: 'tcp://127.0.0.1:46847'
#  -         Start Nanny at: 'tcp://127.0.0.1:46813'
#  -         Start Nanny at: 'tcp://127.0.0.1:46573'
#  -         Start Nanny at: 'tcp://127.0.0.1:36941'
#  -         Start Nanny at: 'tcp://127.0.0.1:38667'
#  -         Start Nanny at: 'tcp://127.0.0.1:33503'
#  -         Start Nanny at: 'tcp://127.0.0.1:34997'
#  -         Start Nanny at: 'tcp://127.0.0.1:37057'
#  -         Start Nanny at: 'tcp://127.0.0.1:42077'
#  -         Start Nanny at: 'tcp://127.0.0.1:36999'
#  -         Start Nanny at: 'tcp://127.0.0.1:45687'
#  -         Start Nanny at: 'tcp://127.0.0.1:43487'
#  -         Start Nanny at: 'tcp://127.0.0.1:45039'
#  -         Start Nanny at: 'tcp://127.0.0.1:36017'
#  -         Start Nanny at: 'tcp://127.0.0.1:41121'
#  -         Start Nanny at: 'tcp://127.0.0.1:36665'
#  -         Start Nanny at: 'tcp://127.0.0.1:43557'
#  -         Start Nanny at: 'tcp://127.0.0.1:45753'
#  -         Start Nanny at: 'tcp://127.0.0.1:37939'
#  -         Start Nanny at: 'tcp://127.0.0.1:36709'
#  -         Start Nanny at: 'tcp://127.0.0.1:35937'
#  -         Start Nanny at: 'tcp://127.0.0.1:39043'
#  -         Start Nanny at: 'tcp://127.0.0.1:35133'
#  -         Start Nanny at: 'tcp://127.0.0.1:43815'
#  -         Start Nanny at: 'tcp://127.0.0.1:36967'
#  -         Start Nanny at: 'tcp://127.0.0.1:34843'
#  -         Start Nanny at: 'tcp://127.0.0.1:37075'
#  -         Start Nanny at: 'tcp://127.0.0.1:43407'
#  -         Start Nanny at: 'tcp://127.0.0.1:45805'
#  -         Start Nanny at: 'tcp://127.0.0.1:35339'
#  -         Start Nanny at: 'tcp://127.0.0.1:45985'
#  -         Start Nanny at: 'tcp://127.0.0.1:43443'
#  -         Start Nanny at: 'tcp://127.0.0.1:42435'
#  -         Start Nanny at: 'tcp://127.0.0.1:42105'
#  -         Start Nanny at: 'tcp://127.0.0.1:32823'
#  -         Start Nanny at: 'tcp://127.0.0.1:34699'
#  -         Start Nanny at: 'tcp://127.0.0.1:41585'
#  -         Start Nanny at: 'tcp://127.0.0.1:35289'
#  -         Start Nanny at: 'tcp://127.0.0.1:43411'
#  -         Start Nanny at: 'tcp://127.0.0.1:35893'
#  -         Start Nanny at: 'tcp://127.0.0.1:42491'
#  -         Start Nanny at: 'tcp://127.0.0.1:37171'
#  -         Start Nanny at: 'tcp://127.0.0.1:45111'
#  -         Start Nanny at: 'tcp://127.0.0.1:34031'
#  -         Start Nanny at: 'tcp://127.0.0.1:42263'
#  -         Start Nanny at: 'tcp://127.0.0.1:40385'
#  -         Start Nanny at: 'tcp://127.0.0.1:40497'
#  -         Start Nanny at: 'tcp://127.0.0.1:36401'
#  -         Start Nanny at: 'tcp://127.0.0.1:40957'
#  -         Start Nanny at: 'tcp://127.0.0.1:34541'
#  -         Start Nanny at: 'tcp://127.0.0.1:46807'
#  -         Start Nanny at: 'tcp://127.0.0.1:33329'
#  -         Start Nanny at: 'tcp://127.0.0.1:41433'
#  -         Start Nanny at: 'tcp://127.0.0.1:34167'
#  -         Start Nanny at: 'tcp://127.0.0.1:35081'
#  -         Start Nanny at: 'tcp://127.0.0.1:44889'
#  -         Start Nanny at: 'tcp://127.0.0.1:37077'
#  -         Start Nanny at: 'tcp://127.0.0.1:38711'
#  -         Start Nanny at: 'tcp://127.0.0.1:36357'
#  -         Start Nanny at: 'tcp://127.0.0.1:37019'
#  -         Start Nanny at: 'tcp://127.0.0.1:45373'
#  -         Start Nanny at: 'tcp://127.0.0.1:36441'
#  -         Start Nanny at: 'tcp://127.0.0.1:46061'
#  -         Start Nanny at: 'tcp://127.0.0.1:44093'
#  -         Start Nanny at: 'tcp://127.0.0.1:36287'
#  -         Start Nanny at: 'tcp://127.0.0.1:38549'
#  -         Start Nanny at: 'tcp://127.0.0.1:35257'
#  -         Start Nanny at: 'tcp://127.0.0.1:45317'
#  -         Start Nanny at: 'tcp://127.0.0.1:42825'
#  - Register worker <WorkerState 'tcp://127.0.0.1:40305', name: 2, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40305
#  - Starting established connection to tcp://127.0.0.1:56634
#  - Register worker <WorkerState 'tcp://127.0.0.1:45353', name: 0, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45353
#  - Starting established connection to tcp://127.0.0.1:56646
#  - Register worker <WorkerState 'tcp://127.0.0.1:33749', name: 6, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33749
#  - Starting established connection to tcp://127.0.0.1:56650
#  - Register worker <WorkerState 'tcp://127.0.0.1:46013', name: 1, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46013
#  - Starting established connection to tcp://127.0.0.1:56676
#  - Register worker <WorkerState 'tcp://127.0.0.1:40039', name: 3, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40039
#  - Starting established connection to tcp://127.0.0.1:56664
#  - Register worker <WorkerState 'tcp://127.0.0.1:37409', name: 9, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37409
#  - Starting established connection to tcp://127.0.0.1:56690
#  - Register worker <WorkerState 'tcp://127.0.0.1:36521', name: 10, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36521
#  - Starting established connection to tcp://127.0.0.1:56706
#  - Register worker <WorkerState 'tcp://127.0.0.1:38491', name: 4, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38491
#  - Starting established connection to tcp://127.0.0.1:56720
#  - Register worker <WorkerState 'tcp://127.0.0.1:36711', name: 8, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36711
#  - Starting established connection to tcp://127.0.0.1:56712
#  - Register worker <WorkerState 'tcp://127.0.0.1:33283', name: 13, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33283
#  - Starting established connection to tcp://127.0.0.1:56736
#  - Register worker <WorkerState 'tcp://127.0.0.1:40303', name: 5, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40303
#  - Starting established connection to tcp://127.0.0.1:56748
#  - Register worker <WorkerState 'tcp://127.0.0.1:45769', name: 7, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45769
#  - Starting established connection to tcp://127.0.0.1:56752
#  - Register worker <WorkerState 'tcp://127.0.0.1:43183', name: 11, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43183
#  - Starting established connection to tcp://127.0.0.1:56774
#  - Register worker <WorkerState 'tcp://127.0.0.1:46703', name: 12, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46703
#  - Starting established connection to tcp://127.0.0.1:56764
#  - Register worker <WorkerState 'tcp://127.0.0.1:35465', name: 14, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35465
#  - Starting established connection to tcp://127.0.0.1:56782
#  - Register worker <WorkerState 'tcp://127.0.0.1:46761', name: 15, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46761
#  - Starting established connection to tcp://127.0.0.1:56788
#  - Register worker <WorkerState 'tcp://127.0.0.1:43107', name: 16, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43107
#  - Starting established connection to tcp://127.0.0.1:56800
#  - Register worker <WorkerState 'tcp://127.0.0.1:33091', name: 18, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33091
#  - Starting established connection to tcp://127.0.0.1:56814
#  - Register worker <WorkerState 'tcp://127.0.0.1:36963', name: 23, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36963
#  - Starting established connection to tcp://127.0.0.1:56832
#  - Register worker <WorkerState 'tcp://127.0.0.1:42945', name: 22, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42945
#  - Starting established connection to tcp://127.0.0.1:56878
#  - Register worker <WorkerState 'tcp://127.0.0.1:35309', name: 24, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35309
#  - Starting established connection to tcp://127.0.0.1:56828
#  - Register worker <WorkerState 'tcp://127.0.0.1:33243', name: 19, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33243
#  - Starting established connection to tcp://127.0.0.1:56822
#  - Register worker <WorkerState 'tcp://127.0.0.1:40531', name: 20, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40531
#  - Starting established connection to tcp://127.0.0.1:56856
#  - Register worker <WorkerState 'tcp://127.0.0.1:41039', name: 21, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41039
#  - Starting established connection to tcp://127.0.0.1:56842
#  - Register worker <WorkerState 'tcp://127.0.0.1:46355', name: 17, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46355
#  - Starting established connection to tcp://127.0.0.1:56872
#  - Register worker <WorkerState 'tcp://127.0.0.1:44225', name: 27, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44225
#  - Starting established connection to tcp://127.0.0.1:56914
#  - Register worker <WorkerState 'tcp://127.0.0.1:36459', name: 25, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36459
#  - Starting established connection to tcp://127.0.0.1:56916
#  - Register worker <WorkerState 'tcp://127.0.0.1:35671', name: 28, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35671
#  - Starting established connection to tcp://127.0.0.1:56894
#  - Register worker <WorkerState 'tcp://127.0.0.1:33395', name: 29, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33395
#  - Starting established connection to tcp://127.0.0.1:56904
#  - Register worker <WorkerState 'tcp://127.0.0.1:37569', name: 26, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37569
#  - Starting established connection to tcp://127.0.0.1:56888
#  - Register worker <WorkerState 'tcp://127.0.0.1:36661', name: 31, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36661
#  - Starting established connection to tcp://127.0.0.1:56920
#  - Register worker <WorkerState 'tcp://127.0.0.1:37263', name: 33, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37263
#  - Starting established connection to tcp://127.0.0.1:56934
#  - Register worker <WorkerState 'tcp://127.0.0.1:38079', name: 40, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38079
#  - Starting established connection to tcp://127.0.0.1:56948
#  - Register worker <WorkerState 'tcp://127.0.0.1:43775', name: 30, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43775
#  - Starting established connection to tcp://127.0.0.1:56954
#  - Register worker <WorkerState 'tcp://127.0.0.1:43437', name: 37, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43437
#  - Starting established connection to tcp://127.0.0.1:56956
#  - Register worker <WorkerState 'tcp://127.0.0.1:37807', name: 32, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37807
#  - Starting established connection to tcp://127.0.0.1:56966
#  - Register worker <WorkerState 'tcp://127.0.0.1:35887', name: 41, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35887
#  - Starting established connection to tcp://127.0.0.1:56976
#  - Register worker <WorkerState 'tcp://127.0.0.1:44319', name: 38, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44319
#  - Starting established connection to tcp://127.0.0.1:56980
#  - Register worker <WorkerState 'tcp://127.0.0.1:39277', name: 35, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39277
#  - Starting established connection to tcp://127.0.0.1:57052
#  - Register worker <WorkerState 'tcp://127.0.0.1:45987', name: 34, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45987
#  - Starting established connection to tcp://127.0.0.1:57100
#  - Register worker <WorkerState 'tcp://127.0.0.1:33499', name: 39, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33499
#  - Starting established connection to tcp://127.0.0.1:57076
#  - Register worker <WorkerState 'tcp://127.0.0.1:43581', name: 36, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43581
#  - Starting established connection to tcp://127.0.0.1:57142
#  - Register worker <WorkerState 'tcp://127.0.0.1:38937', name: 43, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38937
#  - Starting established connection to tcp://127.0.0.1:57146
#  - Register worker <WorkerState 'tcp://127.0.0.1:43085', name: 46, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43085
#  - Starting established connection to tcp://127.0.0.1:57172
#  - Register worker <WorkerState 'tcp://127.0.0.1:40065', name: 45, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40065
#  - Starting established connection to tcp://127.0.0.1:57150
#  - Register worker <WorkerState 'tcp://127.0.0.1:37919', name: 42, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37919
#  - Starting established connection to tcp://127.0.0.1:57196
#  - Register worker <WorkerState 'tcp://127.0.0.1:33513', name: 44, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33513
#  - Starting established connection to tcp://127.0.0.1:57182
#  - Register worker <WorkerState 'tcp://127.0.0.1:41435', name: 47, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41435
#  - Starting established connection to tcp://127.0.0.1:57304
#  - Register worker <WorkerState 'tcp://127.0.0.1:34793', name: 52, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34793
#  - Starting established connection to tcp://127.0.0.1:57198
#  - Register worker <WorkerState 'tcp://127.0.0.1:36713', name: 48, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36713
#  - Starting established connection to tcp://127.0.0.1:57280
#  - Register worker <WorkerState 'tcp://127.0.0.1:39647', name: 49, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39647
#  - Starting established connection to tcp://127.0.0.1:57264
#  - Register worker <WorkerState 'tcp://127.0.0.1:39437', name: 53, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39437
#  - Starting established connection to tcp://127.0.0.1:57330
#  - Register worker <WorkerState 'tcp://127.0.0.1:36687', name: 51, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36687
#  - Starting established connection to tcp://127.0.0.1:57342
#  - Register worker <WorkerState 'tcp://127.0.0.1:41003', name: 60, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41003
#  - Starting established connection to tcp://127.0.0.1:57404
#  - Register worker <WorkerState 'tcp://127.0.0.1:41331', name: 54, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41331
#  - Starting established connection to tcp://127.0.0.1:57368
#  - Register worker <WorkerState 'tcp://127.0.0.1:34927', name: 58, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34927
#  - Starting established connection to tcp://127.0.0.1:57376
#  - Register worker <WorkerState 'tcp://127.0.0.1:32925', name: 50, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:32925
#  - Starting established connection to tcp://127.0.0.1:57350
#  - Register worker <WorkerState 'tcp://127.0.0.1:42191', name: 59, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42191
#  - Starting established connection to tcp://127.0.0.1:57432
#  - Register worker <WorkerState 'tcp://127.0.0.1:39821', name: 55, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39821
#  - Starting established connection to tcp://127.0.0.1:57416
#  - Register worker <WorkerState 'tcp://127.0.0.1:33097', name: 56, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33097
#  - Starting established connection to tcp://127.0.0.1:57444
#  - Register worker <WorkerState 'tcp://127.0.0.1:45777', name: 61, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45777
#  - Starting established connection to tcp://127.0.0.1:57454
#  - Register worker <WorkerState 'tcp://127.0.0.1:41751', name: 63, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41751
#  - Starting established connection to tcp://127.0.0.1:57516
#  - Register worker <WorkerState 'tcp://127.0.0.1:42159', name: 66, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42159
#  - Starting established connection to tcp://127.0.0.1:57456
#  - Register worker <WorkerState 'tcp://127.0.0.1:32957', name: 65, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:32957
#  - Starting established connection to tcp://127.0.0.1:57512
#  - Register worker <WorkerState 'tcp://127.0.0.1:39765', name: 77, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39765
#  - Starting established connection to tcp://127.0.0.1:57538
#  - Register worker <WorkerState 'tcp://127.0.0.1:44573', name: 73, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44573
#  - Starting established connection to tcp://127.0.0.1:57494
#  - Register worker <WorkerState 'tcp://127.0.0.1:39661', name: 64, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39661
#  - Starting established connection to tcp://127.0.0.1:57466
#  - Register worker <WorkerState 'tcp://127.0.0.1:45927', name: 67, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45927
#  - Starting established connection to tcp://127.0.0.1:57558
#  - Register worker <WorkerState 'tcp://127.0.0.1:33165', name: 57, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33165
#  - Starting established connection to tcp://127.0.0.1:57480
#  - Register worker <WorkerState 'tcp://127.0.0.1:44677', name: 76, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44677
#  - Starting established connection to tcp://127.0.0.1:57596
#  - Register worker <WorkerState 'tcp://127.0.0.1:37345', name: 71, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37345
#  - Starting established connection to tcp://127.0.0.1:57540
#  - Register worker <WorkerState 'tcp://127.0.0.1:43101', name: 70, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43101
#  - Starting established connection to tcp://127.0.0.1:57578
#  - Register worker <WorkerState 'tcp://127.0.0.1:45615', name: 69, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45615
#  - Starting established connection to tcp://127.0.0.1:57556
#  - Register worker <WorkerState 'tcp://127.0.0.1:39097', name: 72, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39097
#  - Starting established connection to tcp://127.0.0.1:57564
#  - Register worker <WorkerState 'tcp://127.0.0.1:36715', name: 74, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36715
#  - Starting established connection to tcp://127.0.0.1:57584
#  - Register worker <WorkerState 'tcp://127.0.0.1:34795', name: 68, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34795
#  - Starting established connection to tcp://127.0.0.1:57524
#  - Register worker <WorkerState 'tcp://127.0.0.1:46427', name: 75, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46427
#  - Starting established connection to tcp://127.0.0.1:57586
#  - Register worker <WorkerState 'tcp://127.0.0.1:41113', name: 62, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41113
#  - Starting established connection to tcp://127.0.0.1:57498
#  - Register worker <WorkerState 'tcp://127.0.0.1:35973', name: 94, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35973
#  - Starting established connection to tcp://127.0.0.1:57652
#  - Register worker <WorkerState 'tcp://127.0.0.1:46451', name: 96, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46451
#  - Starting established connection to tcp://127.0.0.1:57690
#  - Register worker <WorkerState 'tcp://127.0.0.1:45825', name: 79, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45825
#  - Starting established connection to tcp://127.0.0.1:57604
#  - Register worker <WorkerState 'tcp://127.0.0.1:34097', name: 87, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34097
#  - Starting established connection to tcp://127.0.0.1:57722
#  - Register worker <WorkerState 'tcp://127.0.0.1:46815', name: 78, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46815
#  - Starting established connection to tcp://127.0.0.1:57590
#  - Register worker <WorkerState 'tcp://127.0.0.1:46493', name: 83, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46493
#  - Starting established connection to tcp://127.0.0.1:57642
#  - Register worker <WorkerState 'tcp://127.0.0.1:37193', name: 82, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37193
#  - Starting established connection to tcp://127.0.0.1:57706
#  - Register worker <WorkerState 'tcp://127.0.0.1:35957', name: 92, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35957
#  - Starting established connection to tcp://127.0.0.1:57750
#  - Register worker <WorkerState 'tcp://127.0.0.1:44633', name: 81, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44633
#  - Starting established connection to tcp://127.0.0.1:57626
#  - Register worker <WorkerState 'tcp://127.0.0.1:41453', name: 98, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41453
#  - Starting established connection to tcp://127.0.0.1:57666
#  - Register worker <WorkerState 'tcp://127.0.0.1:37695', name: 80, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37695
#  - Starting established connection to tcp://127.0.0.1:57612
#  - Register worker <WorkerState 'tcp://127.0.0.1:37167', name: 84, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37167
#  - Starting established connection to tcp://127.0.0.1:57766
#  - Register worker <WorkerState 'tcp://127.0.0.1:39215', name: 93, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39215
#  - Starting established connection to tcp://127.0.0.1:57800
#  - Register worker <WorkerState 'tcp://127.0.0.1:39737', name: 89, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39737
#  - Starting established connection to tcp://127.0.0.1:57786
#  - Register worker <WorkerState 'tcp://127.0.0.1:36439', name: 97, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36439
#  - Starting established connection to tcp://127.0.0.1:57816
#  - Register worker <WorkerState 'tcp://127.0.0.1:40255', name: 95, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40255
#  - Starting established connection to tcp://127.0.0.1:57808
#  - Register worker <WorkerState 'tcp://127.0.0.1:38595', name: 99, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38595
#  - Starting established connection to tcp://127.0.0.1:57740
#  - Register worker <WorkerState 'tcp://127.0.0.1:43703', name: 90, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43703
#  - Starting established connection to tcp://127.0.0.1:57710
#  - Register worker <WorkerState 'tcp://127.0.0.1:33493', name: 88, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33493
#  - Starting established connection to tcp://127.0.0.1:57776
#  - Register worker <WorkerState 'tcp://127.0.0.1:41541', name: 86, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41541
#  - Starting established connection to tcp://127.0.0.1:57704
#  - Register worker <WorkerState 'tcp://127.0.0.1:46295', name: 85, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46295
#  - Starting established connection to tcp://127.0.0.1:57682
#  - Register worker <WorkerState 'tcp://127.0.0.1:37419', name: 91, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37419
#  - Starting established connection to tcp://127.0.0.1:57730
#  - Receive client connection: Client-a0951ae9-2705-11f0-b9b8-00000555fe80
#  - Starting established connection to tcp://127.0.0.1:57890
# <Client: 'tcp://127.0.0.1:38683' processes=100 threads=100>

# %%
np.random.gamma
np.random.weibull
import scipy
scipy.stats.genextreme.rvs#(c, loc, scale, size)
# np.random.lognormal(mean, sigma, size)
# Out:
# <bound method rv_generic.rvs of <scipy.stats._continuous_distns.genextreme_gen object at 0x1484ad235a50>>

# %%
import numpy as np
from scipy.signal import lfilter

def generate_red_noise(size=100, std=0.2, alpha=0):
    """
    Generates red noise (AR(1) process) with a specified standard deviation.

    Parameters:
    size (int): Length of the generated red noise sequence (default: 100).
    std (float): Desired standard deviation of the output red noise (default: 0.2).
    alpha (float): Autoregressive parameter (default: 0, which gives white noise).

    Returns:
    np.ndarray: Red noise sequence with the specified standard deviation.
    """

    # Generate standard normal white noise
    noise = np.random.normal(0, std, size)
    
    # Apply AR(1) filter to introduce autocorrelation
    if alpha: noise = lfilter([1], [1, -alpha], noise)
        
    # Normalize the output to match the desired standard deviation
    noise = noise / np.std(noise) * std
    return noise

# %%
def non_stationary_noise(arr: np.ndarray, start_std: float, end_std: float, window: int) -> np.ndarray:
    """
    Apply a linearly varying noise multiplier to an array.

    The function scales the input array using a smoothly increasing 
    standard deviation multiplier. The standard deviation starts at 
    a lower value and linearly increases, reaching `start_std` at 
    index `window//2` and `end_std` at `len(arr) - window//2`.

    Parameters:
    -----------
    arr : np.ndarray
        Input array to be scaled.
    start_std : float
        Standard deviation multiplier at index `window//2`.
    end_std : float
        Standard deviation multiplier at index `len(arr) - window//2`.
    window : int
        Defines the range within which the standard deviation scaling begins and ends.

    Returns:
    --------
    np.ndarray
        Scaled array with non-stationary noise applied.
    """

    n = len(arr)
    start_idx = window // 2
    end_idx = n - window // 2

    std_mult_series = np.linspace(
        start_std - (start_idx / (end_idx - start_idx)) * (end_std - start_std),
        end_std + ((n - end_idx) / (end_idx - start_idx)) * (end_std - start_std),
        n
    )

    return arr * std_mult_series

# %%
sample_ts = generate_red_noise(300, 1, 0)

# %%
sample_ts_new = non_stationary_noise(sample_ts, start_std=0.1, end_std=1, window=30)

# %%
plt.plot(sample_ts)
plt.plot(sample_ts_new)

# %%
std_list = np.arange(0.1, 0.5, 0.1)
rho_list = np.arange(0.1, 0.5, 0.1)

for std, rho in product(std_list, rho_list):
    output_std = np.std(generate_red_noise(300, std, rho))
    print(f'{std=:.2f} - {rho=:.2f} - {output_std:.2f} - ({(std-output_std):.2f})')
# Out:
# std=0.10 - rho=0.10 - 0.10 - (0.00)
# std=0.10 - rho=0.20 - 0.10 - (0.00)
# std=0.10 - rho=0.30 - 0.10 - (-0.00)
# std=0.10 - rho=0.40 - 0.10 - (0.00)
# std=0.20 - rho=0.10 - 0.20 - (-0.00)
# std=0.20 - rho=0.20 - 0.20 - (-0.00)
# std=0.20 - rho=0.30 - 0.20 - (-0.00)
# std=0.20 - rho=0.40 - 0.20 - (0.00)
# std=0.30 - rho=0.10 - 0.30 - (0.00)
# std=0.30 - rho=0.20 - 0.30 - (0.00)
# std=0.30 - rho=0.30 - 0.30 - (0.00)
# std=0.30 - rho=0.40 - 0.30 - (0.00)
# std=0.40 - rho=0.10 - 0.40 - (0.00)
# std=0.40 - rho=0.20 - 0.40 - (0.00)
# std=0.40 - rho=0.30 - 0.40 - (0.00)
# std=0.40 - rho=0.40 - 0.40 - (0.00)

# %%
def generate_base_noise(distribution, **kwargs):
    """
    Returns a pre-configured noise generation function with fixed parameters.

    Parameters:
    distribution (str): The distribution to slog in as the base noise source.
    **kwargs: Additional parameters required for each distribution.

    Returns:
    function: A function that generates noise samples when called.
    """

    if distribution == "normal": return partial(np.random.normal, **kwargs)
    elif distribution == "gamma": return partial(np.random.gamma, **kwargs)
    elif distribution == "lognormal": return partial(np.random.lognormal, **kwargs)
    elif distribution == "weibull": return partial(np.random.weibull, **kwargs)
    elif distribution == "exponential": return partial(np.random.exponential, **kwargs)
    elif distribution == "gumbel": return partial(np.random.gumbel, **kwargs)
    elif distribution == "poisson": return partial(np.random.poisson, **kwargs)
    else:
        raise ValueError(
            "Unsupported distribution type. Choose from: normal, gamma, lognormal, weibull, exponential, gumbel, poisson."
        )

# %%
def generate_noise_process(size, alpha, noise_func):
    """
    Generates an autocorrelated noise process (AR(1) process) using a given noise function.

    Parameters:
    size (int): Length of the generated noise sequence.
    alpha (float): Autoregressive parameter (0 gives uncorrelated noise).
    noise_func (function): Pre-configured function to generate noise samples.

    Returns:
    np.ndarray: Noise process sequence with the specified autocorrelation.
    """
    
    # Generate noise using the pre-configured function
    base_noise = noise_func(size)

    # Apply AR(1) filter to introduce autocorrelation
    noise_process = lfilter([1], [1, -alpha], base_noise)

    # Normalize the output to match the original standard deviation
    noise_process = noise_process / np.std(noise_process) * np.std(base_noise)

    return noise_process

# %%
# # Create a noise generator with specific parameters
# gamma_noise = generate_base_noise("gamma", shape=2, scale=0.5)
# lognormal_noise = generate_base_noise("lognormal", mean=0, sigma=0.3)

# # Use it in the AR(1) noise process
# gamma_series = generate_noise_process(size=1000, alpha=0.8, noise_func=gamma_noise)
# lognormal_series = generate_noise_process(size=1000, alpha=0.5, noise_func=lognormal_noise)

# %% [markdown]
# <h1 style='color:cyan'> Single Ensemble </h1>

# %%
np.random.seed(51)

# Generate time series
n = 150  # Number of time points
base_period = np.tile(0, 30)
grad = 1.2/130 # 1.2 degree change since 1850
trend_line = grad * np.arange(150)  # Linear trend

true_trend = np.concatenate([base_period, trend_line])
t = np.arange(len(true_trend))

# %%
base_noise = generate_red_noise(len(true_trend), 0.25, 0.3)
base_noise.shape, true_trend.shape
# Out:
# ((180,), (180,))

# %%
num_iterations = 4

# %%
# Generate iterations

# %%
# Define the iterations coordinate
iterations = np.arange(1, num_iterations + 1)

# Compute noisy signals (vectorized)
noisy_signals = true_trend + np.outer(iterations, base_noise)

# Convert to xarray DataArray
noisy_series_xr = xr.DataArray(
    noisy_signals,
    dims=( "noise_index","time"),  # Using 'noise_index' as requested
    coords={"noise_index": np.arange(num_iterations),  "time": t}
)

# %%
nrows = 2
ncols = 2
num_plot = nrows*ncols


fig = plt.figure(figsize=(6*nrows, 3.5*ncols))
gs = gridspec.GridSpec(nrows, ncols, hspace=0.3)
axes = [fig.add_subplot(gs[i]) for i in range(num_plot)]

time = noisy_series_xr.time.values

for i in np.arange(num_iterations):

    noisy_series = noisy_series_xr.sel(noise_index=i).values

    
    axes[i].plot(time, noisy_series, color='red', alpha=0.6)
    # axes[i].plot(t, true_trend, linestyle='dashed', color='black', label='True Trend')
    
    axes[i].set_title(f'Standard Deviation={np.std(noisy_series[:30]):.1f}')
    # axes[i].legend()
    axes[i].grid(True)

    axes[i].set_xlim(0, len(time))
    axes[i].set_ylim(-2.4, 5)
    
# axes[0].set_ylabel('Value')
for ax in axes:
    ax.set_xlabel('Time (years)')

# plt.tight_layout()

# %%
signal_df = xr.apply_ufunc(
    my_stats.apply_lowess,
    noisy_series_xr,
    input_core_dims=[['time']],
    output_core_dims=[['time']],
    vectorize=True
)

# %%
signal_df.plot(hue='noise_index');

# %%
noise_df = noisy_series_xr.isel(time=slice(0,30)).std(dim='time')
noise_df
# Out:
# <xarray.DataArray (noise_index: 4)> Size: 32B
# 0.2637 0.5273 0.791 1.055
# Coordinates:
#   * noise_index  (noise_index) int64 32B 0 1 2 3

# %%
sn_df = signal_df/noise_df

# %%
sn_df.plot(hue='noise_index');

# %% [markdown]
# <h1 style='color:cyan'> Variable Definitions </h1>

# %%
def generate_noise_ensemble(std: float, rho: float, num_trials: int = 200, 
                            atol: float = None, rtol: float = None, length: int = 100, 
                            batch_size: int = 100):
    """
    Generate an ensemble of red noise series with a specified standard deviation in parallel batches.

    Parameters:
    - std: Target standard deviation of the noise series.
    - rho: Autoregressive coefficient for red noise.
    - num_trials: Number of noise series to generate.
    - atol: Absolute tolerance for matching the desired standard deviation.
    - rtol: Relative tolerance for matching the desired standard deviation.
    - length: Length of each noise series.
    - batch_size: Number of noise series processed in a single batch.

    Returns:
    - A NumPy array containing the noise ensemble.
    """

    if atol is None and rtol is None:
        atol = 0.05 * std
    elif rtol is not None:
        atol = rtol * std

    print(f'\n{std=} - {rho=} - {length=} - {atol=}\n')

    @delayed
    def generate_batch():
        """ Generate a batch of red noise and filter valid samples. """
        samples = np.array([generate_red_noise(length, std, rho) for _ in range(batch_size)])
        stds = np.std(samples, axis=1)
        valid_samples = samples[(stds > (std - atol)) & (stds < (std + atol))]
        print(f'len - {len(valid_samples)}')
        return valid_samples

    collected_samples = []
    to_compute = []

    
    batch_num = 0  # Track batch number
    while len(collected_samples) < num_trials:
        batch_num += 1
        print(f"{batch_num} ({len(collected_samples)}), ", end='')  # Print batch number
    
        batch = generate_batch()  # Create delayed task
        valid_samples = compute(batch)[0]  # Compute after each batch
        
        collected_samples.extend(valid_samples)

        # # Stop if we have enough samples
        # if len(collected_samples) >= num_trials:
        #     break

    # Trim to exactly `num_trials`
    noise_series_arr = np.array(collected_samples[:num_trials])

    # Convert to xarray
    noise_bs_xr = xr.DataArray(
        noise_series_arr,
        dims=("iteration", "time"),
        coords={"iteration": np.arange(num_trials), "time": np.arange(length),
               'rho': rho, 'std': std}
    ).chunk({'iteration':'auto', 'time':-1})


    return noise_bs_xr

# %%
base_period_length = 30
window = 30

# %%
base_period = np.tile(0, base_period_length)
grad = 1.2/140 # 1.2 degree change since 1850
trend_line = grad * np.arange(470)  # Linear trend

true_trend = np.concatenate([base_period, trend_line])
true_trend.shape
# Out:
# (500,)

# %%
kde_kwargs= dict(bw_method=0.2) # silverman, scott#bw_method=0.2)

# %%
x = np.linspace(0, true_trend.shape[0], 2000)

# %%
kde_create_kwargs = dict(
    input_core_dims=[['iteration']],
    output_core_dims=[['x']],
    kwargs={'x': x, **kde_kwargs},
    vectorize=True,
    dask='parallelized',
    output_sizes={'x':len(x)},  # Specify the size of the 'bin' dimension
    output_dtypes=[float]
)

# %%
SAVE_DIR = '/g/data/w40/ab2313/time_of_emergence/synthetic_data'

# %% [markdown]
# <h1 style='color:cyan'> Bootstrap</h1>

# %% [markdown]
# <h2 style='color:yellow'> Generating Data </h2>

# %%
std_values = [0.1, 0.25, 0.5, 0.75, 1]
rho_values = [0, 0.25, 0.5, 0.75]

# First, concatenate along std
std_concat_list = []
for std in std_values:
    rho_concat_list = [
        generate_noise_ensemble(
            std, rho, length=true_trend.shape[0],
            rtol=0.2, num_trials=10000)
        for rho in rho_values]
    std_concat_list.append(xr.concat(rho_concat_list, dim="rho"))

# Then, concatenate along rho
noise_ensemble_da = xr.concat(std_concat_list, dim="std")
# Out:
# std=0.1 - rho=0 - length=500 - atol=0.020000000000000004
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.1 - rho=0.25 - length=500 - atol=0.020000000000000004
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.1 - rho=0.5 - length=500 - atol=0.020000000000000004
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.1 - rho=0.75 - length=500 - atol=0.020000000000000004
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.25 - rho=0 - length=500 - atol=0.05
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.25 - rho=0.25 - length=500 - atol=0.05
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.25 - rho=0.5 - length=500 - atol=0.05
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.25 - rho=0.75 - length=500 - atol=0.05
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.5 - rho=0 - length=500 - atol=0.1
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.5 - rho=0.25 - length=500 - atol=0.1
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.5 - rho=0.5 - length=500 - atol=0.1
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.5 - rho=0.75 - length=500 - atol=0.1
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.75 - rho=0 - length=500 - atol=0.15000000000000002
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.75 - rho=0.25 - length=500 - atol=0.15000000000000002
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.75 - rho=0.5 - length=500 - atol=0.15000000000000002
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=0.75 - rho=0.75 - length=500 - atol=0.15000000000000002
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=1 - rho=0 - length=500 - atol=0.2
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=1 - rho=0.25 - length=500 - atol=0.2
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=1 - rho=0.5 - length=500 - atol=0.2
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=1 - rho=0.75 - length=500 - atol=0.2
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),

# %%
true_trend.shape
# Out:
# (500,)

# %%
noise_ensemble_da
# Out:
# <xarray.DataArray (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# dask.array<chunksize=(1, 1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0

# %%
trend_bs_xr = noise_ensemble_da + true_trend

# %%
trend_bs_xr
# Out:
# <xarray.DataArray (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# dask.array<chunksize=(1, 1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0

# %%
fig, axes = plt.subplots(2, 2)
axes = axes.ravel()

trend_bs_xr.sel(std=0.1, rho=0).plot(ax=axes[0], hue='iteration', add_legend=False);
trend_bs_xr.sel(std=0.1, rho=0.75).plot(ax=axes[1], hue='iteration', add_legend=False);
trend_bs_xr.sel(std=1, rho=0).plot(ax=axes[2], hue='iteration', add_legend=False);
trend_bs_xr.sel(std=1, rho=0.75).plot(ax=axes[3], hue='iteration', add_legend=False);

plt.tight_layout()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 38.15 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %% [markdown]
# <h2 style='color:yellow'> ToE Calclulation </h2>

# %%
data_ds_window = (trend_bs_xr
                  .rolling(time=window, center=True, min_periods=window)
                  .construct('window_dim')
                  # .chunk({'window_dim':-1,**CHUNKS_FOR_PVALUE_TESTS})
                  .persist()
                 ) 

base_period_window_ds = (trend_bs_xr.sel(time=slice(0, base_period_length))
                         # .chunk(CHUNKS_FOR_PVALUE_TESTS)
                         .rename({'time':'window_dim'})
                         .persist()
                        )
wait(data_ds_window);
wait(base_period_window_ds);
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 763.01 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.95 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
trend_bs_xr
# Out:
# <xarray.DataArray (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# dask.array<chunksize=(1, 1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0

# %% [markdown]
# ### KS and Overlap

# %%
# # The arguements needed for all of the calculations
# rolling_window_kwargs = dict(
#     input_core_dims=[['window_dim'], ['window_dim']],
#     exclude_dims={'window_dim'},
#     vectorize=True,
#     dask='parallelized')

# %%
# %%time
# # Expected 3 minutes 30 seconds - best
# # 6 23 - era5
# ks_ds = xr.apply_ufunc(
#         toe_calc.return_ks_pvalue,
#         data_ds_window,
#         base_period_window_ds,
#     **rolling_window_kwargs
#     ).compute()

# %%
# %%time
ks_ds = toe_calc_variations.ks(data_ds_window, base_period_window_ds)

# %%
# import toe_calc_variations

# %%
ks_ds.sel(rho=0.25, std=0.25).plot(hue='iteration', add_legend=False);

# %%
# %%time
fga_ds = toe_calc_variations.fga(
    trend_bs_xr, trend_bs_xr.isel(time=slice(0, base_period_length)), data_ds_window).compute()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.95 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.95 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.96 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
fga_ds
# Out:
# <xarray.DataArray 'frac' (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# 81.89 83.64 90.0 88.37 88.43 ... 0.0109 0.00677 1.947e-12 2.821e-25 2.827e-26
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0
# Attributes:
#     bw_method:   0.2
#     bmin:        -4.91480215867236
#     bmax:        8.865021559479432
#     num_points:  1000

# %% [markdown]
# ### S/N Ratio

# %%
trend_anom_bs_xr = trend_bs_xr - trend_bs_xr.isel(time=slice(0, base_period_length)).mean(dim='time')

# %%
signal_bs_xr = xr.apply_ufunc(
    my_stats.apply_lowess,
    trend_anom_bs_xr,
    input_core_dims=[['time']],
    output_core_dims=[['time']],
    vectorize=True,
    dask='parallelized',
    output_dtypes=[float]
).compute()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.96 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
noise_bs_xr = trend_bs_xr.isel(time=slice(0, base_period_length)).std(dim='time')

# %%
sn_bs_xr = signal_bs_xr/noise_bs_xr

# %%
fig, axes = plt.subplots(2, 2)
axes = axes.ravel()

sn_bs_xr.sel(std=0.1, rho=0).plot(ax=axes[0], hue='iteration', add_legend=False);
sn_bs_xr.sel(std=0.1, rho=0.75).plot(ax=axes[1], hue='iteration', add_legend=False);
sn_bs_xr.sel(std=1, rho=0).plot(ax=axes[2], hue='iteration', add_legend=False);
sn_bs_xr.sel(std=1, rho=0.75).plot(ax=axes[3], hue='iteration', add_legend=False);

plt.tight_layout()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 801.09 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %% [markdown]
# ### ToE

# %%
# trend_bs_xr.to_zarr(os.path.join(SAVE_DIR, 'trend_rho_std.zarr'), mode='w')
trend_bs_xr = xr.open_dataset(os.path.join(SAVE_DIR, 'trend_rho_std.zarr'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # trend_bs_xr.to_zarr(os.path.join(SAVE_DIR, 'trend_rho_std.zarr'), mode='w')
# ----> 2 trend_bs_xr = xr.open_dataset(os.path.join(SAVE_DIR, 'trend_rho_std.zarr'))
#
# NameError: name 'SAVE_DIR' is not defined

# %%
sn_bs_xr.to_zarr(os.path.join(SAVE_DIR, 'sn_rho_std.zarr'), mode='w')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 1.49 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
ks_ds.to_zarr(os.path.join(SAVE_DIR, 'ks_rho_std.zarr'), mode='w')

# %%
fga_ds.to_zarr(os.path.join(SAVE_DIR, 'fga_rho_std.zarr'), mode='w')

# %%
sn_toe_bs_xr = toe_calc.get_permanent_exceedance(
            sn_bs_xr, threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
ks_toe_bs_xr = toe_calc.get_permanent_exceedance(
            ks_ds, threshold=0.01, comparison_func=np.less, time=sn_bs_xr.time.values)

# %%
fga_toe_bs_xr = toe_calc.get_permanent_exceedance(
            fga_ds, threshold=62, comparison_func=np.less, time=sn_bs_xr.time.values)

# %%
sn_toe_bs_xr.sel(std=1, rho=0.75).plot()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 801.10 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
# %%time
sn_toe_bs_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    sn_toe_bs_xr,
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 1.49 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# CPU times: user 17 s, sys: 27.3 s, total: 44.3 s
# Wall time: 44.3 s

# %%
# %%time
ks_toe_bs_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    ks_toe_bs_xr,
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# CPU times: user 5.47 s, sys: 2.5 s, total: 7.96 s
# Wall time: 4 s

# %%
# %%time
fga_toe_bs_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    fga_toe_bs_xr,
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# CPU times: user 5.43 s, sys: 2.49 s, total: 7.92 s
# Wall time: 3.99 s

# %%
ks_toe_bs_kde_xr['x'] = x
sn_toe_bs_kde_xr['x'] = x
fga_toe_bs_kde_xr['x'] = x

# %%
sn_toe_bs_xr = sn_toe_bs_xr.compute()
ks_toe_bs_xr = ks_toe_bs_xr.compute()
fga_toe_bs_xr = fga_toe_bs_xr.compute()

# %% [markdown]
# <h2 style='color:yellow'> Plotting </h2>

# %%
sn_toe_bs_xr.median(dim='iteration').plot()

# %%
from matplotlib.ticker import MaxNLocator

# %%
fga_toe_bs_xr.std(dim='iteration').to_pandas().round(0)
# Out:
# rho   0.00  0.25  0.50  0.75
# std
# 0.10   4.0   4.0   5.0   7.0
# 0.25   9.0  10.0  13.0  17.0
# 0.50  17.0  21.0  25.0  34.0
# 0.75  25.0  30.0  38.0  51.0
# 1.00  33.0  39.0  49.0  67.0

# %%
fga_toe_bs_xr.mean(dim='iteration').to_pandas().round(0)
# Out:
# rho    0.00   0.25   0.50   0.75
# std
# 0.10   42.0   42.0   41.0   40.0
# 0.25   57.0   57.0   57.0   55.0
# 0.50   86.0   86.0   86.0   86.0
# 0.75  116.0  117.0  119.0  121.0
# 1.00  147.0  151.0  154.0  159.0

# %%
def plot_toe_bs_kde(toe_bs_kde_xr, toe_bs_xr, colors=None, fig=None, axs=None,
                    add_legend=True, ylabel=True):
    """
    Plots Time of Emergence (ToE) bootstrapped KDE distributions for different std values, with vertical median lines.
    
    Parameters:
    - toe_bs_kde_xr: xarray.Dataset containing KDE distributions for ToE
    - toe_bs_xr: xarray.Dataset containing raw ToE values for computing medians
    - x: numpy array of x-axis values
    - fig: Optional matplotlib figure
    - axs: Optional list of matplotlib axes
    
    Returns:
    - fig, axs: Matplotlib figure and axes
    """
    # Get unique values for rho and std
    rho_values = toe_bs_kde_xr['rho'].values
    std_values = toe_bs_kde_xr['std'].values
    x = toe_bs_kde_xr.x.values
    
    # Assign a unique color to each rho for consistency across plots
    if colors is None: colors = plt.cm.viridis(np.linspace(0, 1, len(rho_values)))
    
    # Create figure and gridspec if not provided
    if fig is None or axs is None:
        fig = plt.figure(figsize=(6, len(std_values) * 1.5))
        gs = gridspec.GridSpec(len(std_values), 1, figure=fig, hspace=0)
        axs = [fig.add_subplot(gs[i, 0]) for i in range(len(std_values))]
    
    # Loop through std (rows)
    for i, (ax, std) in enumerate(zip(axs, std_values)):
        # Plot all rho values on the same subplot, using consistent colors
        for color, rho in zip(colors, rho_values):
            data = toe_bs_kde_xr.sel(std=std, rho=rho)
            ax.plot(x, data, color=color, label=f'{rho:.2f}')
            
            # Compute and plot the median vertical line
            median_x = np.nanmedian(toe_bs_xr.sel(std=std, rho=rho).values)
            median_y = data.values[np.argmin(np.abs(x - median_x))]
            ax.plot([median_x, median_x], [0, median_y], linestyle="dashed", color=color, alpha=0.7)

        
        ax.yaxis.set_major_locator(MaxNLocator(nbins=5, min_n_ticks=4, prune=None))
        ax.set_xlim(0, 350)
        if i == 0 and add_legend: 
            leg = ax.legend(loc='upper right', ncol=2, fontsize=12, frameon=False)
            leg.set_title('Lag-1 Auto-correlation')
            leg.get_title().set_fontsize(12)
        if 0 < i < len(std_values) - 1:
            # ax.spines['bottom'].set_visible(False)
            ax.set_xticklabels([])
        if i == len(std_values) - 1:
            ax.set_xlabel('Time of Emergence (ToE)') 
        if i == 0:
            ax.xaxis.tick_top()
            ax.xaxis.set_label_position('top')
        if ylabel: ax.set_ylabel(fr'$\sigma={std}$', fontsize=12)  
        ax.grid(True, linestyle='--', alpha=0.25, color='grey')
    
    return fig, axs

# %%
colors = plt.cm.viridis_r(np.linspace(0, 1, sn_toe_bs_kde_xr['rho'].values.shape[0]))

# %%
from toe_plots import METRIC_MAP

# %%
# Create figure and gridspec (multiple rows, 1 column)
fig = plt.figure(figsize=(14, len(std_values) * 1.5))
gs = gridspec.GridSpec(len(ks_toe_bs_kde_xr['std'].values), 3, figure=fig, hspace=0.13)
axes_left = [fig.add_subplot(gs[i, 0]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]
axes_middle = [fig.add_subplot(gs[i, 1]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]
axes_right = [fig.add_subplot(gs[i, 2]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]


plot_toe_bs_kde(sn_toe_bs_kde_xr, sn_toe_bs_xr, fig=fig, axs=axes_left, colors=colors);
plot_toe_bs_kde(ks_toe_bs_kde_xr, ks_toe_bs_xr, fig=fig, axs=axes_middle, colors=colors, ylabel=False, add_legend=False);
plot_toe_bs_kde(fga_toe_bs_kde_xr, fga_toe_bs_xr, fig=fig, axs=axes_right, colors=colors, ylabel=False, add_legend=False);


axes_left[0].set_title(METRIC_MAP['sn'], fontsize=15)
axes_middle[0].set_title(METRIC_MAP['ks'].replace('\n', ' '), fontsize=15)
axes_right[0].set_title(METRIC_MAP['frac'].replace('\n', ' '), fontsize=15)


for axes in [axes_left, axes_middle, axes_right]:
    for i,ax in enumerate(axes):
        if i == 0: ax.set_ylim(0, 0.16)
        if i == 1:ax.set_ylim(0, 0.05)
        if i == 2: ax.set_ylim(0, 0.025)
        if i==3: ax.set_ylim(0, 0.02)

# %%
# Create figure and gridspec (multiple rows, 1 column)
fig = plt.figure(figsize=(10, len(std_values) * 1.5))
gs = gridspec.GridSpec(len(ks_toe_bs_kde_xr['std'].values), 2, figure=fig, hspace=0)
axes_left = [fig.add_subplot(gs[i, 0]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]
axes_right = [fig.add_subplot(gs[i, 1]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]


plot_toe_bs_kde(sn_toe_bs_kde_xr, sn_toe_bs_xr, fig=fig, axs=axes_left, colors=colors);
plot_toe_bs_kde(ks_toe_bs_kde_xr, ks_toe_bs_xr, fig=fig, axs=axes_right, colors=colors);

# %% [markdown]
# <h1 style='color:cyan'> Non-stationary Variance </h1>

# %% [markdown]
# <h2 style='color:yellow'> Generating Data </h2>

# %%
attempt_no = 2

# %%
reload(toe_calc_variations)
# Out:
# <module 'toe_calc_variations' from '/home/563/ab2313/Documents/time_of_emergene_drafts/src/toe_calc_variations.py'>

# %%
true_trend.shape
# Out:
# (500,)

# %%
base_noise_xr = generate_noise_ensemble(
            1, 0, length=true_trend.shape[0],
            rtol=0.2, num_trials=10000)
# Out:
# std=1 - rho=0 - length=500 - atol=0.2
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),

# %%
non_stationary_noise
# Out:
# <function __main__.non_stationary_noise(arr: numpy.ndarray, start_std: float, end_std: float, window: int) -> numpy.ndarray>

# %%
non_stat_noise_kwargs = dict(
    input_core_dims=[['time']],
    output_core_dims = [['time']],
    vectorize=True,
    dask = 'parallelized',
    output_dtypes=[float]
)

# %%
base_noise_0p1t1p0_xr = xr.apply_ufunc(
    non_stationary_noise, 
    base_noise_xr,
    kwargs = dict(start_std=0.1, end_std=1, window=30),
    **non_stat_noise_kwargs
).persist()
wait(base_noise_0p1t1p0_xr);
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 38.15 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
base_noise_0p1t0p5_xr = xr.apply_ufunc(
    non_stationary_noise, 
    base_noise_xr,
    kwargs = dict(start_std=0.1, end_std=0.5, window=30),
    **non_stat_noise_kwargs
).persist()
wait(base_noise_0p1t0p5_xr);
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 38.15 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
base_noise_0p5t1p0_xr = xr.apply_ufunc(
    non_stationary_noise, 
    base_noise_xr,
    kwargs = dict(start_std=0.5, end_std=1, window=30),
    **non_stat_noise_kwargs
).persist()
wait(base_noise_0p5t1p0_xr);
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 38.15 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
def revers_time_values(ds):
    ds2 = ds.copy(deep=True)
    ds2.data = ds2.data[..., ::-1]
    return ds2

# %%
# Reverse nosie for trends with decreasing noise
base_noise_1p0t0p1_xr = revers_time_values(base_noise_0p1t1p0_xr)
base_noise_1p0t0p5_xr = revers_time_values(base_noise_0p5t1p0_xr)
base_noise_0p5t0p1_xr = revers_time_values(base_noise_0p1t0p5_xr)

# %%
plt.plot(true_trend)
plt.plot(true_trend/2)

# %%
# Increading trends
# Divide true trend by 2 as ToE is too early
trend_0p1t1p0_xr = base_noise_0p1t1p0_xr + true_trend/2
trend_0p5t1p0_xr = base_noise_0p5t1p0_xr + true_trend/2
trend_0p1t0p5_xr = base_noise_0p1t0p5_xr + true_trend/2

# %%
# Decrsing trends
trend_1p0t0p1_xr = base_noise_1p0t0p1_xr + true_trend
trend_1p0t0p5_xr = base_noise_1p0t0p5_xr + true_trend
trend_0p5t0p1_xr = base_noise_0p5t0p1_xr + true_trend

# %%
trend_0p1t1p0_xr['std'] = '0p1t1p0'
trend_0p5t1p0_xr['std'] = '0p5t1p0'
trend_0p1t0p5_xr['std'] = '0p1t0p5'
trend_1p0t0p1_xr['std'] = '1p0t0p1'
trend_1p0t0p5_xr['std'] = '1p0t0p5'
trend_0p5t0p1_xr['std'] = '0p5t0p1'

# %%
trend_non_stat_xr = xr.concat(
    [trend_0p1t1p0_xr, trend_0p5t1p0_xr, trend_0p1t0p5_xr,
     trend_1p0t0p1_xr, trend_1p0t0p5_xr, trend_0p5t0p1_xr], dim='std')

# %%
trend_non_stat_xr
# Out:
# <xarray.DataArray (std: 6, iteration: 10000, time: 500)> Size: 240MB
# dask.array<chunksize=(1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#     rho        int64 8B 0
#   * std        (std) <U7 168B '0p1t1p0' '0p5t1p0' ... '1p0t0p5' '0p5t0p1'

# %%
trend_non_stat_xr.isel(iteration=1).plot(hue='std');

# %% [markdown]
# <h2 style='color:yellow'> ToE Calculation </h2>

# %%
data_ds_window_non_stat = (trend_non_stat_xr
                  .rolling(time=window, center=True, min_periods=window)
                  .construct('window_dim')
                  # .chunk({'window_dim':-1,**CHUNKS_FOR_PVALUE_TESTS})
                  .persist()
                 ) 

base_period_window_ds_non_stat = (trend_non_stat_xr.sel(time=slice(0, base_period_length))
                         # .chunk(CHUNKS_FOR_PVALUE_TESTS)
                         .rename({'time':'window_dim'})
                         .persist()
                        )
wait(data_ds_window_non_stat);
wait(base_period_window_ds_non_stat);

# %%
# %%time
ks_non_stat_ds = toe_calc_variations.ks(data_ds_window_non_stat.isel(iteration=slice(0,100)),
                                        base_period_window_ds_non_stat.isel(iteration=slice(0,100)))

# %%
trend_non_stat_xr
# Out:
# <xarray.DataArray (std: 6, iteration: 10000, time: 500)> Size: 240MB
# dask.array<chunksize=(1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#     rho        int64 8B 0
#   * std        (std) <U7 168B '0p1t1p0' '0p5t1p0' ... '1p0t0p5' '0p5t0p1'

# %%
fga_non_stat_ds = toe_calc_variations.fga(
    trend_non_stat_xr,#.isel(iteration=slice(0,100)),
    trend_non_stat_xr.isel(time=slice(0, base_period_length)),#.isel(iteration=slice(0,100)),
    data_ds_window_non_stat#.isel(iteration=slice(0,100))
).compute()

# %%
reload(toe_calc_variations)
# Out:
# <module 'toe_calc_variations' from '/home/563/ab2313/Documents/time_of_emergene_drafts/src/toe_calc_variations.py'>

# %%
# %%time
sn_non_stat_xr = toe_calc_variations.sn_ratio(
    trend_non_stat_xr,#.isel(iteration=slice(0,100)),
    start=0, end=30)
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 228.90 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
sn_non_stat_xr
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:         (iteration: 10000, time: 500, std: 6)
# Coordinates:
#   * iteration       (iteration) int64 80kB 0 1 2 3 4 ... 9996 9997 9998 9999
#   * time            (time) int64 4kB 0 1 2 3 4 5 6 ... 494 495 496 497 498 499
#     rho             int64 8B 0
#   * std             (std) <U7 168B '0p1t1p0' '0p5t1p0' ... '1p0t0p5' '0p5t0p1'
# Data variables:
#     sn              (std, iteration, time) float64 240MB 0.3106 0.292 ... 7.731
#     sn_lowess_full  (std, iteration, time) float64 240MB 0.06535 ... 12.1
#     sn_roll         (std, iteration, time) float64 240MB nan nan nan ... nan nan
#     noise           (std, iteration, time) float64 240MB -0.04482 ... 0.01647
#     signal          (std, iteration, time) float64 240MB 0.0389 ... 3.846

# %%
sn_non_stat_xr.signal.sel(std=['0p1t1p0', '1p0t0p1']).isel(iteration=0).plot(hue='std');

# %%
sn_non_stat_xr.sn.sel(std=['0p1t1p0', '1p0t0p1']).isel(iteration=0).plot(hue='std');

# %% [markdown]
# <h2 style='color:yellow'>  Saving and Opening Data </h2>

# %%
# base_noise_xr.to_zarr(os.path.join(SAVE_DIR, 'base_noise_non_stat_var.zarr'), mode='w')
# trend_non_stat_xr.to_zarr(os.path.join(SAVE_DIR, 'trend_non_stat_var.zarr'), mode='w')
# sn_non_stat_xr.to_zarr(os.path.join(SAVE_DIR, 'sn_non_stat_var.zarr'), mode='w')
# ks_non_stat_ds.to_zarr(os.path.join(SAVE_DIR, 'ks_non_stat_var.zarr'), mode='w')
# fga_non_stat_ds.to_zarr(os.path.join(SAVE_DIR, 'ga_non_stat_var.zarr'), mode='w')

# %%
chunks = {'time':-1, 'iteration':200}

# %%
base_noise_xr
# Out:
# <xarray.Dataset> Size: 40MB
# Dimensions:                        (iteration: 10000, time: 500)
# Coordinates:
#   * iteration                      (iteration) int64 80kB 0 1 2 ... 9998 9999
#     rho                            int64 8B ...
#     std                            int64 8B ...
#   * time                           (time) int64 4kB 0 1 2 3 ... 496 497 498 499
# Data variables:
#     __xarray_dataarray_variable__  (iteration, time) float64 40MB dask.array<chunksize=(10000, 500), meta=np.ndarray>

# %%
base_noise_xr = xr.open_zarr(os.path.join(SAVE_DIR, 'base_noise_non_stat_var.zarr')).to_array().chunk(**chunks)
trend_non_stat_xr = xr.open_zarr(os.path.join(SAVE_DIR, 'trend_non_stat_var.zarr')).chunk(**chunks)
sn_non_stat_xr = xr.open_zarr(os.path.join(SAVE_DIR, 'sn_non_stat_var.zarr')).chunk(**chunks)
ks_non_stat_ds = xr.open_zarr(os.path.join(SAVE_DIR, 'ks_non_stat_var.zarr')).chunk(**chunks)
fga_non_stat_ds = xr.open_zarr(os.path.join(SAVE_DIR, 'ga_non_stat_var.zarr')).chunk(**chunks)

# %%
# %%time
ks_toe_non_stat_xr = toe_calc.get_permanent_exceedance(
            ks_non_stat_ds, threshold=0.01, comparison_func=np.less, time=ks_non_stat_ds.time.values).compute()
# Out:
# CPU times: user 117 ms, sys: 50.4 ms, total: 167 ms
# Wall time: 227 ms

# %%
# %%time
sn_toe_non_stat_xr = toe_calc.get_permanent_exceedance(
    sn_non_stat_xr[['sn', 'sn_lowess_full', 'sn_roll']],
    threshold=1, comparison_func=np.greater,
    time=sn_non_stat_xr.time.values.astype(int), trim_nan=True).compute()
# Out:
# CPU times: user 4.38 s, sys: 665 ms, total: 5.05 s
# Wall time: 5.02 s

# %%
fga_toe_non_stat_xr = toe_calc.get_permanent_exceedance(
            fga_non_stat_ds, threshold=62, comparison_func=np.less, time=fga_non_stat_ds.time.values).compute()

# %%
# %%time
ks_toe_non_stat_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    ks_toe_non_stat_xr,
    **kde_create_kwargs
).compute();
# Out:
# CPU times: user 65.4 ms, sys: 22.3 ms, total: 87.7 ms
# Wall time: 54.2 ms
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.

# %%
# %%time
sn_toe_non_stat_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    sn_toe_non_stat_xr,
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# CPU times: user 5.44 s, sys: 697 ms, total: 6.14 s
# Wall time: 3.78 s

# %%
# %%time
fga_toe_non_stat_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    fga_toe_non_stat_xr,
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# CPU times: user 1.77 s, sys: 231 ms, total: 2 s
# Wall time: 1.23 s

# %%
ks_toe_non_stat_kde_xr['x'] = x
fga_toe_non_stat_kde_xr['x'] = x
sn_toe_non_stat_kde_xr['x'] = x

# %% [markdown]
# <h2 style='color:yellow'> Plots </h2>

# %%
def plot_toe_bs_kde_custom(kde_xr, toe_xr, colors=None, fig=None, axs=None, add_legend=True):
    """
    Plots Time of Emergence (ToE) KDE distributions for different datasets (KS and FGA) as variables within a merged dataset,
    with distinct colors for each dataset and different std values with distinct linestyles.

    Parameters:
    - kde_xr: xarray.Dataset containing KDE distributions with 'KS' and 'FGA' as variables
    - std_values: List of std values to plot
    - colors: Optional color list for datasets
    - fig: Optional matplotlib figure
    - axs: Optional list of matplotlib axes
    
    Returns:
    - fig, axs: Matplotlib figure and axes
    """
    x = kde_xr.x.values  # Assuming all datasets share the same x values
    std_values = kde_xr['std'].values
    toe_metrics = list(kde_xr)
    
    nrows = int(np.ceil(len(std_values)/2))
    # Create figure and gridspec if not provided
    if fig is None or axs is None:
        fig = plt.figure(figsize=(5*nrows, 10))
        gs = gridspec.GridSpec(nrows, 2, figure=fig, hspace=0.1)
        axs = []
        for j in range(2):  # Since you have 2 columns
            for i in range(nrows):
                axs.append(fig.add_subplot(gs[i, j]))
        # axs = [fig.add_subplot(gs[i]) for i in range(len(std_values))]
    
    for i, std in enumerate(std_values):
        ax = axs[i]
        for toe_met in toe_metrics:
            style = toe_plots.TEST_STYLES.get(toe_met, {'color':'black', 'linestyle':'sold'})
            data = kde_xr[toe_met].sel(std=std)

            ax.plot(x, data, label=toe_plots.METRIC_MAP.get(toe_met, toe_met).replace('\n', ' ').replace(' (', '\n('), **style)
            median_x = np.nanmedian(toe_xr[toe_met].sel(std=std).values)
            median_y = data.values[np.argmin(np.abs(x - median_x))]
            # ax.plot([median_x, median_x], [0, median_y], **style)
    
        ax.set_xlim(0, 350)
        if i in [0, 3]:
            ax.xaxis.tick_top()
            ax.xaxis.set_label_position("top")
            ax.set_xlabel("Time of Emergence (ToE)", fontsize=14)
        elif i in [2, 5]:
            ax.set_xlabel("Time of Emergence (ToE)", fontsize=14)

        if i in [1, 4]:
            ax.set_xticklabels([])
        else:
            ax.tick_params(axis='x', labelsize=12)
    
        
        ax.grid(True, linestyle="--", alpha=0.25, color="grey")
        ax.set_ylabel(r'$\sigma=$' + std.replace('p', '.').replace('t', ' to '), fontsize=15)
    
    if add_legend:
        axs[0].legend(loc='upper right', fontsize=12, frameon=False)#, bbox_to_anchor=(1.5, 0.5))

    axs[0].set_title('Increasing Variability', fontsize=16, pad=60)
    axs[3].set_title('Decreasing Variability', fontsize=16, pad=60)

# %%
toe_non_stat_kde_xr = xr.merge([sn_toe_non_stat_kde_xr, ks_toe_non_stat_kde_xr, fga_toe_non_stat_kde_xr])

# %%
toe_non_stat_xr = xr.merge([sn_toe_non_stat_xr, ks_toe_non_stat_xr, fga_toe_non_stat_xr])

# %%
non_stat_tests = list(toe_non_stat_kde_xr)
non_stat_tests
# Out:
# ['sn', 'sn_lowess_full', 'sn_roll', 'ks', 'frac']

# %%
std_order = ['0p1t0p5', '0p5t1p0', '0p1t1p0', '0p5t0p1', '1p0t0p5', '1p0t0p1']

# %%
plot_toe_bs_kde_custom(toe_non_stat_kde_xr.sel(std=std_order), toe_non_stat_xr)#['sn', 'sn_lowess_full', 'ks', 'frac']]);

# %% [markdown]
# <h1 style='color:yellow'> Trend Demonstartion </h1>

# %%
colors = plt.cm.viridis_r(np.linspace(0, 1, trend_bs_xr['rho'].values.shape[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 colors = plt.cm.viridis_r(np.linspace(0, 1, trend_bs_xr['rho'].values.shape[0]))
#
# NameError: name 'trend_bs_xr' is not defined

# %%
trend_bs_xr_sample = trend_bs_xr.isel(iteration=0).compute()

# %%
 trend_non_stat_xr.isel(iteration=0).values

# %%
trend_non_stat_xr_sample = trend_non_stat_xr.isel(iteration=0).compute()

# %%
non_stat_std_values

# %%
grad_label = grad * 10
grad_label2 = grad_label/2

# %%
fig = plt.figure(figsize=(10, 16))
gs = gridspec.GridSpec(4,2, hspace=0.2, height_ratios=[0.5, 1, 1, 0.5])
ax_top = fig.add_subplot(gs[0, :])

ax_top.plot(true_trend, label=f'{grad_label:.2f} per decade')
ax_top.plot(true_trend/2, label=f'{grad_label2:.2f} per decade')
ax_top.set_xlim(0, 500)
ax_top.legend()

std_values = trend_bs_xr_sample['std'].values
rho_values = trend_bs_xr_sample['rho'].values

for num,rho in enumerate(rho_values):
    rho_gs = gridspec.GridSpecFromSubplotSpec(len(std_values), 1, hspace=0, subplot_spec=gs[2+num])
    rho_axes = [fig.add_subplot(rho_gs[i]) for i in range(len(std_values))]
    for num2, std in enumerate(std_values):
        ax = rho_axes[num2]
        ax.plot(trend_bs_xr_sample.sel(rho=rho, std=std).values)
        ax.set_ylabel(r'$\sigma=$'+f'\n{std:0.2f}', rotation=0, labelpad=15)
        ax.set_yticks([0, 2.5, 5])
        ax.set_ylim(-3, 8)
        ax.set_xlim(0, 500)
        if num2 < (len(std_values)-1):
            ax.set_xticklabels([])
        
    rho_axes[0].set_title(r'$\rho_1=$'+f'{rho:0.2f}')


non_stat_ax1 = fig.add_subplot(gs[-2])
non_stat_ax2 = fig.add_subplot(gs[-1])


non_stat_std_values = trend_non_stat_xr_sample['std'].values
for i in range(3):
    std_vali  = non_stat_std_values[i]
    std_valim  = non_stat_std_values[-i-1]

    trend_non_stat_xr_sample.sel(std=std_vali).plot(ax=non_stat_ax1, alpha=0.5,
                                                    label=std_vali.replace('p', '.').replace('t', ' to '))
    trend_non_stat_xr_sample.sel(std=std_valim).plot(ax=non_stat_ax2, alpha=0.5,
                                                    label=std_valim.replace('p', '.').replace('t', ' to '))

leg1 = non_stat_ax1.legend()
leg1.set_title('Variance Change')

leg2 = non_stat_ax2.legend()
leg2.set_title('Variance Change')
non_stat_ax1.set_title('Increasing Variance', fontsize=14)
non_stat_ax2.set_title('Decreasing Variance', fontsize=14)

# %%
fig = plt.figure(figsize=(6, 10))
gs = gridspec.GridSpec(5,2)

ax_top = fig.add_subplot(gs[0, :])
rho_axes = np.array([fig.add_subplot(gs[row, col]) for row, col in [(1, 0), (1,1), (2, 0), (2, 1)]]).ravel()

ax_top.plot(true_trend)
ax_top.plot(true_trend/2)

std_values = trend_bs_xr_sample['std'].values
rho_values = trend_bs_xr_sample['rho'].values

for num,rho in enumerate(rho_values):
    ax = rho_axes[num]
    for std in std_values:
        ax.plot(trend_bs_xr_sample.sel(rho=rho, std=std).values, alpha=0.5)

# %%
trend_non_stat_xr

# %%
trend_bs_xr

# %% [markdown]
# # Old

# %%
for rho in sn_toe_bs_kde_xr['rho'].values:
    plt.plot(x, sn_toe_bs_kde_xr.sel(std=0.1, rho=rho))

# %%
for std in sn_toe_bs_kde_xr['std'].values:
    plt.plot(x, sn_toe_bs_kde_xr.sel(std=std, rho=0.75))

# %%
sn_toe_bs_kde_xr

# %%
sn_toe_bs_xr

# %%
sn_toe_bs_kde_m1 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=0).values, x)

# %%
toe_median_1 = toe_calc.get_permanent_exceedance(
            sn_bs_xr.median(dim='iteration'), threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1

# %%
# toe_median_1#.isel(multiplier=0)

# %%
 # Get the std of signal at the time when the median S/N ration between iterations is one
singal_range_list = []
for mult in toe_median_1.multiplier.values:
    median_toe = toe_median_1.sel(multiplier=mult).values.astype(int).item()
    signal_range = signal_bs_xr.sel(multiplier=mult).isel(time=median_toe)#.std()
    singal_range_list.append(signal_range)
signal_range_xr = xr.concat(singal_range_list, dim='multiplier')

# %%
ratio_s_std_to_noise_std = signal_range_xr.std(dim='iteration')/noise_bs_xr.std(dim='iteration')

# %%
ratio_s_std_to_noise_std

# %%
x = np.linspace(0, 200, 1000)

# %%
sn_toe_bs_xr

# %%
sn_toe_bs_kde_m1 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=0).values, x)
sn_toe_bs_kde_m2 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=1).values, x)
sn_toe_bs_kde_m3 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=2).values, x)
sn_toe_bs_kde_m4 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=3).values, x)

# %%
plt.plot(x, sn_toe_bs_kde_m1, label='1')
plt.plot(x, sn_toe_bs_kde_m2, label='2')
plt.plot(x, sn_toe_bs_kde_m3, label='3')
plt.plot(x, sn_toe_bs_kde_m4, label='4')
plt.legend()

# %%
trend_anom_bs_xr = trend_bs_xr - trend_bs_xr.isel(time=slice(0, 30)).mean(dim='time')

# %%
signal_bs_xr = xr.apply_ufunc(
    my_stats.apply_lowess,
    trend_anom_bs_xr,
    input_core_dims=[['time']],
    output_core_dims=[['time']],
    vectorize=True
)

# %%
noise_bs_xr = trend_bs_xr.isel(time=slice(0, 30)).std(dim='time')

# %%
sn_bs_xr = signal_bs_xr/noise_bs_xr

# %%
sn_toe_bs_xr = toe_calc.get_permanent_exceedance(
            sn_bs_xr, threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1 = toe_calc.get_permanent_exceedance(
            sn_bs_xr.median(dim='iteration'), threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1

# %%
# toe_median_1#.isel(multiplier=0)

# %%
 # Get the std of signal at the time when the median S/N ration between iterations is one
singal_range_list = []
for mult in toe_median_1.multiplier.values:
    median_toe = toe_median_1.sel(multiplier=mult).values.astype(int).item()
    signal_range = signal_bs_xr.sel(multiplier=mult).isel(time=median_toe)#.std()
    singal_range_list.append(signal_range)
signal_range_xr = xr.concat(singal_range_list, dim='multiplier')

# %%
ratio_s_std_to_noise_std = signal_range_xr.std(dim='iteration')/noise_bs_xr.std(dim='iteration')

# %%
ratio_s_std_to_noise_std

# %%
x = np.linspace(0, 200, 1000)

# %%
sn_toe_bs_xr

# %%
sn_toe_bs_kde_m1 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=0).values, x)
sn_toe_bs_kde_m2 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=1).values, x)
sn_toe_bs_kde_m3 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=2).values, x)
sn_toe_bs_kde_m4 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=3).values, x)

# %%
plt.plot(x, sn_toe_bs_kde_m1, label='1')
plt.plot(x, sn_toe_bs_kde_m2, label='2')
plt.plot(x, sn_toe_bs_kde_m3, label='3')
plt.plot(x, sn_toe_bs_kde_m4, label='4')
plt.legend()

# %%
noise_bs_xr = generate_noise_ensemble(0.25, 0.2, length=true_trend.shape[0])

# %%
trend_bs_xr = noise_bs_xr + true_trend

# %%
multipliers = [1, 2, 3, 4]

# Stack different noise scalings into a new "multiplier" dimension
trend_bs_xr = xr.concat([true_trend + noise_bs_xr * m for m in multipliers], dim="multiplier")

# Assign correct multiplier labels
trend_bs_xr["multiplier"] = multipliers
trend_bs_xr

# %%
trend_anom_bs_xr = trend_bs_xr - trend_bs_xr.isel(time=slice(0, 30)).mean(dim='time')

# %%
signal_bs_xr = xr.apply_ufunc(
    my_stats.apply_lowess,
    trend_anom_bs_xr,
    input_core_dims=[['time']],
    output_core_dims=[['time']],
    vectorize=True
)

# %%
noise_bs_xr = trend_bs_xr.isel(time=slice(0, 30)).std(dim='time')

# %%
sn_bs_xr = signal_bs_xr/noise_bs_xr

# %%
sn_toe_bs_xr = toe_calc.get_permanent_exceedance(
            sn_bs_xr, threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1 = toe_calc.get_permanent_exceedance(
            sn_bs_xr.median(dim='iteration'), threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1

# %%
# toe_median_1#.isel(multiplier=0)

# %%
 # Get the std of signal at the time when the median S/N ration between iterations is one
singal_range_list = []
for mult in toe_median_1.multiplier.values:
    median_toe = toe_median_1.sel(multiplier=mult).values.astype(int).item()
    signal_range = signal_bs_xr.sel(multiplier=mult).isel(time=median_toe)#.std()
    singal_range_list.append(signal_range)
signal_range_xr = xr.concat(singal_range_list, dim='multiplier')

# %%
ratio_s_std_to_noise_std = signal_range_xr.std(dim='iteration')/noise_bs_xr.std(dim='iteration')

# %%
ratio_s_std_to_noise_std

# %%
x = np.linspace(0, 200, 1000)

# %%
sn_toe_bs_xr

# %%
sn_toe_bs_kde_m1 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=0).values, x)
sn_toe_bs_kde_m2 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=1).values, x)
sn_toe_bs_kde_m3 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=2).values, x)
sn_toe_bs_kde_m4 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=3).values, x)

# %%
plt.plot(x, sn_toe_bs_kde_m1, label='1')
plt.plot(x, sn_toe_bs_kde_m2, label='2')
plt.plot(x, sn_toe_bs_kde_m3, label='3')
plt.plot(x, sn_toe_bs_kde_m4, label='4')
plt.legend()

# %%
noise_bs_xr.plot()

# %%
sn_bs_xr.plot(hue='iteration', add_legend=False);

# %%
signal_bs_xr.plot(hue='iteration', add_legend=False);

# %%
trend_series.plot(hue='iteration', add_legend=False);

# %%
noise_series_xr.plot(hue='iteration', add_legend=False);

# %%
noise_series_list.shape

# %%
lat_lon_sp = dict(lat=-34, lon=145, method='nearest')

# %%
stats_test_1d_array_ks = partial(
    toe_calc.stats_test_1d_array, stats_func=toe_calc.return_ks_pvalue,
    window=window, base_period_length=base_period.length+1)

# %%
ks_1d_1p = stats_test_1d_array_ks(data_ds.sel(**lat_lon_sp).isel(**ensemble_kwargs).values)

# %%
plt.plot(ks_1d_1p,label='1d', linestyle='--')
plt.plot(ks_ds.sel(**lat_lon_sp).isel(time=slice(int(window/2), -int(window/2)), **ensemble_kwargs).values, label='roll', alpha=0.5)
plt.legend()

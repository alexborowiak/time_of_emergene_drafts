# %%
import pandas as pd
import xarray as xr
import matplotlib.gridspec as gridspec
import dask
from dask import delayed, compute
from itertools import product
from importlib import reload
from functools import partial
# Out:
# Matplotlib created a temporary cache directory at /jobfs/141575903.gadi-pbs/matplotlib-1gokc969 because the default path (/home/563/ab2313/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import lfilter

# My imports
import os, sys
sys.path.append(os.path.join(os.getcwd(), 'Documents', 'time_of_emergene_drafts'))
sys.path.append(os.path.join(os.getcwd(), 'Documents', 'time_of_emergene_drafts', 'src'))
import my_stats
import toe_calc
import toe_calc_variations
import toe_constants as toe_const

# %%
import toe_plots

# %%
xr.set_options(display_expand_data=False)

# %%
from dask.distributed import wait

# %%
from dask.distributed import Client
# client.close()  # Close existing client
client = Client(n_workers=100, threads_per_worker=1, memory_limit=None)
client
# Out:
#  - State start
#  -   Scheduler at:     tcp://127.0.0.1:35569
#  -   dashboard at:         /proxy/8787/status
#  - Registering Worker plugin shuffle
#  -         Start Nanny at: 'tcp://127.0.0.1:41263'
#  -         Start Nanny at: 'tcp://127.0.0.1:33847'
#  -         Start Nanny at: 'tcp://127.0.0.1:44555'
#  -         Start Nanny at: 'tcp://127.0.0.1:36251'
#  -         Start Nanny at: 'tcp://127.0.0.1:45017'
#  -         Start Nanny at: 'tcp://127.0.0.1:34637'
#  -         Start Nanny at: 'tcp://127.0.0.1:46501'
#  -         Start Nanny at: 'tcp://127.0.0.1:40711'
#  -         Start Nanny at: 'tcp://127.0.0.1:35097'
#  -         Start Nanny at: 'tcp://127.0.0.1:35311'
#  -         Start Nanny at: 'tcp://127.0.0.1:43621'
#  -         Start Nanny at: 'tcp://127.0.0.1:40667'
#  -         Start Nanny at: 'tcp://127.0.0.1:43733'
#  -         Start Nanny at: 'tcp://127.0.0.1:38187'
#  -         Start Nanny at: 'tcp://127.0.0.1:43513'
#  -         Start Nanny at: 'tcp://127.0.0.1:36365'
#  -         Start Nanny at: 'tcp://127.0.0.1:44527'
#  -         Start Nanny at: 'tcp://127.0.0.1:34385'
#  -         Start Nanny at: 'tcp://127.0.0.1:37575'
#  -         Start Nanny at: 'tcp://127.0.0.1:40515'
#  -         Start Nanny at: 'tcp://127.0.0.1:46197'
#  -         Start Nanny at: 'tcp://127.0.0.1:36225'
#  -         Start Nanny at: 'tcp://127.0.0.1:46723'
#  -         Start Nanny at: 'tcp://127.0.0.1:35491'
#  -         Start Nanny at: 'tcp://127.0.0.1:33499'
#  -         Start Nanny at: 'tcp://127.0.0.1:41769'
#  -         Start Nanny at: 'tcp://127.0.0.1:38741'
#  -         Start Nanny at: 'tcp://127.0.0.1:32953'
#  -         Start Nanny at: 'tcp://127.0.0.1:41357'
#  -         Start Nanny at: 'tcp://127.0.0.1:39287'
#  -         Start Nanny at: 'tcp://127.0.0.1:42353'
#  -         Start Nanny at: 'tcp://127.0.0.1:36935'
#  -         Start Nanny at: 'tcp://127.0.0.1:40713'
#  -         Start Nanny at: 'tcp://127.0.0.1:37431'
#  -         Start Nanny at: 'tcp://127.0.0.1:41309'
#  -         Start Nanny at: 'tcp://127.0.0.1:37883'
#  -         Start Nanny at: 'tcp://127.0.0.1:41565'
#  -         Start Nanny at: 'tcp://127.0.0.1:33703'
#  -         Start Nanny at: 'tcp://127.0.0.1:39739'
#  -         Start Nanny at: 'tcp://127.0.0.1:33165'
#  -         Start Nanny at: 'tcp://127.0.0.1:44221'
#  -         Start Nanny at: 'tcp://127.0.0.1:43843'
#  -         Start Nanny at: 'tcp://127.0.0.1:46163'
#  -         Start Nanny at: 'tcp://127.0.0.1:33271'
#  -         Start Nanny at: 'tcp://127.0.0.1:35421'
#  -         Start Nanny at: 'tcp://127.0.0.1:42229'
#  -         Start Nanny at: 'tcp://127.0.0.1:44417'
#  -         Start Nanny at: 'tcp://127.0.0.1:37595'
#  -         Start Nanny at: 'tcp://127.0.0.1:41179'
#  -         Start Nanny at: 'tcp://127.0.0.1:34887'
#  -         Start Nanny at: 'tcp://127.0.0.1:36419'
#  -         Start Nanny at: 'tcp://127.0.0.1:45383'
#  -         Start Nanny at: 'tcp://127.0.0.1:44671'
#  -         Start Nanny at: 'tcp://127.0.0.1:34631'
#  -         Start Nanny at: 'tcp://127.0.0.1:36473'
#  -         Start Nanny at: 'tcp://127.0.0.1:35469'
#  -         Start Nanny at: 'tcp://127.0.0.1:38235'
#  -         Start Nanny at: 'tcp://127.0.0.1:42005'
#  -         Start Nanny at: 'tcp://127.0.0.1:40103'
#  -         Start Nanny at: 'tcp://127.0.0.1:45923'
#  -         Start Nanny at: 'tcp://127.0.0.1:38727'
#  -         Start Nanny at: 'tcp://127.0.0.1:44467'
#  -         Start Nanny at: 'tcp://127.0.0.1:42403'
#  -         Start Nanny at: 'tcp://127.0.0.1:33321'
#  -         Start Nanny at: 'tcp://127.0.0.1:40275'
#  -         Start Nanny at: 'tcp://127.0.0.1:43919'
#  -         Start Nanny at: 'tcp://127.0.0.1:40721'
#  -         Start Nanny at: 'tcp://127.0.0.1:37581'
#  -         Start Nanny at: 'tcp://127.0.0.1:37179'
#  -         Start Nanny at: 'tcp://127.0.0.1:32787'
#  -         Start Nanny at: 'tcp://127.0.0.1:37217'
#  -         Start Nanny at: 'tcp://127.0.0.1:36237'
#  -         Start Nanny at: 'tcp://127.0.0.1:45989'
#  -         Start Nanny at: 'tcp://127.0.0.1:32969'
#  -         Start Nanny at: 'tcp://127.0.0.1:38005'
#  -         Start Nanny at: 'tcp://127.0.0.1:39681'
#  -         Start Nanny at: 'tcp://127.0.0.1:40561'
#  -         Start Nanny at: 'tcp://127.0.0.1:44223'
#  -         Start Nanny at: 'tcp://127.0.0.1:40117'
#  -         Start Nanny at: 'tcp://127.0.0.1:38351'
#  -         Start Nanny at: 'tcp://127.0.0.1:41641'
#  -         Start Nanny at: 'tcp://127.0.0.1:38017'
#  -         Start Nanny at: 'tcp://127.0.0.1:38971'
#  -         Start Nanny at: 'tcp://127.0.0.1:41961'
#  -         Start Nanny at: 'tcp://127.0.0.1:43751'
#  -         Start Nanny at: 'tcp://127.0.0.1:34589'
#  -         Start Nanny at: 'tcp://127.0.0.1:46343'
#  -         Start Nanny at: 'tcp://127.0.0.1:46647'
#  -         Start Nanny at: 'tcp://127.0.0.1:45947'
#  -         Start Nanny at: 'tcp://127.0.0.1:45123'
#  -         Start Nanny at: 'tcp://127.0.0.1:33909'
#  -         Start Nanny at: 'tcp://127.0.0.1:37811'
#  -         Start Nanny at: 'tcp://127.0.0.1:39801'
#  -         Start Nanny at: 'tcp://127.0.0.1:40687'
#  -         Start Nanny at: 'tcp://127.0.0.1:41851'
#  -         Start Nanny at: 'tcp://127.0.0.1:43557'
#  -         Start Nanny at: 'tcp://127.0.0.1:35043'
#  -         Start Nanny at: 'tcp://127.0.0.1:37153'
#  -         Start Nanny at: 'tcp://127.0.0.1:46253'
#  -         Start Nanny at: 'tcp://127.0.0.1:35375'
#  - Register worker <WorkerState 'tcp://127.0.0.1:33213', name: 2, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33213
#  - Starting established connection to tcp://127.0.0.1:43084
#  - Register worker <WorkerState 'tcp://127.0.0.1:33569', name: 4, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33569
#  - Starting established connection to tcp://127.0.0.1:43088
#  - Register worker <WorkerState 'tcp://127.0.0.1:46567', name: 1, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46567
#  - Starting established connection to tcp://127.0.0.1:43096
#  - Register worker <WorkerState 'tcp://127.0.0.1:42319', name: 0, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42319
#  - Starting established connection to tcp://127.0.0.1:43072
#  - Register worker <WorkerState 'tcp://127.0.0.1:42689', name: 10, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42689
#  - Starting established connection to tcp://127.0.0.1:43110
#  - Register worker <WorkerState 'tcp://127.0.0.1:46557', name: 3, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46557
#  - Starting established connection to tcp://127.0.0.1:43124
#  - Register worker <WorkerState 'tcp://127.0.0.1:39339', name: 9, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39339
#  - Starting established connection to tcp://127.0.0.1:43120
#  - Register worker <WorkerState 'tcp://127.0.0.1:40883', name: 7, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40883
#  - Starting established connection to tcp://127.0.0.1:43106
#  - Register worker <WorkerState 'tcp://127.0.0.1:37685', name: 6, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37685
#  - Starting established connection to tcp://127.0.0.1:43136
#  - Register worker <WorkerState 'tcp://127.0.0.1:41175', name: 12, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41175
#  - Starting established connection to tcp://127.0.0.1:43142
#  - Register worker <WorkerState 'tcp://127.0.0.1:46273', name: 8, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46273
#  - Starting established connection to tcp://127.0.0.1:43162
#  - Register worker <WorkerState 'tcp://127.0.0.1:41713', name: 5, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41713
#  - Starting established connection to tcp://127.0.0.1:43148
#  - Register worker <WorkerState 'tcp://127.0.0.1:37621', name: 13, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37621
#  - Starting established connection to tcp://127.0.0.1:43180
#  - Register worker <WorkerState 'tcp://127.0.0.1:43159', name: 14, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43159
#  - Starting established connection to tcp://127.0.0.1:43174
#  - Register worker <WorkerState 'tcp://127.0.0.1:40943', name: 11, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40943
#  - Starting established connection to tcp://127.0.0.1:43186
#  - Register worker <WorkerState 'tcp://127.0.0.1:46559', name: 17, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46559
#  - Starting established connection to tcp://127.0.0.1:43196
#  - Register worker <WorkerState 'tcp://127.0.0.1:33061', name: 16, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33061
#  - Starting established connection to tcp://127.0.0.1:43208
#  - Register worker <WorkerState 'tcp://127.0.0.1:45705', name: 18, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45705
#  - Starting established connection to tcp://127.0.0.1:43210
#  - Register worker <WorkerState 'tcp://127.0.0.1:34691', name: 22, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34691
#  - Starting established connection to tcp://127.0.0.1:43234
#  - Register worker <WorkerState 'tcp://127.0.0.1:46173', name: 21, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46173
#  - Starting established connection to tcp://127.0.0.1:43240
#  - Register worker <WorkerState 'tcp://127.0.0.1:46437', name: 25, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46437
#  - Starting established connection to tcp://127.0.0.1:43252
#  - Register worker <WorkerState 'tcp://127.0.0.1:34437', name: 15, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34437
#  - Starting established connection to tcp://127.0.0.1:43218
#  - Register worker <WorkerState 'tcp://127.0.0.1:37265', name: 19, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37265
#  - Starting established connection to tcp://127.0.0.1:43242
#  - Register worker <WorkerState 'tcp://127.0.0.1:37033', name: 24, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37033
#  - Starting established connection to tcp://127.0.0.1:43270
#  - Register worker <WorkerState 'tcp://127.0.0.1:46245', name: 20, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46245
#  - Starting established connection to tcp://127.0.0.1:43248
#  - Register worker <WorkerState 'tcp://127.0.0.1:41595', name: 28, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41595
#  - Starting established connection to tcp://127.0.0.1:43292
#  - Register worker <WorkerState 'tcp://127.0.0.1:43399', name: 27, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43399
#  - Starting established connection to tcp://127.0.0.1:43282
#  - Register worker <WorkerState 'tcp://127.0.0.1:39645', name: 30, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39645
#  - Starting established connection to tcp://127.0.0.1:43300
#  - Register worker <WorkerState 'tcp://127.0.0.1:43673', name: 26, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43673
#  - Starting established connection to tcp://127.0.0.1:43326
#  - Register worker <WorkerState 'tcp://127.0.0.1:36299', name: 29, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36299
#  - Starting established connection to tcp://127.0.0.1:43322
#  - Register worker <WorkerState 'tcp://127.0.0.1:37823', name: 31, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37823
#  - Starting established connection to tcp://127.0.0.1:43308
#  - Register worker <WorkerState 'tcp://127.0.0.1:46735', name: 32, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46735
#  - Starting established connection to tcp://127.0.0.1:43336
#  - Register worker <WorkerState 'tcp://127.0.0.1:32939', name: 23, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:32939
#  - Starting established connection to tcp://127.0.0.1:43258
#  - Register worker <WorkerState 'tcp://127.0.0.1:39301', name: 37, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39301
#  - Starting established connection to tcp://127.0.0.1:43388
#  - Register worker <WorkerState 'tcp://127.0.0.1:45603', name: 36, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45603
#  - Starting established connection to tcp://127.0.0.1:43382
#  - Register worker <WorkerState 'tcp://127.0.0.1:33163', name: 34, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33163
#  - Starting established connection to tcp://127.0.0.1:43358
#  - Register worker <WorkerState 'tcp://127.0.0.1:33415', name: 35, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33415
#  - Starting established connection to tcp://127.0.0.1:43366
#  - Register worker <WorkerState 'tcp://127.0.0.1:38383', name: 41, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38383
#  - Starting established connection to tcp://127.0.0.1:43400
#  - Register worker <WorkerState 'tcp://127.0.0.1:36179', name: 33, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36179
#  - Starting established connection to tcp://127.0.0.1:43352
#  - Register worker <WorkerState 'tcp://127.0.0.1:40835', name: 43, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40835
#  - Starting established connection to tcp://127.0.0.1:43408
#  - Register worker <WorkerState 'tcp://127.0.0.1:40349', name: 42, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40349
#  - Starting established connection to tcp://127.0.0.1:43416
#  - Register worker <WorkerState 'tcp://127.0.0.1:46499', name: 40, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46499
#  - Starting established connection to tcp://127.0.0.1:43428
#  - Register worker <WorkerState 'tcp://127.0.0.1:40455', name: 39, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40455
#  - Starting established connection to tcp://127.0.0.1:43410
#  - Register worker <WorkerState 'tcp://127.0.0.1:38923', name: 47, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38923
#  - Starting established connection to tcp://127.0.0.1:43444
#  - Register worker <WorkerState 'tcp://127.0.0.1:36383', name: 38, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36383
#  - Starting established connection to tcp://127.0.0.1:43446
#  - Register worker <WorkerState 'tcp://127.0.0.1:42191', name: 44, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42191
#  - Starting established connection to tcp://127.0.0.1:43452
#  - Register worker <WorkerState 'tcp://127.0.0.1:37101', name: 45, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37101
#  - Starting established connection to tcp://127.0.0.1:43532
#  - Register worker <WorkerState 'tcp://127.0.0.1:41651', name: 49, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41651
#  - Starting established connection to tcp://127.0.0.1:43602
#  - Register worker <WorkerState 'tcp://127.0.0.1:44695', name: 50, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44695
#  - Starting established connection to tcp://127.0.0.1:43562
#  - Register worker <WorkerState 'tcp://127.0.0.1:44725', name: 48, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44725
#  - Starting established connection to tcp://127.0.0.1:43608
#  - Register worker <WorkerState 'tcp://127.0.0.1:46561', name: 52, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46561
#  - Starting established connection to tcp://127.0.0.1:43570
#  - Register worker <WorkerState 'tcp://127.0.0.1:38153', name: 46, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38153
#  - Starting established connection to tcp://127.0.0.1:43612
#  - Register worker <WorkerState 'tcp://127.0.0.1:36161', name: 55, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36161
#  - Starting established connection to tcp://127.0.0.1:43628
#  - Register worker <WorkerState 'tcp://127.0.0.1:38601', name: 53, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38601
#  - Starting established connection to tcp://127.0.0.1:43646
#  - Register worker <WorkerState 'tcp://127.0.0.1:41031', name: 54, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41031
#  - Starting established connection to tcp://127.0.0.1:43678
#  - Register worker <WorkerState 'tcp://127.0.0.1:44289', name: 51, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44289
#  - Starting established connection to tcp://127.0.0.1:43668
#  - Register worker <WorkerState 'tcp://127.0.0.1:42675', name: 61, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42675
#  - Starting established connection to tcp://127.0.0.1:43772
#  - Register worker <WorkerState 'tcp://127.0.0.1:38011', name: 56, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38011
#  - Starting established connection to tcp://127.0.0.1:43740
#  - Register worker <WorkerState 'tcp://127.0.0.1:33689', name: 58, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33689
#  - Starting established connection to tcp://127.0.0.1:43760
#  - Register worker <WorkerState 'tcp://127.0.0.1:39889', name: 60, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39889
#  - Starting established connection to tcp://127.0.0.1:43874
#  - Register worker <WorkerState 'tcp://127.0.0.1:35543', name: 62, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35543
#  - Starting established connection to tcp://127.0.0.1:43868
#  - Register worker <WorkerState 'tcp://127.0.0.1:36233', name: 71, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36233
#  - Starting established connection to tcp://127.0.0.1:43934
#  - Register worker <WorkerState 'tcp://127.0.0.1:38783', name: 59, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38783
#  - Starting established connection to tcp://127.0.0.1:43844
#  - Register worker <WorkerState 'tcp://127.0.0.1:43417', name: 66, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43417
#  - Starting established connection to tcp://127.0.0.1:43924
#  - Register worker <WorkerState 'tcp://127.0.0.1:45841', name: 67, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45841
#  - Starting established connection to tcp://127.0.0.1:44016
#  - Register worker <WorkerState 'tcp://127.0.0.1:36127', name: 65, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36127
#  - Starting established connection to tcp://127.0.0.1:43898
#  - Register worker <WorkerState 'tcp://127.0.0.1:41187', name: 69, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41187
#  - Starting established connection to tcp://127.0.0.1:44034
#  - Register worker <WorkerState 'tcp://127.0.0.1:45857', name: 64, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45857
#  - Starting established connection to tcp://127.0.0.1:43908
#  - Register worker <WorkerState 'tcp://127.0.0.1:40125', name: 72, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40125
#  - Starting established connection to tcp://127.0.0.1:43952
#  - Register worker <WorkerState 'tcp://127.0.0.1:45807', name: 90, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45807
#  - Starting established connection to tcp://127.0.0.1:44136
#  - Register worker <WorkerState 'tcp://127.0.0.1:39667', name: 78, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39667
#  - Starting established connection to tcp://127.0.0.1:44070
#  - Register worker <WorkerState 'tcp://127.0.0.1:42059', name: 70, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42059
#  - Starting established connection to tcp://127.0.0.1:43946
#  - Register worker <WorkerState 'tcp://127.0.0.1:35971', name: 68, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35971
#  - Starting established connection to tcp://127.0.0.1:43940
#  - Register worker <WorkerState 'tcp://127.0.0.1:32885', name: 74, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:32885
#  - Starting established connection to tcp://127.0.0.1:43966
#  - Register worker <WorkerState 'tcp://127.0.0.1:43351', name: 63, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43351
#  - Starting established connection to tcp://127.0.0.1:43992
#  - Register worker <WorkerState 'tcp://127.0.0.1:46811', name: 82, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46811
#  - Starting established connection to tcp://127.0.0.1:44126
#  - Register worker <WorkerState 'tcp://127.0.0.1:39599', name: 75, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39599
#  - Starting established connection to tcp://127.0.0.1:44062
#  - Register worker <WorkerState 'tcp://127.0.0.1:46413', name: 73, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46413
#  - Starting established connection to tcp://127.0.0.1:44078
#  - Register worker <WorkerState 'tcp://127.0.0.1:38539', name: 77, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38539
#  - Starting established connection to tcp://127.0.0.1:44130
#  - Register worker <WorkerState 'tcp://127.0.0.1:38161', name: 79, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38161
#  - Starting established connection to tcp://127.0.0.1:44098
#  - Register worker <WorkerState 'tcp://127.0.0.1:34349', name: 89, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34349
#  - Starting established connection to tcp://127.0.0.1:44204
#  - Register worker <WorkerState 'tcp://127.0.0.1:41549', name: 76, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41549
#  - Starting established connection to tcp://127.0.0.1:44110
#  - Register worker <WorkerState 'tcp://127.0.0.1:35013', name: 87, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35013
#  - Starting established connection to tcp://127.0.0.1:44188
#  - Register worker <WorkerState 'tcp://127.0.0.1:42745', name: 98, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42745
#  - Starting established connection to tcp://127.0.0.1:44274
#  - Register worker <WorkerState 'tcp://127.0.0.1:35223', name: 57, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35223
#  - Starting established connection to tcp://127.0.0.1:43878
#  - Register worker <WorkerState 'tcp://127.0.0.1:39251', name: 95, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39251
#  - Starting established connection to tcp://127.0.0.1:44240
#  - Register worker <WorkerState 'tcp://127.0.0.1:44907', name: 81, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44907
#  - Starting established connection to tcp://127.0.0.1:44174
#  - Register worker <WorkerState 'tcp://127.0.0.1:40859', name: 92, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40859
#  - Starting established connection to tcp://127.0.0.1:44334
#  - Register worker <WorkerState 'tcp://127.0.0.1:44411', name: 93, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:44411
#  - Starting established connection to tcp://127.0.0.1:44304
#  - Register worker <WorkerState 'tcp://127.0.0.1:34899', name: 88, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34899
#  - Starting established connection to tcp://127.0.0.1:44244
#  - Register worker <WorkerState 'tcp://127.0.0.1:46819', name: 97, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46819
#  - Starting established connection to tcp://127.0.0.1:44258
#  - Register worker <WorkerState 'tcp://127.0.0.1:43333', name: 91, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43333
#  - Starting established connection to tcp://127.0.0.1:44214
#  - Register worker <WorkerState 'tcp://127.0.0.1:37941', name: 84, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:37941
#  - Starting established connection to tcp://127.0.0.1:44144
#  - Register worker <WorkerState 'tcp://127.0.0.1:34185', name: 80, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34185
#  - Starting established connection to tcp://127.0.0.1:44092
#  - Register worker <WorkerState 'tcp://127.0.0.1:38551', name: 94, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38551
#  - Starting established connection to tcp://127.0.0.1:44302
#  - Register worker <WorkerState 'tcp://127.0.0.1:41661', name: 85, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41661
#  - Starting established connection to tcp://127.0.0.1:44160
#  - Register worker <WorkerState 'tcp://127.0.0.1:42611', name: 99, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42611
#  - Starting established connection to tcp://127.0.0.1:44330
#  - Register worker <WorkerState 'tcp://127.0.0.1:39003', name: 96, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39003
#  - Starting established connection to tcp://127.0.0.1:44152
#  - Register worker <WorkerState 'tcp://127.0.0.1:39631', name: 86, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39631
#  - Starting established connection to tcp://127.0.0.1:44288
#  - Register worker <WorkerState 'tcp://127.0.0.1:42953', name: 83, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:42953
#  - Starting established connection to tcp://127.0.0.1:44232
#  - Receive client connection: Client-ca4f2a7d-384e-11f0-85a3-00000561fe80
#  - Starting established connection to tcp://127.0.0.1:44406
# <Client: 'tcp://127.0.0.1:35569' processes=100 threads=100>

# %%
np.random.gamma
np.random.weibull
import scipy
scipy.stats.genextreme.rvs#(c, loc, scale, size)
# np.random.lognormal(mean, sigma, size)
# Out:
# <bound method rv_generic.rvs of <scipy.stats._continuous_distns.genextreme_gen object at 0x14fcfaa61a50>>

# %%
import numpy as np
from scipy.signal import lfilter

def generate_red_noise(size=100, std=0.2, alpha=0):
    """
    Generates red noise (AR(1) process) with a specified standard deviation.

    Parameters:
    size (int): Length of the generated red noise sequence (default: 100).
    std (float): Desired standard deviation of the output red noise (default: 0.2).
    alpha (float): Autoregressive parameter (default: 0, which gives white noise).

    Returns:
    np.ndarray: Red noise sequence with the specified standard deviation.
    """

    # Generate standard normal white noise
    noise = np.random.normal(0, std, size)
    
    # Apply AR(1) filter to introduce autocorrelation
    if alpha: noise = lfilter([1], [1, -alpha], noise)
        
    # Normalize the output to match the desired standard deviation
    noise = noise / np.std(noise) * std
    return noise

# %%
def non_stationary_noise(arr: np.ndarray, start_std: float, end_std: float, window: int) -> np.ndarray:
    """
    Apply a linearly varying noise multiplier to an array.

    The function scales the input array using a smoothly increasing 
    standard deviation multiplier. The standard deviation starts at 
    a lower value and linearly increases, reaching `start_std` at 
    index `window//2` and `end_std` at `len(arr) - window//2`.

    Parameters:
    -----------
    arr : np.ndarray
        Input array to be scaled.
    start_std : float
        Standard deviation multiplier at index `window//2`.
    end_std : float
        Standard deviation multiplier at index `len(arr) - window//2`.
    window : int
        Defines the range within which the standard deviation scaling begins and ends.

    Returns:
    --------
    np.ndarray
        Scaled array with non-stationary noise applied.
    """

    n = len(arr)
    start_idx = window // 2
    end_idx = n - window // 2

    std_mult_series = np.linspace(
        start_std - (start_idx / (end_idx - start_idx)) * (end_std - start_std),
        end_std + ((n - end_idx) / (end_idx - start_idx)) * (end_std - start_std),
        n
    )

    return arr * std_mult_series

# %%
sample_ts = generate_red_noise(300, 1, 0)

# %%
sample_ts_new = non_stationary_noise(sample_ts, start_std=0.1, end_std=1, window=30)

# %%
plt.plot(sample_ts)
plt.plot(sample_ts_new)

# %%
std_list = np.arange(0.1, 0.5, 0.1)
rho_list = np.arange(0.1, 0.5, 0.1)

for std, rho in product(std_list, rho_list):
    output_std = np.std(generate_red_noise(300, std, rho))
    print(f'{std=:.2f} - {rho=:.2f} - {output_std:.2f} - ({(std-output_std):.2f})')
# Out:
# std=0.10 - rho=0.10 - 0.10 - (0.00)
# std=0.10 - rho=0.20 - 0.10 - (0.00)
# std=0.10 - rho=0.30 - 0.10 - (-0.00)
# std=0.10 - rho=0.40 - 0.10 - (0.00)
# std=0.20 - rho=0.10 - 0.20 - (0.00)
# std=0.20 - rho=0.20 - 0.20 - (0.00)
# std=0.20 - rho=0.30 - 0.20 - (0.00)
# std=0.20 - rho=0.40 - 0.20 - (-0.00)
# std=0.30 - rho=0.10 - 0.30 - (0.00)
# std=0.30 - rho=0.20 - 0.30 - (0.00)
# std=0.30 - rho=0.30 - 0.30 - (0.00)
# std=0.30 - rho=0.40 - 0.30 - (0.00)
# std=0.40 - rho=0.10 - 0.40 - (0.00)
# std=0.40 - rho=0.20 - 0.40 - (0.00)
# std=0.40 - rho=0.30 - 0.40 - (-0.00)
# std=0.40 - rho=0.40 - 0.40 - (0.00)

# %%
def generate_base_noise(distribution, **kwargs):
    """
    Returns a pre-configured noise generation function with fixed parameters.

    Parameters:
    distribution (str): The distribution to slog in as the base noise source.
    **kwargs: Additional parameters required for each distribution.

    Returns:
    function: A function that generates noise samples when called.
    """

    if distribution == "normal": return partial(np.random.normal, **kwargs)
    elif distribution == "gamma": return partial(np.random.gamma, **kwargs)
    elif distribution == "lognormal": return partial(np.random.lognormal, **kwargs)
    elif distribution == "weibull": return partial(np.random.weibull, **kwargs)
    elif distribution == "exponential": return partial(np.random.exponential, **kwargs)
    elif distribution == "gumbel": return partial(np.random.gumbel, **kwargs)
    elif distribution == "poisson": return partial(np.random.poisson, **kwargs)
    else:
        raise ValueError(
            "Unsupported distribution type. Choose from: normal, gamma, lognormal, weibull, exponential, gumbel, poisson."
        )

# %%
def generate_noise_process(size, alpha, noise_func):
    """
    Generates an autocorrelated noise process (AR(1) process) using a given noise function.

    Parameters:
    size (int): Length of the generated noise sequence.
    alpha (float): Autoregressive parameter (0 gives uncorrelated noise).
    noise_func (function): Pre-configured function to generate noise samples.

    Returns:
    np.ndarray: Noise process sequence with the specified autocorrelation.
    """
    
    # Generate noise using the pre-configured function
    base_noise = noise_func(size)

    # Apply AR(1) filter to introduce autocorrelation
    noise_process = lfilter([1], [1, -alpha], base_noise)

    # Normalize the output to match the original standard deviation
    noise_process = noise_process / np.std(noise_process) * np.std(base_noise)

    return noise_process

# %%
# # Create a noise generator with specific parameters
# gamma_noise = generate_base_noise("gamma", shape=2, scale=0.5)
# lognormal_noise = generate_base_noise("lognormal", mean=0, sigma=0.3)

# # Use it in the AR(1) noise process
# gamma_series = generate_noise_process(size=1000, alpha=0.8, noise_func=gamma_noise)
# lognormal_series = generate_noise_process(size=1000, alpha=0.5, noise_func=lognormal_noise)

# %% [markdown]
# <h1 style='color:cyan'> Single Ensemble </h1>

# %%
np.random.seed(51)

# Generate time series
n = 150  # Number of time points
base_period = np.tile(0, 30)
grad = 1.2/130 # 1.2 degree change since 1850
trend_line = grad * np.arange(150)  # Linear trend

true_trend = np.concatenate([base_period, trend_line])
t = np.arange(len(true_trend))

# %%
base_noise = generate_red_noise(len(true_trend), 0.25, 0.3)
base_noise.shape, true_trend.shape
# Out:
# ((180,), (180,))

# %%
num_iterations = 4

# %%
# Generate iterations

# %%
# Define the iterations coordinate
iterations = np.arange(1, num_iterations + 1)

# Compute noisy signals (vectorized)
noisy_signals = true_trend + np.outer(iterations, base_noise)

# Convert to xarray DataArray
noisy_series_xr = xr.DataArray(
    noisy_signals,
    dims=( "noise_index","time"),  # Using 'noise_index' as requested
    coords={"noise_index": np.arange(num_iterations),  "time": t}
)

# %%
nrows = 2
ncols = 2
num_plot = nrows*ncols


fig = plt.figure(figsize=(6*nrows, 3.5*ncols))
gs = gridspec.GridSpec(nrows, ncols, hspace=0.3)
axes = [fig.add_subplot(gs[i]) for i in range(num_plot)]

time = noisy_series_xr.time.values

for i in np.arange(num_iterations):

    noisy_series = noisy_series_xr.sel(noise_index=i).values

    
    axes[i].plot(time, noisy_series, color='red', alpha=0.6)
    # axes[i].plot(t, true_trend, linestyle='dashed', color='black', label='True Trend')
    
    axes[i].set_title(f'Standard Deviation={np.std(noisy_series[:30]):.1f}')
    # axes[i].legend()
    axes[i].grid(True)

    axes[i].set_xlim(0, len(time))
    axes[i].set_ylim(-2.4, 5)
    
# axes[0].set_ylabel('Value')
for ax in axes:
    ax.set_xlabel('Time (years)')

# plt.tight_layout()

# %%
signal_df = xr.apply_ufunc(
    my_stats.apply_lowess,
    noisy_series_xr,
    input_core_dims=[['time']],
    output_core_dims=[['time']],
    vectorize=True
)

# %%
signal_df.plot(hue='noise_index');

# %%
noise_df = noisy_series_xr.isel(time=slice(0,30)).std(dim='time')
noise_df
# Out:
# <xarray.DataArray (noise_index: 4)> Size: 32B
# 0.2637 0.5273 0.791 1.055
# Coordinates:
#   * noise_index  (noise_index) int64 32B 0 1 2 3

# %%
sn_df = signal_df/noise_df

# %%
sn_df.plot(hue='noise_index');

# %% [markdown]
# <h1 style='color:cyan'> Variable Definitions </h1>

# %%
def generate_noise_ensemble(std: float, rho: float, num_trials: int = 200, 
                            atol: float = None, rtol: float = None, length: int = 100, 
                            batch_size: int = 100):
    """
    Generate an ensemble of red noise series with a specified standard deviation in parallel batches.

    Parameters:
    - std: Target standard deviation of the noise series.
    - rho: Autoregressive coefficient for red noise.
    - num_trials: Number of noise series to generate.
    - atol: Absolute tolerance for matching the desired standard deviation.
    - rtol: Relative tolerance for matching the desired standard deviation.
    - length: Length of each noise series.
    - batch_size: Number of noise series processed in a single batch.

    Returns:
    - A NumPy array containing the noise ensemble.
    """

    if atol is None and rtol is None:
        atol = 0.05 * std
    elif rtol is not None:
        atol = rtol * std

    print(f'\n{std=} - {rho=} - {length=} - {atol=}\n')

    @delayed
    def generate_batch():
        """ Generate a batch of red noise and filter valid samples. """
        samples = np.array([generate_red_noise(length, std, rho) for _ in range(batch_size)])
        stds = np.std(samples, axis=1)
        valid_samples = samples[(stds > (std - atol)) & (stds < (std + atol))]
        print(f'len - {len(valid_samples)}')
        return valid_samples

    collected_samples = []
    to_compute = []

    
    batch_num = 0  # Track batch number
    while len(collected_samples) < num_trials:
        batch_num += 1
        print(f"{batch_num} ({len(collected_samples)}), ", end='')  # Print batch number
    
        batch = generate_batch()  # Create delayed task
        valid_samples = compute(batch)[0]  # Compute after each batch
        
        collected_samples.extend(valid_samples)

        # # Stop if we have enough samples
        # if len(collected_samples) >= num_trials:
        #     break

    # Trim to exactly `num_trials`
    noise_series_arr = np.array(collected_samples[:num_trials])

    # Convert to xarray
    noise_bs_xr = xr.DataArray(
        noise_series_arr,
        dims=("iteration", "time"),
        coords={"iteration": np.arange(num_trials), "time": np.arange(length),
               'rho': rho, 'std': std}
    ).chunk({'iteration':'auto', 'time':-1})


    return noise_bs_xr

# %%
base_period_length = 30
window = 30

# %%
base_period = np.tile(0, base_period_length)
# grad = 1.2/140 # 1.2 degree change since 1850
grad = 0.6/140 # 1.2 degree change since 1850

trend_line = grad * np.arange(470)  # Linear trend

true_trend = np.concatenate([base_period, trend_line])
true_trend.shape
# Out:
# (500,)

# %%
kde_kwargs= dict(bw_method=0.2) # silverman, scott#bw_method=0.2)

# %%
x = np.linspace(0, true_trend.shape[0], 2000)

# %%
plt.plot(true_trend)

# %%
kde_create_kwargs = dict(
    input_core_dims=[['iteration']],
    output_core_dims=[['x']],
    kwargs={'x': x, **kde_kwargs},
    vectorize=True,
    dask='parallelized',
    output_sizes={'x':len(x)},  # Specify the size of the 'bin' dimension
    output_dtypes=[float]
)

# %%
SAVE_DIR = '/g/data/w40/ab2313/time_of_emergence/synthetic_data'

# %% [markdown]
# <h1 style='color:cyan'> Variance and auto-correlation </h1>

# %% [markdown]
# <h2 style='color:yellow'> Generating Data </h2>

# %%
std_values = [0.1, 0.25, 0.5, 0.75, 1]
(6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),
# std=1 - rho=0.75 - length=500 - atol=0.2
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),

# %%
true_trend.shape
# Out:
# (500,)

# %%
noise_ensemble_da
# Out:
# <xarray.DataArray (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# dask.array<chunksize=(1, 1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0

# %%
trend_bs_xr = noise_ensemble_da + true_trend

# %%
trend_bs_xr
# Out:
# <xarray.DataArray (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# dask.array<chunksize=(1, 1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0

# %%
fig, axes = plt.subplots(2, 2)
axes = axes.ravel()

trend_bs_xr.sel(std=0.1, rho=0).plot(ax=axes[0], hue='iteration', add_legend=False);
trend_bs_xr.sel(std=0.1, rho=0.75).plot(ax=axes[1], hue='iteration', add_legend=False);
trend_bs_xr.sel(std=1, rho=0).plot(ax=axes[2], hue='iteration', add_legend=False);
trend_bs_xr.sel(std=1, rho=0.75).plot(ax=axes[3], hue='iteration', add_legend=False);

plt.tight_layout()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 38.15 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %% [markdown]
# <h2 style='color:yellow'> ToE Calclulation </h2>

# %%
data_ds_window = (trend_bs_xr
                  .rolling(time=window, center=True, min_periods=window)
                  .construct('window_dim')
                  # .chunk({'window_dim':-1,**CHUNKS_FOR_PVALUE_TESTS})
                  .persist()
                 ) 

base_period_window_ds = (trend_bs_xr.sel(time=slice(0, base_period_length))
                         # .chunk(CHUNKS_FOR_PVALUE_TESTS)
                         .rename({'time':'window_dim'})
                         .persist()
                        )
wait(data_ds_window);
wait(base_period_window_ds);
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 763.01 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.95 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
trend_bs_xr
# Out:
# <xarray.DataArray (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# dask.array<chunksize=(1, 1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0

# %% [markdown]
# ### KS and Overlap

# %%
# # The arguements needed for all of the calculations
# rolling_window_kwargs = dict(
#     input_core_dims=[['window_dim'], ['window_dim']],
#     exclude_dims={'window_dim'},
#     vectorize=True,
#     dask='parallelized')

# %%
# %%time
# # Expected 3 minutes 30 seconds - best
# # 6 23 - era5
# ks_ds = xr.apply_ufunc(
#         toe_calc.return_ks_pvalue,
#         data_ds_window,
#         base_period_window_ds,
#     **rolling_window_kwargs
#     ).compute()

# %%
# %%time
ks_ds = toe_calc_variations.ks(data_ds_window, base_period_window_ds)

# %%
# import toe_calc_variations

# %%
ks_ds.sel(rho=0.25, std=0.25).plot(hue='iteration', add_legend=False);

# %%
# %%time
fga_ds = toe_calc_variations.fga(
    trend_bs_xr, trend_bs_xr.isel(time=slice(0, base_period_length)), data_ds_window).compute()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.95 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.95 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.96 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
fga_ds
# Out:
# <xarray.DataArray 'frac' (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# 81.89 83.64 90.0 88.37 88.43 ... 0.0109 0.00677 1.947e-12 2.821e-25 2.827e-26
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0
# Attributes:
#     bw_method:   0.2
#     bmin:        -4.91480215867236
#     bmax:        8.865021559479432
#     num_points:  1000

# %% [markdown]
# ### S/N Ratio

# %%
trend_anom_bs_xr = trend_bs_xr - trend_bs_xr.isel(time=slice(0, base_period_length)).mean(dim='time')

# %%
signal_bs_xr = xr.apply_ufunc(
    my_stats.apply_lowess,
    trend_anom_bs_xr,
    input_core_dims=[['time']],
    output_core_dims=[['time']],
    vectorize=True,
    dask='parallelized',
    output_dtypes=[float]
).compute()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 762.96 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
noise_bs_xr = trend_bs_xr.isel(time=slice(0, base_period_length)).std(dim='time')

# %%
sn_bs_xr = signal_bs_xr/noise_bs_xr

# %%
fig, axes = plt.subplots(2, 2)
axes = axes.ravel()

sn_bs_xr.sel(std=0.1, rho=0).plot(ax=axes[0], hue='iteration', add_legend=False);
sn_bs_xr.sel(std=0.1, rho=0.75).plot(ax=axes[1], hue='iteration', add_legend=False);
sn_bs_xr.sel(std=1, rho=0).plot(ax=axes[2], hue='iteration', add_legend=False);
sn_bs_xr.sel(std=1, rho=0.75).plot(ax=axes[3], hue='iteration', add_legend=False);

plt.tight_layout()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 801.09 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %% [markdown]
# <h2 style='color:yellow'> Saving and Opening Data </h2>

# %%
# sn_bs_xr.to_zarr(os.path.join(SAVE_DIR, 'sn_rho_std.zarr'), mode='w')

# ks_ds.to_zarr(os.path.join(SAVE_DIR, 'ks_rho_std.zarr'), mode='w')

# fga_ds.to_zarr(os.path.join(SAVE_DIR, 'fga_rho_std.zarr'), mode='w')

# %%
# trend_bs_xr.to_zarr(os.path.join(SAVE_DIR, 'trend_rho_std.zarr'), mode='w')
trend_bs_xr = xr.open_dataset(os.path.join(SAVE_DIR, 'trend_rho_std.zarr'))
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'h5netcdf' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)

# %%
chunks = {'time':-1, 'iteration':200}

# %%
sn_bs_xr = (xr.open_zarr(os.path.join(SAVE_DIR, 'sn_rho_std.zarr'))
            .chunk(**chunks)
            .to_array()
            .squeeze().drop_vars('variable')
            )
sn_bs_xr.name = 'sn'
ks_ds = xr.open_zarr(os.path.join(SAVE_DIR, 'ks_rho_std.zarr')).ks.chunk(**chunks)
fga_ds = xr.open_zarr(os.path.join(SAVE_DIR, 'fga_rho_std.zarr')).frac.chunk(**chunks)

# %%
ks_ds
# Out:
# <xarray.DataArray 'ks' (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# dask.array<chunksize=(1, 1, 200, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499

# %%
sn_bs_xr
# Out:
# <xarray.DataArray 'sn' (std: 5, rho: 4, iteration: 10000, time: 500)> Size: 800MB
# dask.array<chunksize=(1, 1, 200, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * rho        (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std        (std) float64 40B 0.1 0.25 0.5 0.75 1.0
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499

# %% [markdown]
# <h2 style='color:yellow'> ToE </h2>

# %%
sn_toe_bs_xr = toe_calc.get_permanent_exceedance(
            sn_bs_xr, threshold=1, comparison_func=np.greater,
    time=sn_bs_xr.time.values)

# %%
ks_toe_bs_xr = toe_calc.get_permanent_exceedance(
            ks_ds, threshold=0.01, comparison_func=np.less, time=sn_bs_xr.time.values)

# %%
fga_toe_bs_xr = toe_calc.get_permanent_exceedance(
            fga_ds, threshold=62, comparison_func=np.less, time=sn_bs_xr.time.values)

# %%
sn_toe_bs_xr.sel(std=1, rho=0.75).plot()

# %%
# %%time
sn_toe_bs_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    sn_toe_bs_xr,
    dask_gufunc_kwargs={'allow_rechunk':True},
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# CPU times: user 2.28 s, sys: 461 ms, total: 2.74 s
# Wall time: 2.86 s

# %%
# %%time
ks_toe_bs_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    ks_toe_bs_xr,
    dask_gufunc_kwargs={'allow_rechunk':True},
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# CPU times: user 3.87 s, sys: 688 ms, total: 4.56 s
# Wall time: 4.63 s

# %%
# %%time
fga_toe_bs_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    fga_toe_bs_xr,
    dask_gufunc_kwargs={'allow_rechunk':True},
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# CPU times: user 4 s, sys: 687 ms, total: 4.69 s
# Wall time: 4.78 s

# %%
ks_toe_bs_kde_xr['x'] = x
sn_toe_bs_kde_xr['x'] = x
fga_toe_bs_kde_xr['x'] = x

# %%
sn_toe_bs_xr = sn_toe_bs_xr.compute()
ks_toe_bs_xr = ks_toe_bs_xr.compute()
fga_toe_bs_xr = fga_toe_bs_xr.compute()

# %% [markdown]
# <h2 style='color:yellow'> Plotting </h2>

# %%
sn_toe_bs_xr.median(dim='iteration').plot()

# %%
from matplotlib.ticker import MaxNLocator

# %%
fga_toe_bs_xr.std(dim='iteration').to_pandas().round(0)
# Out:
# rho   0.00  0.25  0.50  0.75
# std
# 0.10   4.0   4.0   5.0   7.0
# 0.25   9.0  10.0  13.0  17.0
# 0.50  17.0  21.0  25.0  34.0
# 0.75  25.0  30.0  38.0  51.0
# 1.00  33.0  39.0  49.0  67.0

# %%
fga_toe_bs_xr.mean(dim='iteration').to_pandas().round(0)
# Out:
# rho    0.00   0.25   0.50   0.75
# std
# 0.10   42.0   42.0   41.0   40.0
# 0.25   57.0   57.0   57.0   55.0
# 0.50   86.0   86.0   86.0   86.0
# 0.75  116.0  117.0  119.0  121.0
# 1.00  147.0  151.0  154.0  159.0

# %%
def plot_toe_bs_kde(toe_bs_kde_xr, toe_bs_xr, colors=None, fig=None, axs=None,
                    add_legend=True, ylabel=True):
    """
    Plots Time of Emergence (ToE) bootstrapped KDE distributions for different std values, with vertical median lines.
    
    Parameters:
    - toe_bs_kde_xr: xarray.Dataset containing KDE distributions for ToE
    - toe_bs_xr: xarray.Dataset containing raw ToE values for computing medians
    - x: numpy array of x-axis values
    - fig: Optional matplotlib figure
    - axs: Optional list of matplotlib axes
    
    Returns:
    - fig, axs: Matplotlib figure and axes
    """
    # Get unique values for rho and std
    rho_values = toe_bs_kde_xr['rho'].values
    std_values = toe_bs_kde_xr['std'].values
    x = toe_bs_kde_xr.x.values
    
    # Assign a unique color to each rho for consistency across plots
    if colors is None: colors = plt.cm.viridis(np.linspace(0, 1, len(rho_values)))
    
    # Create figure and gridspec if not provided
    if fig is None or axs is None:
        fig = plt.figure(figsize=(6, len(std_values) * 1.5))
        gs = gridspec.GridSpec(len(std_values), 1, figure=fig, hspace=0)
        axs = [fig.add_subplot(gs[i, 0]) for i in range(len(std_values))]
    
    # Loop through std (rows)
    for i, (ax, std) in enumerate(zip(axs, std_values)):
        # Plot all rho values on the same subplot, using consistent colors
        for color, rho in zip(colors, rho_values):
            data = toe_bs_kde_xr.sel(std=std, rho=rho)
            ax.plot(x, data, color=color, label=f'{rho:.2f}')
            
            # Compute and plot the median vertical line
            median_x = np.nanmedian(toe_bs_xr.sel(std=std, rho=rho).values)
            median_y = data.values[np.argmin(np.abs(x - median_x))]
            ax.plot([median_x, median_x], [0, median_y], linestyle="dashed",
                    color=color, alpha=0.7)

        
        ax.yaxis.set_major_locator(MaxNLocator(nbins=5, min_n_ticks=4, prune=None))
        ax.set_xlim(0, 350)
        if i == 0 and add_legend: 
            leg = ax.legend(loc='upper right', ncol=2, fontsize=12, frameon=False)
            leg.set_title('Lag-1 Auto-correlation')
            leg.get_title().set_fontsize(12)
        if 0 < i < len(std_values) - 1:
            # ax.spines['bottom'].set_visible(False)
            ax.set_xticklabels([])
        if i == len(std_values) - 1:
            ax.set_xlabel('Time of Emergence (ToE)') 
        if i == 0:
            ax.xaxis.tick_top()
            ax.xaxis.set_label_position('top')
        if ylabel: ax.set_ylabel(fr'$\sigma={std}$', fontsize=12)  
        ax.grid(True, linestyle='--', alpha=0.25, color='grey')
    
    return fig, axs

# %%
colors = plt.cm.viridis_r(np.linspace(0, 1, sn_toe_bs_kde_xr['rho'].values.shape[0]))

# %%
from toe_plots import METRIC_MAP

# %%
std_values = sn_toe_bs_kde_xr['std'].values

# %%
# Create figure and gridspec (multiple rows, 1 column)
fig = plt.figure(figsize=(14, len(std_values) * 1.5))
gs = gridspec.GridSpec(len(ks_toe_bs_kde_xr['std'].values), 3, figure=fig, hspace=0.13)
axes_left = [fig.add_subplot(gs[i, 0]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]
axes_middle = [fig.add_subplot(gs[i, 1]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]
axes_right = [fig.add_subplot(gs[i, 2]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]


plot_toe_bs_kde(sn_toe_bs_kde_xr, sn_toe_bs_xr, fig=fig, axs=axes_left, colors=colors);
plot_toe_bs_kde(ks_toe_bs_kde_xr, ks_toe_bs_xr, fig=fig, axs=axes_middle, colors=colors, ylabel=False, add_legend=False);
plot_toe_bs_kde(fga_toe_bs_kde_xr, fga_toe_bs_xr, fig=fig, axs=axes_right, colors=colors, ylabel=False, add_legend=False);


axes_left[0].set_title(METRIC_MAP['sn'], fontsize=15)
axes_middle[0].set_title(METRIC_MAP['ks'].replace('\n', ' '), fontsize=15)
axes_right[0].set_title(METRIC_MAP['frac'].replace('\n', ' '), fontsize=15)


for axes in [axes_left, axes_middle, axes_right]:
    for i,ax in enumerate(axes):
        if i == 0: ax.set_ylim(0, 0.16)
        if i == 1:ax.set_ylim(0, 0.05)
        if i == 2: ax.set_ylim(0, 0.025)
        if i==3: ax.set_ylim(0, 0.02)

# %%
sn_toe_bs_kde_xr
# Out:
# <xarray.DataArray 'sn' (std: 5, rho: 4, x: 2000)> Size: 320kB
# 0.0 9.881e-324 3.466e-318 1.648e-312 ... 4.624e-11 4.24e-11 3.887e-11 3.562e-11
# Coordinates:
#   * rho      (rho) float64 32B 0.0 0.25 0.5 0.75
#   * std      (std) float64 40B 0.1 0.25 0.5 0.75 1.0
#   * x        (x) float64 16kB 0.0 0.2501 0.5003 0.7504 ... 499.5 499.7 500.0

# %%
# Create figure and gridspec (multiple rows, 1 column)
fig = plt.figure(figsize=(10, len(std_values) * 1.5))
gs = gridspec.GridSpec(len(ks_toe_bs_kde_xr['std'].values), 2, figure=fig, hspace=0)
axes_left = [fig.add_subplot(gs[i, 0]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]
axes_right = [fig.add_subplot(gs[i, 1]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]


plot_toe_bs_kde(sn_toe_bs_kde_xr, sn_toe_bs_xr, fig=fig, axs=axes_left, colors=colors);
plot_toe_bs_kde(ks_toe_bs_kde_xr, ks_toe_bs_xr, fig=fig, axs=axes_right, colors=colors);

# %% [markdown]
# <h1 style='color:cyan'> Non-stationary Variance </h1>

# %% [markdown]
# <h2 style='color:yellow'> Generating Data </h2>

# %%
attempt_no = 2

# %%
reload(toe_calc_variations)
# Out:
# <module 'toe_calc_variations' from '/home/563/ab2313/Documents/time_of_emergene_drafts/src/toe_calc_variations.py'>

# %%
true_trend.shape
# Out:
# (500,)

# %%
base_noise_xr = generate_noise_ensemble(
            1, 0, length=true_trend.shape[0],
            rtol=0.2, num_trials=10000)
# Out:
# std=1 - rho=0 - length=500 - atol=0.2
#
# 1 (0), 2 (100), 3 (200), 4 (300), 5 (400), 6 (500), 7 (600), 8 (700), 9 (800), 10 (900), 11 (1000), 12 (1100), 13 (1200), 14 (1300), 15 (1400), 16 (1500), 17 (1600), 18 (1700), 19 (1800), 20 (1900), 21 (2000), 22 (2100), 23 (2200), 24 (2300), 25 (2400), 26 (2500), 27 (2600), 28 (2700), 29 (2800), 30 (2900), 31 (3000), 32 (3100), 33 (3200), 34 (3300), 35 (3400), 36 (3500), 37 (3600), 38 (3700), 39 (3800), 40 (3900), 41 (4000), 42 (4100), 43 (4200), 44 (4300), 45 (4400), 46 (4500), 47 (4600), 48 (4700), 49 (4800), 50 (4900), 51 (5000), 52 (5100), 53 (5200), 54 (5300), 55 (5400), 56 (5500), 57 (5600), 58 (5700), 59 (5800), 60 (5900), 61 (6000), 62 (6100), 63 (6200), 64 (6300), 65 (6400), 66 (6500), 67 (6600), 68 (6700), 69 (6800), 70 (6900), 71 (7000), 72 (7100), 73 (7200), 74 (7300), 75 (7400), 76 (7500), 77 (7600), 78 (7700), 79 (7800), 80 (7900), 81 (8000), 82 (8100), 83 (8200), 84 (8300), 85 (8400), 86 (8500), 87 (8600), 88 (8700), 89 (8800), 90 (8900), 91 (9000), 92 (9100), 93 (9200), 94 (9300), 95 (9400), 96 (9500), 97 (9600), 98 (9700), 99 (9800), 100 (9900),

# %%
non_stationary_noise
# Out:
# <function __main__.non_stationary_noise(arr: numpy.ndarray, start_std: float, end_std: float, window: int) -> numpy.ndarray>

# %%
non_stat_noise_kwargs = dict(
    input_core_dims=[['time']],
    output_core_dims = [['time']],
    vectorize=True,
    dask = 'parallelized',
    output_dtypes=[float]
)

# %%
base_noise_0p1t1p0_xr = xr.apply_ufunc(
    non_stationary_noise, 
    base_noise_xr,
    kwargs = dict(start_std=0.1, end_std=1, window=30),
    **non_stat_noise_kwargs
).persist()
wait(base_noise_0p1t1p0_xr);
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 38.15 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
base_noise_0p1t0p5_xr = xr.apply_ufunc(
    non_stationary_noise, 
    base_noise_xr,
    kwargs = dict(start_std=0.1, end_std=0.5, window=30),
    **non_stat_noise_kwargs
).persist()
wait(base_noise_0p1t0p5_xr);
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 38.15 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
base_noise_0p5t1p0_xr = xr.apply_ufunc(
    non_stationary_noise, 
    base_noise_xr,
    kwargs = dict(start_std=0.5, end_std=1, window=30),
    **non_stat_noise_kwargs
).persist()
wait(base_noise_0p5t1p0_xr);
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 38.15 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
def revers_time_values(ds):
    ds2 = ds.copy(deep=True)
    ds2.data = ds2.data[..., ::-1]
    return ds2

# %%
# Reverse nosie for trends with decreasing noise
base_noise_1p0t0p1_xr = revers_time_values(base_noise_0p1t1p0_xr)
base_noise_1p0t0p5_xr = revers_time_values(base_noise_0p5t1p0_xr)
base_noise_0p5t0p1_xr = revers_time_values(base_noise_0p1t0p5_xr)

# %%
plt.plot(true_trend)
plt.plot(true_trend/2)

# %%
# Increading trends
# Divide true trend by 2 as ToE is too early
trend_0p1t1p0_xr = base_noise_0p1t1p0_xr + true_trend#/2
trend_0p5t1p0_xr = base_noise_0p5t1p0_xr + true_trend#/2
trend_0p1t0p5_xr = base_noise_0p1t0p5_xr + true_trend#/2

# %%
# Decrsing trends
trend_1p0t0p1_xr = base_noise_1p0t0p1_xr + true_trend
trend_1p0t0p5_xr = base_noise_1p0t0p5_xr + true_trend
trend_0p5t0p1_xr = base_noise_0p5t0p1_xr + true_trend

# %%
trend_0p1t1p0_xr['std'] = '0p1t1p0'
trend_0p5t1p0_xr['std'] = '0p5t1p0'
trend_0p1t0p5_xr['std'] = '0p1t0p5'
trend_1p0t0p1_xr['std'] = '1p0t0p1'
trend_1p0t0p5_xr['std'] = '1p0t0p5'
trend_0p5t0p1_xr['std'] = '0p5t0p1'

# %%
trend_non_stat_xr = xr.concat(
    [trend_0p1t1p0_xr, trend_0p5t1p0_xr, trend_0p1t0p5_xr,
     trend_1p0t0p1_xr, trend_1p0t0p5_xr, trend_0p5t0p1_xr], dim='std')

# %%
trend_non_stat_xr
# Out:
# <xarray.DataArray (std: 6, iteration: 10000, time: 500)> Size: 240MB
# dask.array<chunksize=(1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#     rho        int64 8B 0
#   * std        (std) <U7 168B '0p1t1p0' '0p5t1p0' ... '1p0t0p5' '0p5t0p1'

# %%
trend_non_stat_xr.isel(iteration=1).plot(hue='std');

# %% [markdown]
# <h2 style='color:yellow'> ToE Calculation </h2>

# %%
data_ds_window_non_stat = (trend_non_stat_xr
                  .rolling(time=window, center=True, min_periods=window)
                  .construct('window_dim')
                  # .chunk({'window_dim':-1,**CHUNKS_FOR_PVALUE_TESTS})
                  .persist()
                 ) 

base_period_window_ds_non_stat = (trend_non_stat_xr.sel(time=slice(0, base_period_length))
                         # .chunk(CHUNKS_FOR_PVALUE_TESTS)
                         .rename({'time':'window_dim'})
                         .persist()
                        )
wait(data_ds_window_non_stat);
wait(base_period_window_ds_non_stat);

# %%
# %%time
ks_non_stat_ds = toe_calc_variations.ks(data_ds_window_non_stat.isel(iteration=slice(0,100)),
                                        base_period_window_ds_non_stat.isel(iteration=slice(0,100)))

# %%
trend_non_stat_xr
# Out:
# <xarray.DataArray (std: 6, iteration: 10000, time: 500)> Size: 240MB
# dask.array<chunksize=(1, 10000, 500), meta=np.ndarray>
# Coordinates:
#   * iteration  (iteration) int64 80kB 0 1 2 3 4 5 ... 9995 9996 9997 9998 9999
#   * time       (time) int64 4kB 0 1 2 3 4 5 6 7 ... 493 494 495 496 497 498 499
#     rho        int64 8B 0
#   * std        (std) <U7 168B '0p1t1p0' '0p5t1p0' ... '1p0t0p5' '0p5t0p1'

# %%
fga_non_stat_ds = toe_calc_variations.fga(
    trend_non_stat_xr,#.isel(iteration=slice(0,100)),
    trend_non_stat_xr.isel(time=slice(0, base_period_length)),#.isel(iteration=slice(0,100)),
    data_ds_window_non_stat#.isel(iteration=slice(0,100))
).compute()

# %%
reload(toe_calc_variations)
# Out:
# <module 'toe_calc_variations' from '/home/563/ab2313/Documents/time_of_emergene_drafts/src/toe_calc_variations.py'>

# %%
# %%time
sn_non_stat_xr = toe_calc_variations.sn_ratio(
    trend_non_stat_xr,#.isel(iteration=slice(0,100)),
    start=0, end=30)
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 228.90 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
sn_non_stat_xr
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:         (iteration: 10000, time: 500, std: 6)
# Coordinates:
#   * iteration       (iteration) int64 80kB 0 1 2 3 4 ... 9996 9997 9998 9999
#   * time            (time) int64 4kB 0 1 2 3 4 5 6 ... 494 495 496 497 498 499
#     rho             int64 8B 0
#   * std             (std) <U7 168B '0p1t1p0' '0p5t1p0' ... '1p0t0p5' '0p5t0p1'
# Data variables:
#     sn              (std, iteration, time) float64 240MB 0.3106 0.292 ... 7.731
#     sn_lowess_full  (std, iteration, time) float64 240MB 0.06535 ... 12.1
#     sn_roll         (std, iteration, time) float64 240MB nan nan nan ... nan nan
#     noise           (std, iteration, time) float64 240MB -0.04482 ... 0.01647
#     signal          (std, iteration, time) float64 240MB 0.0389 ... 3.846

# %%
sn_non_stat_xr.signal.sel(std=['0p1t1p0', '1p0t0p1']).isel(iteration=0).plot(hue='std');

# %%
sn_non_stat_xr.sn.sel(std=['0p1t1p0', '1p0t0p1']).isel(iteration=0).plot(hue='std');

# %% [markdown]
# <h2 style='color:yellow'>  Saving and Opening Data </h2>

# %%
# base_noise_xr.to_zarr(os.path.join(SAVE_DIR, 'base_noise_non_stat_var.zarr'), mode='w')
# trend_non_stat_xr.to_zarr(os.path.join(SAVE_DIR, 'trend_non_stat_var.zarr'), mode='w')
# sn_non_stat_xr.to_zarr(os.path.join(SAVE_DIR, 'sn_non_stat_var.zarr'), mode='w')
# ks_non_stat_ds.to_zarr(os.path.join(SAVE_DIR, 'ks_non_stat_var.zarr'), mode='w')
# fga_non_stat_ds.to_zarr(os.path.join(SAVE_DIR, 'ga_non_stat_var.zarr'), mode='w')

# %%
chunks = {'time':-1, 'iteration':200}

# %%
base_noise_xr = xr.open_zarr(os.path.join(SAVE_DIR, 'base_noise_non_stat_var.zarr')).to_array().chunk(**chunks)
trend_non_stat_xr = xr.open_zarr(os.path.join(SAVE_DIR, 'trend_non_stat_var.zarr')).chunk(**chunks)
sn_non_stat_xr = xr.open_zarr(os.path.join(SAVE_DIR, 'sn_non_stat_var.zarr')).chunk(**chunks)
ks_non_stat_ds = xr.open_zarr(os.path.join(SAVE_DIR, 'ks_non_stat_var.zarr')).chunk(**chunks)
fga_non_stat_ds = xr.open_zarr(os.path.join(SAVE_DIR, 'ga_non_stat_var.zarr')).chunk(**chunks)

# %%
# %%time
ks_toe_non_stat_xr = toe_calc.get_permanent_exceedance(
            ks_non_stat_ds, threshold=0.01, comparison_func=np.less, time=ks_non_stat_ds.time.values).compute()
# Out:
# CPU times: user 1.64 s, sys: 753 ms, total: 2.39 s
# Wall time: 3.67 s

# %%
# %%time
sn_toe_non_stat_xr = toe_calc.get_permanent_exceedance(
    sn_non_stat_xr[['sn', 'sn_lowess_full', 'sn_roll']],
    threshold=1, comparison_func=np.greater,
    time=sn_non_stat_xr.time.values.astype(int), trim_nan=True).compute()
# Out:
# CPU times: user 9.66 s, sys: 3.91 s, total: 13.6 s
# Wall time: 17.2 s

# %%
fga_toe_non_stat_xr = toe_calc.get_permanent_exceedance(
            fga_non_stat_ds, threshold=62, comparison_func=np.less, time=fga_non_stat_ds.time.values).compute()

# %%
# %%time
ks_toe_non_stat_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    ks_toe_non_stat_xr,
    **kde_create_kwargs
).compute();
# Out:
# CPU times: user 95.4 ms, sys: 9.38 ms, total: 105 ms
# Wall time: 63.5 ms
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.

# %%
# %%time
sn_toe_non_stat_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    sn_toe_non_stat_xr,
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# CPU times: user 5.34 s, sys: 806 ms, total: 6.15 s
# Wall time: 3.76 s

# %%
# %%time
fga_toe_non_stat_kde_xr = xr.apply_ufunc(
    toe_calc.create_kde_x_exists,
    fga_toe_non_stat_xr,
    **kde_create_kwargs
).compute();
# Out:
# <timed exec>:1: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
# CPU times: user 1.75 s, sys: 262 ms, total: 2.02 s
# Wall time: 1.23 s

# %%
ks_toe_non_stat_kde_xr['x'] = x
fga_toe_non_stat_kde_xr['x'] = x
sn_toe_non_stat_kde_xr['x'] = x

# %% [markdown]
# <h2 style='color:yellow'> Plots </h2>

# %%
def plot_toe_bs_kde_custom(
    kde_xr, toe_xr,
    colors=None, fig=None, gs=None, axs=None, add_legend=True, legend_loc='upper right',
    fontscale=1, bbox_to_anchor=None):
    """
    Plots Time of Emergence (ToE) KDE distributions for different datasets (KS and FGA) as variables within a merged dataset,
    with distinct colors for each dataset and different std values with distinct linestyles.

    Parameters:
    - kde_xr: xarray.Dataset containing KDE distributions with 'KS' and 'FGA' as variables
    - std_values: List of std values to plot
    - colors: Optional color list for datasets
    - fig: Optional matplotlib figure
    - axs: Optional list of matplotlib axes
    
    Returns:
    - fig, axs: Matplotlib figure and axes
    """
    x = kde_xr.x.values  # Assuming all datasets share the same x values
    std_values = kde_xr['std'].values
    toe_metrics = list(kde_xr)
    
    nrows = int(np.ceil(len(std_values)/2))
    # Create figure and gridspec if not provided
    if fig is None: fig = plt.figure(figsize=(15, 3.33*nrows))
    if gs is None: gs = gridspec.GridSpec(nrows, 2, figure=fig, hspace=0.1)

    if axs is None:
        axs = []
        for j in range(2):  # Since you have 2 columns
            for i in range(nrows):
                axs.append(fig.add_subplot(gs[i, j]))
    
    for i, std in enumerate(std_values):
        ax = axs[i]
        for toe_met in toe_metrics:
            style = toe_plots.TEST_STYLES.get(toe_met, {'color':'black', 'linestyle':'sold'})
            data = kde_xr[toe_met].sel(std=std)
            label= toe_plots.METRIC_MAP.get(toe_met, toe_met).replace('\n', ' ').replace(' (', '\n(')
            if 'Smirnov' in label: label = label.replace('Smirnov', '\nSmirnov')
            ax.plot(x, data, label=label, linewidth=1.5*fontscale, **style)
            median_x = np.nanmedian(toe_xr[toe_met].sel(std=std).values)
            median_y = data.values[np.argmin(np.abs(x - median_x))]
            # ax.plot([median_x, median_x], [0, median_y], **style)
        ax.set_xlim(0, 350)
        ax.grid(True, linestyle="--", alpha=0.25, color="grey")
        ax.set_ylabel(r'$\sigma=$' + std.replace('p', '.').replace('t', ' to '),
                      fontsize=12*fontscale)
        ax.tick_params(axis='x', labelsize=10*fontscale)
        ax.tick_params(axis='y', labelsize=10*fontscale)

    
    if add_legend:
        legend = axs[0].legend(loc=legend_loc, fontsize=10*fontscale,
                               bbox_to_anchor=bbox_to_anchor)

    axs[nrows].set_title('Increasing Variability over Time', fontsize=12*fontscale, pad=60)
    axs[0].set_title('Decreasing Variability over Time', fontsize=12*fontscale, pad=60)

    return fig, axs

# %%
def __format_multi_axes(axes):

    for i, ax in enumerate(axes):
        if i in [0, 3]:
            ax.xaxis.tick_top()
            ax.xaxis.set_label_position("top")
            ax.set_xlabel("Time of Emergence (ToE)", fontsize=14)
        elif i in [2, 5]:
            ax.set_xlabel("Time of Emergence (ToE)", fontsize=14)

        if i in [1, 4]:
            ax.set_xticklabels([])
        else:
            ax.tick_params(axis='x', labelsize=12)

# %%
toe_non_stat_kde_xr = xr.merge([sn_toe_non_stat_kde_xr, ks_toe_non_stat_kde_xr, fga_toe_non_stat_kde_xr])

# %%
toe_non_stat_xr = xr.merge([sn_toe_non_stat_xr, ks_toe_non_stat_xr, fga_toe_non_stat_xr])

# %%
non_stat_tests = list(toe_non_stat_kde_xr)
non_stat_tests
# Out:
# ['sn', 'sn_lowess_full', 'sn_roll', 'ks', 'frac']

# %%
std_order = ['0p1t0p5', '0p5t1p0', '0p1t1p0', '0p5t0p1', '1p0t0p5', '1p0t0p1']

# %%
fig, axs = plot_toe_bs_kde_custom(toe_non_stat_kde_xr.sel(std=std_order), toe_non_stat_xr,
                                 fontscale=1.5)
__format_multi_axes(axs)

# %% [markdown]
# <h1 style='color:cyan'> Combing Mean and Variances Changes </h1>

# %%
# linewidths = np.linspace(3, 0.2, 5+1)
# alphas = np.linspace(0.4, 1, 4)

# %%
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

# %%
def plot_toe_bs_kde_v2(toe_bs_kde_xr, toe_bs_xr, colors=None, fig=None, ax=None,
                    add_legend=True, ylabel=True, color_list='k', linestyle='solid',
                      xlabel=True):
    """
    Plots Time of Emergence (ToE) bootstrapped KDE distributions for different std values, with vertical median lines.
    
    Parameters:
    - toe_bs_kde_xr: xarray.Dataset containing KDE distributions for ToE
    - toe_bs_xr: xarray.Dataset containing raw ToE values for computing medians
    - x: numpy array of x-axis values
    - fig: Optional matplotlib figure
    - axs: Optional list of matplotlib axes
    
    Returns:
    - fig, axs: Matplotlib figure and axes
    """
    # Get unique values for rho and std
    rho_values = toe_bs_kde_xr['rho'].values
    std_values = toe_bs_kde_xr['std'].values
    x = toe_bs_kde_xr.x.values
    
    
    # Create figure and gridspec if not provided
    if fig is None or axs is None:
        fig = plt.figure(figsize=(6, len(std_values) * 1.5))
        ax = fig.add_subplot(111)

    linewidths = np.linspace(3, 0.2, len(rho_values)+1)
    alphas = np.linspace(0.4, 1, len(rho_values))
    # Loop through std (rows)
    for i, std in enumerate(std_values):
        # Plot all rho values on the same subplot, using consistent colors
        if isinstance(color_list, str): color=color_list
        else: color=color_list[i]
        for j, rho in enumerate(rho_values):
            data = toe_bs_kde_xr.sel(std=std, rho=rho)
            ax.plot(x, data, color=color, linewidth=linewidths[j],
                    alpha=alphas[j], label=f'{rho:.2f}')
            
            # Compute and plot the median vertical line
            median_x = np.nanmedian(toe_bs_xr.sel(std=std, rho=rho).values)
            median_y = data.values[np.argmin(np.abs(x - median_x))]
            ax.plot(
                [median_x, median_x], [0, median_y],
                linestyle="dashed", linewidth=linewidths[j], color=color, alpha=alphas[j])

        
        ax.yaxis.set_major_locator(MaxNLocator(nbins=5, min_n_ticks=4, prune=None))
        ax.set_xlim(0, 250)
        if xlabel: ax.set_xlabel('Time of Emergence (ToE)', fontsize=12)    
        ax.grid(True, linestyle='--', alpha=0.25, color='grey')


    if add_legend:
        # Create legend entries
        std_line_list = [mlines.Line2D([], [], color=color, label=std)
                         for color, std in zip(color_list, std_subset)]
        
        rho_line_list = [mlines.Line2D([], [], color='grey', linewidth=lw, label=rho, alpha=alpha)
                         for lw, alpha, rho in zip(linewidths, alphas, rho_values)]
        
        # First legend: Standard Deviation
        leg1 = axes[0].legend(
            ncol=3, handles=std_line_list, title='Standard Deviation',
            loc='upper center', fontsize=10, title_fontsize=10, bbox_to_anchor=(0.2, 1.53))
        # Add the first legend manually so the second one doesn't overwrite it
        axes[0].add_artist(leg1)
        # Second legend: Lag-1 Autocorrelation
        axes[0].legend(
            ncol=4, handles=rho_line_list, title='Lag-1 Autocorrelation',
            loc='upper center', fontsize=10, title_fontsize=10, bbox_to_anchor=(0.7, 1.53))
    
    return fig, axs

# %%
# color_list = ['#1f77b4', '#ff7f0e', '#8bc34a']
color_list = ['#0072B2', '#E69F00', '#009E73']  # Blue, Orange, Green
# color_list = ['#1b9e77', '#d95f02', '#7570b3']  # Teal, Rust, Purple

# %%
reload(toe_plots)
# Out:
# <module 'toe_plots' from '/home/563/ab2313/Documents/time_of_emergene_drafts/src/toe_plots.py'>

# %%
# fig = plt.figure(figsize=(8, 14))
fig = plt.figure(figsize=(8, 10))

outer_gs = gridspec.GridSpec(2, 1, figure=fig, hspace=0.35, height_ratios=[1, 0.4])

gs_top = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=outer_gs[0], hspace=0)
axes =[fig.add_subplot(gs_top[i]) for i in range(3)]

gs_bottom = gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=outer_gs[1], wspace=0.08)
axes_bottom =[fig.add_subplot(gs_bottom[i]) for i in range(2)]
fig.text(0.5, 0.97, "Effect of Auto-correlation and Variability",
         ha='center', va='bottom', fontsize=14, weight='bold')
fig.text(0.5, 0.34, "Effect of Variability Changing in time",
         ha='center', va='bottom', fontsize=14, weight='bold')

#######
std_subset = [0.1 , 0.5 , 1.  ]

plot_toe_bs_kde_v2(
    sn_toe_bs_kde_xr.sel(std=std_subset), sn_toe_bs_xr.sel(std=std_subset),
    fig=fig, ax=axes[0], color_list=color_list, add_legend=False);

plot_toe_bs_kde_v2(
    ks_toe_bs_kde_xr.sel(std=std_subset), ks_toe_bs_xr.sel(std=std_subset),
    fig=fig, ax=axes[1], color_list=color_list, add_legend=False, xlabel=False);

plot_toe_bs_kde_v2(
    fga_toe_bs_kde_xr.sel(std=std_subset), fga_toe_bs_xr.sel(std=std_subset),
    fig=fig, ax=axes[2], color_list=color_list, add_legend=True);

axes[1].set_xticklabels([])
# Move ticks and label to top
axes[0].xaxis.tick_top()
# axes[0].xaxis.set_label_position('top')
axes[1].set_ylabel('Relative Frequency', fontsize=12)

ANNOTATE_KWARGS = dict(
    xy=(0.5, 0.8), xycoords='axes fraction', ha='center', va='center',
    color='k', fontsize=12)

axes[0].annotate(METRIC_MAP['sn'], **ANNOTATE_KWARGS)
axes[1].annotate(METRIC_MAP['ks'].replace('\n', ' '), **ANNOTATE_KWARGS)
axes[2].annotate(METRIC_MAP['frac'].replace('\n', ' '), **ANNOTATE_KWARGS)

#### Variance changes


variance_changes = ['1p0t0p1', '0p5t1p0']


fig, axes_bottom= plot_toe_bs_kde_custom(
    toe_non_stat_kde_xr.sel(std = variance_changes), toe_non_stat_xr,
    fig=fig, axs=axes_bottom,add_legend=False)

# Even though the function has a legend, it's placed behine right column plot
legend = axes_bottom[-1].legend(loc='upper left', fontsize=10,
                       bbox_to_anchor=(-.4, 1))

for ax in axes_bottom:
    ax.set_ylabel('Relative Frequency')
    ax.set_xlabel('Time of Emergence (ToE)', fontsize=12)   

axes_bottom[0].set_title(
    'Standard Deviation\nDecrease from ' +\
     variance_changes[0].replace('p', '.').replace('t', ' to '),
    fontsize=10)
axes_bottom[1].set_title(
    'Standard Deviation\nIncrease from ' +\
    variance_changes[1].replace('p', '.').replace('t', ' to '),
    fontsize=10)

axes_bottom[-1].yaxis.tick_right()                     # Move y-axis ticks to the right
axes_bottom[-1].yaxis.set_label_position("right")     # Move y-axis label to the right
axes_bottom[-1].tick_params(labelright=True, labelleft=False)  # Show labels on right, hide on left

# %%
fig = plt.figure(figsize=(8, 8))
gs = gridspec.GridSpec(3, 1, figure=fig, hspace=0)
axes =[fig.add_subplot(gs[i]) for i in range(3)]


color_list = ['#1f77b4', '#ff7f0e', '#8bc34a']
std_subset = [0.1 , 0.5 , 1.  ]

plot_toe_bs_kde_v2(
    sn_toe_bs_kde_xr.sel(std=std_subset), sn_toe_bs_xr.sel(std=std_subset),
    fig=fig, ax=axes[0], color_list=color_list, add_legend=False);

plot_toe_bs_kde_v2(
    ks_toe_bs_kde_xr.sel(std=std_subset), ks_toe_bs_xr.sel(std=std_subset),
    fig=fig, ax=axes[1], color_list=color_list, add_legend=False, xlabel=False);

plot_toe_bs_kde_v2(
    fga_toe_bs_kde_xr.sel(std=std_subset), fga_toe_bs_xr.sel(std=std_subset),
    fig=fig, ax=axes[2], color_list=color_list, add_legend=True);

axes[1].set_xticklabels([])
# Move ticks and label to top
axes[0].xaxis.tick_top()
axes[0].xaxis.set_label_position('top')
axes[1].set_ylabel('Relative Frequency', fontsize=12)

ANNOTATE_KWARGS = dict(
    xy=(0.5, 0.8), xycoords='axes fraction', ha='center', va='center',
    color='k', fontsize=12)

axes[0].annotate(METRIC_MAP['sn'], **ANNOTATE_KWARGS)
axes[1].annotate(METRIC_MAP['ks'].replace('\n', ' '), **ANNOTATE_KWARGS)
axes[2].annotate(METRIC_MAP['frac'].replace('\n', ' '), **ANNOTATE_KWARGS)
# Out:
# Text(0.5, 0.8, 'Area of Overlap')

# %%
# Create figure and gridspec (multiple rows, 1 column)
fig = plt.figure(figsize=(14, len(std_values) * 1.5))
gs = gridspec.GridSpec(len(ks_toe_bs_kde_xr['std'].values), 3, figure=fig, hspace=0.13)
axes_left = [fig.add_subplot(gs[i, 0]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]
axes_middle = [fig.add_subplot(gs[i, 1]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]
axes_right = [fig.add_subplot(gs[i, 2]) for i in range(len(ks_toe_bs_kde_xr['std'].values))]


plot_toe_bs_kde(sn_toe_bs_kde_xr, sn_toe_bs_xr, fig=fig, axs=axes_left, colors=colors);
plot_toe_bs_kde(ks_toe_bs_kde_xr, ks_toe_bs_xr, fig=fig, axs=axes_middle, colors=colors, ylabel=False, add_legend=False);
plot_toe_bs_kde(fga_toe_bs_kde_xr, fga_toe_bs_xr, fig=fig, axs=axes_right, colors=colors, ylabel=False, add_legend=False);


axes_left[0].set_title(METRIC_MAP['sn'], fontsize=15)
axes_middle[0].set_title(METRIC_MAP['ks'].replace('\n', ' '), fontsize=15)
axes_right[0].set_title(METRIC_MAP['frac'].replace('\n', ' '), fontsize=15)


for axes in [axes_left, axes_middle, axes_right]:
    for i,ax in enumerate(axes):
        if i == 0: ax.set_ylim(0, 0.16)
        if i == 1:ax.set_ylim(0, 0.05)
        if i == 2: ax.set_ylim(0, 0.025)
        if i==3: ax.set_ylim(0, 0.02)

# %%
std_subset = [0.1 , 0.5 , 1.  ]

fig = plt.figure(figsize=(6, 4))
# gs = gridspec.GridSpec(1, 1, figure=fig, hspace=0.13)
ax = fig.add_subplot(111)
axes = [ax, ax, ax]#[fig.add_subplot(gs[i]) for i in range(len(std_subset))]

plot_toe_bs_kde(
    sn_toe_bs_kde_xr.sel(std=std_subset), sn_toe_bs_xr.sel(std=std_subset),
    fig=fig, axs=axes, colors=colors);


axes[0].set_title(METRIC_MAP['sn'], fontsize=15)
# Out:
# Text(0.5, 1.0, 'S/N$_{\\mathrm{LOWESS,\\ base}}$ Ratio')

# %%
std_subset = [0.1 , 0.5 , 1.  ]

fig = plt.figure(figsize=(14/3, 10))
gs = gridspec.GridSpec(len(ks_toe_bs_kde_xr['std'].values), 1, figure=fig, hspace=0.13)
axes = [fig.add_subplot(gs[i]) for i in range(len(std_subset))]

plot_toe_bs_kde(
    sn_toe_bs_kde_xr.sel(std=std_subset), sn_toe_bs_xr.sel(std=std_subset),
    fig=fig, axs=axes, colors=colors);


axes[0].set_title(METRIC_MAP['sn'], fontsize=15)
# Out:
# Text(0.5, 1.0, 'S/N$_{\\mathrm{LOWESS,\\ base}}$ Ratio')

# %%
variance_changes = ['1p0t0p1', '0p5t1p0']

fig = plt.figure(figsize=(16, 5))

fig, axs= plot_toe_bs_kde_custom(
    toe_non_stat_kde_xr.sel(std = variance_changes), toe_non_stat_xr,
    fig=fig, legend_loc='upper right')


for ax in axs:
    ax.set_ylabel('Relative Frequency')

axs[0].set_title(
    'Standard Deviation Decrease from ' + variance_changes[0].replace('p', '.').replace('t', ' to '),
    fontsize=16)
axs[1].set_title(
    'Standard Deviation Increase from ' + variance_changes[0].replace('p', '.').replace('t', ' to '),
    fontsize=16)
# Out:
# Text(0.5, 1.0, 'Standard Deviation Increase from 1.0 to 0.1')

# %% [markdown]
# <h1 style='color:yellow'> Trend Demonstartion </h1>

# %%
colors = plt.cm.viridis_r(np.linspace(0, 1, trend_bs_xr['rho'].values.shape[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 colors = plt.cm.viridis_r(np.linspace(0, 1, trend_bs_xr['rho'].values.shape[0]))
#
# NameError: name 'trend_bs_xr' is not defined

# %%
trend_bs_xr_sample = trend_bs_xr.isel(iteration=0).compute()

# %%
 trend_non_stat_xr.isel(iteration=0).values

# %%
trend_non_stat_xr_sample = trend_non_stat_xr.isel(iteration=0).compute()

# %%
non_stat_std_values

# %%
grad_label = grad * 10
grad_label2 = grad_label/2

# %%
fig = plt.figure(figsize=(10, 16))
gs = gridspec.GridSpec(4,2, hspace=0.2, height_ratios=[0.5, 1, 1, 0.5])
ax_top = fig.add_subplot(gs[0, :])

ax_top.plot(true_trend, label=f'{grad_label:.2f} per decade')
ax_top.plot(true_trend/2, label=f'{grad_label2:.2f} per decade')
ax_top.set_xlim(0, 500)
ax_top.legend()

std_values = trend_bs_xr_sample['std'].values
rho_values = trend_bs_xr_sample['rho'].values

for num,rho in enumerate(rho_values):
    rho_gs = gridspec.GridSpecFromSubplotSpec(len(std_values), 1, hspace=0, subplot_spec=gs[2+num])
    rho_axes = [fig.add_subplot(rho_gs[i]) for i in range(len(std_values))]
    for num2, std in enumerate(std_values):
        ax = rho_axes[num2]
        ax.plot(trend_bs_xr_sample.sel(rho=rho, std=std).values)
        ax.set_ylabel(r'$\sigma=$'+f'\n{std:0.2f}', rotation=0, labelpad=15)
        ax.set_yticks([0, 2.5, 5])
        ax.set_ylim(-3, 8)
        ax.set_xlim(0, 500)
        if num2 < (len(std_values)-1):
            ax.set_xticklabels([])
        
    rho_axes[0].set_title(r'$\rho_1=$'+f'{rho:0.2f}')


non_stat_ax1 = fig.add_subplot(gs[-2])
non_stat_ax2 = fig.add_subplot(gs[-1])


non_stat_std_values = trend_non_stat_xr_sample['std'].values
for i in range(3):
    std_vali  = non_stat_std_values[i]
    std_valim  = non_stat_std_values[-i-1]

    trend_non_stat_xr_sample.sel(std=std_vali).plot(ax=non_stat_ax1, alpha=0.5,
                                                    label=std_vali.replace('p', '.').replace('t', ' to '))
    trend_non_stat_xr_sample.sel(std=std_valim).plot(ax=non_stat_ax2, alpha=0.5,
                                                    label=std_valim.replace('p', '.').replace('t', ' to '))

leg1 = non_stat_ax1.legend()
leg1.set_title('Variance Change')

leg2 = non_stat_ax2.legend()
leg2.set_title('Variance Change')
non_stat_ax1.set_title('Increasing Variance', fontsize=14)
non_stat_ax2.set_title('Decreasing Variance', fontsize=14)

# %%
fig = plt.figure(figsize=(6, 10))
gs = gridspec.GridSpec(5,2)

ax_top = fig.add_subplot(gs[0, :])
rho_axes = np.array([fig.add_subplot(gs[row, col]) for row, col in [(1, 0), (1,1), (2, 0), (2, 1)]]).ravel()

ax_top.plot(true_trend)
ax_top.plot(true_trend/2)

std_values = trend_bs_xr_sample['std'].values
rho_values = trend_bs_xr_sample['rho'].values

for num,rho in enumerate(rho_values):
    ax = rho_axes[num]
    for std in std_values:
        ax.plot(trend_bs_xr_sample.sel(rho=rho, std=std).values, alpha=0.5)

# %%
trend_non_stat_xr

# %%
trend_bs_xr

# %% [markdown]
# # Old

# %%
for rho in sn_toe_bs_kde_xr['rho'].values:
    plt.plot(x, sn_toe_bs_kde_xr.sel(std=0.1, rho=rho))

# %%
for std in sn_toe_bs_kde_xr['std'].values:
    plt.plot(x, sn_toe_bs_kde_xr.sel(std=std, rho=0.75))

# %%
sn_toe_bs_kde_xr

# %%
sn_toe_bs_xr

# %%
sn_toe_bs_kde_m1 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=0).values, x)

# %%
toe_median_1 = toe_calc.get_permanent_exceedance(
            sn_bs_xr.median(dim='iteration'), threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1

# %%
# toe_median_1#.isel(multiplier=0)

# %%
 # Get the std of signal at the time when the median S/N ration between iterations is one
singal_range_list = []
for mult in toe_median_1.multiplier.values:
    median_toe = toe_median_1.sel(multiplier=mult).values.astype(int).item()
    signal_range = signal_bs_xr.sel(multiplier=mult).isel(time=median_toe)#.std()
    singal_range_list.append(signal_range)
signal_range_xr = xr.concat(singal_range_list, dim='multiplier')

# %%
ratio_s_std_to_noise_std = signal_range_xr.std(dim='iteration')/noise_bs_xr.std(dim='iteration')

# %%
ratio_s_std_to_noise_std

# %%
x = np.linspace(0, 200, 1000)

# %%
sn_toe_bs_xr

# %%
sn_toe_bs_kde_m1 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=0).values, x)
sn_toe_bs_kde_m2 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=1).values, x)
sn_toe_bs_kde_m3 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=2).values, x)
sn_toe_bs_kde_m4 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=3).values, x)

# %%
plt.plot(x, sn_toe_bs_kde_m1, label='1')
plt.plot(x, sn_toe_bs_kde_m2, label='2')
plt.plot(x, sn_toe_bs_kde_m3, label='3')
plt.plot(x, sn_toe_bs_kde_m4, label='4')
plt.legend()

# %%
trend_anom_bs_xr = trend_bs_xr - trend_bs_xr.isel(time=slice(0, 30)).mean(dim='time')

# %%
signal_bs_xr = xr.apply_ufunc(
    my_stats.apply_lowess,
    trend_anom_bs_xr,
    input_core_dims=[['time']],
    output_core_dims=[['time']],
    vectorize=True
)

# %%
noise_bs_xr = trend_bs_xr.isel(time=slice(0, 30)).std(dim='time')

# %%
sn_bs_xr = signal_bs_xr/noise_bs_xr

# %%
sn_toe_bs_xr = toe_calc.get_permanent_exceedance(
            sn_bs_xr, threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1 = toe_calc.get_permanent_exceedance(
            sn_bs_xr.median(dim='iteration'), threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1

# %%
# toe_median_1#.isel(multiplier=0)

# %%
 # Get the std of signal at the time when the median S/N ration between iterations is one
singal_range_list = []
for mult in toe_median_1.multiplier.values:
    median_toe = toe_median_1.sel(multiplier=mult).values.astype(int).item()
    signal_range = signal_bs_xr.sel(multiplier=mult).isel(time=median_toe)#.std()
    singal_range_list.append(signal_range)
signal_range_xr = xr.concat(singal_range_list, dim='multiplier')

# %%
ratio_s_std_to_noise_std = signal_range_xr.std(dim='iteration')/noise_bs_xr.std(dim='iteration')

# %%
ratio_s_std_to_noise_std

# %%
x = np.linspace(0, 200, 1000)

# %%
sn_toe_bs_xr

# %%
sn_toe_bs_kde_m1 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=0).values, x)
sn_toe_bs_kde_m2 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=1).values, x)
sn_toe_bs_kde_m3 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=2).values, x)
sn_toe_bs_kde_m4 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=3).values, x)

# %%
plt.plot(x, sn_toe_bs_kde_m1, label='1')
plt.plot(x, sn_toe_bs_kde_m2, label='2')
plt.plot(x, sn_toe_bs_kde_m3, label='3')
plt.plot(x, sn_toe_bs_kde_m4, label='4')
plt.legend()

# %%
noise_bs_xr = generate_noise_ensemble(0.25, 0.2, length=true_trend.shape[0])

# %%
trend_bs_xr = noise_bs_xr + true_trend

# %%
multipliers = [1, 2, 3, 4]

# Stack different noise scalings into a new "multiplier" dimension
trend_bs_xr = xr.concat([true_trend + noise_bs_xr * m for m in multipliers], dim="multiplier")

# Assign correct multiplier labels
trend_bs_xr["multiplier"] = multipliers
trend_bs_xr

# %%
trend_anom_bs_xr = trend_bs_xr - trend_bs_xr.isel(time=slice(0, 30)).mean(dim='time')

# %%
signal_bs_xr = xr.apply_ufunc(
    my_stats.apply_lowess,
    trend_anom_bs_xr,
    input_core_dims=[['time']],
    output_core_dims=[['time']],
    vectorize=True
)

# %%
noise_bs_xr = trend_bs_xr.isel(time=slice(0, 30)).std(dim='time')

# %%
sn_bs_xr = signal_bs_xr/noise_bs_xr

# %%
sn_toe_bs_xr = toe_calc.get_permanent_exceedance(
            sn_bs_xr, threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1 = toe_calc.get_permanent_exceedance(
            sn_bs_xr.median(dim='iteration'), threshold=1, comparison_func=np.greater, time=sn_bs_xr.time.values)

# %%
toe_median_1

# %%
# toe_median_1#.isel(multiplier=0)

# %%
 # Get the std of signal at the time when the median S/N ration between iterations is one
singal_range_list = []
for mult in toe_median_1.multiplier.values:
    median_toe = toe_median_1.sel(multiplier=mult).values.astype(int).item()
    signal_range = signal_bs_xr.sel(multiplier=mult).isel(time=median_toe)#.std()
    singal_range_list.append(signal_range)
signal_range_xr = xr.concat(singal_range_list, dim='multiplier')

# %%
ratio_s_std_to_noise_std = signal_range_xr.std(dim='iteration')/noise_bs_xr.std(dim='iteration')

# %%
ratio_s_std_to_noise_std

# %%
x = np.linspace(0, 200, 1000)

# %%
sn_toe_bs_xr

# %%
sn_toe_bs_kde_m1 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=0).values, x)
sn_toe_bs_kde_m2 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=1).values, x)
sn_toe_bs_kde_m3 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=2).values, x)
sn_toe_bs_kde_m4 = toe_calc.create_kde_x_exists(sn_toe_bs_xr.isel(multiplier=3).values, x)

# %%
plt.plot(x, sn_toe_bs_kde_m1, label='1')
plt.plot(x, sn_toe_bs_kde_m2, label='2')
plt.plot(x, sn_toe_bs_kde_m3, label='3')
plt.plot(x, sn_toe_bs_kde_m4, label='4')
plt.legend()

# %%
noise_bs_xr.plot()

# %%
sn_bs_xr.plot(hue='iteration', add_legend=False);

# %%
signal_bs_xr.plot(hue='iteration', add_legend=False);

# %%
trend_series.plot(hue='iteration', add_legend=False);

# %%
noise_series_xr.plot(hue='iteration', add_legend=False);

# %%
noise_series_list.shape

# %%
lat_lon_sp = dict(lat=-34, lon=145, method='nearest')

# %%
stats_test_1d_array_ks = partial(
    toe_calc.stats_test_1d_array, stats_func=toe_calc.return_ks_pvalue,
    window=window, base_period_length=base_period.length+1)

# %%
ks_1d_1p = stats_test_1d_array_ks(data_ds.sel(**lat_lon_sp).isel(**ensemble_kwargs).values)

# %%
plt.plot(ks_1d_1p,label='1d', linestyle='--')
plt.plot(ks_ds.sel(**lat_lon_sp).isel(time=slice(int(window/2), -int(window/2)), **ensemble_kwargs).values, label='roll', alpha=0.5)
plt.legend()

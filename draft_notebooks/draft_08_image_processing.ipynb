# %%
FNAME = '2015_King_et_al.png'

# %%
import os, sys

# %%
os.getcwd()
# Out:
# '/home/563/ab2313'

# %%
sys.path.append(os.path.join(os.getcwd(), 'Documents/time_of_emergene_drafts/draft_notebooks'))

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image
import numpy as np

# %%
# Open the PNG file
img = Image.open('Documents/time_of_emergene_drafts/draft_notebooks/2015_King_et_al_img1.png')

# %%
# Convert the image to a NumPy array
img_array = np.array(img)

# %%
import matplotlib.pyplot as plt

# Assuming img_array is the NumPy array representing the image

# Plot the image
plt.imshow(img_array)

# Add a title and labels (optional)
plt.title('Image Plot')
plt.xlabel('Width')
plt.ylabel('Height')

# Display the plot
plt.show()

# %%
# Load the image
img = cv2.imread('/home/Documents/time_of_emergene_drafts/draft_notebooks/2015_King_et_al.png')
# Out:
# [ WARN:0@61.629] global loadsave.cpp:244 findDecoder imread_('/home/Documents/time_of_emergene_drafts/draft_notebooks/2015_King_et_al.png'): can't open/read file: check file path/integrity

# %%
# Resize the image (optional)
img = cv2.resize(img, (500, 500))

# %%
# Convert to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Extract pixel values
pixel_values = np.array(img)
# Out:
# [ WARN:0@29.467] global loadsave.cpp:244 findDecoder imread_('2015_King_et_al.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 5
#       2 img = cv2.imread(FNAME)
#       4 # Resize the image (optional)
# ----> 5 img = cv2.resize(img, (500, 500))
#       7 # Convert to RGB
#       8 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#
# error: OpenCV(4.7.0) /home/conda/feedstock_root/build_artifacts/libopencv_1674428346434/work/modules/imgproc/src/resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
# Reshape the array (if needed)
# pixel_values = pixel_values.reshape((height, width, 3))

# Plot the array
plt.imshow(pixel_values)
plt.show()

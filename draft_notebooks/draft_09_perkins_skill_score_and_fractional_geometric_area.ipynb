# %%
# Standard Library Imports
import os
import sys
from importlib import reload
from functools import partial
from enum import Enum
from typing import NamedTuple
from time import sleep
# Third-Party Library Imports
import numpy as np
from numpy.typing import ArrayLike
import pandas as pd
import xarray as xr
from scipy.stats import spearmanr

# Plotting imports
import hvplot.xarray
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import ticker as mticker
import matplotlib.gridspec as gridspec
import matplotlib.colors as mcolors
import seaborn as sns
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# My imports
sys.path.append(os.path.join(os.getcwd(), 'Documents', 'time_of_emergene_drafts'))
sys.path.append(os.path.join(os.getcwd(), 'Documents', 'time_of_emergene_drafts', 'src'))

import utils
import plotting_utils
import climate_utils
import stats
import time_of_emrgence_calc as toe
import toe_constants as toe_const

# Suppress Warnings
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', message="p-value floored: true value smaller than 0.001")
warnings.filterwarnings('ignore', message="p-value capped: true value larger than 0.25")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="bb9dafc9-e1ea-44ae-8868-fd299b5a14f2" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"bef831b2-f967-4184-a6dc-8d547b1163d4":{"version":"3.3.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"6986c001dd684fa1b888177d0c5c4d8e","client_comm_id":"180c20da588b48c38c14f22432970d71"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"bef831b2-f967-4184-a6dc-8d547b1163d4","roots":{"p1002":"bb9dafc9-e1ea-44ae-8868-fd299b5a14f2"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Matplotlib created a temporary config/cache directory at /jobfs/116060590.gadi-pbs/matplotlib-_mfd109o because the default path (/home/563/ab2313/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
xr.set_options(display_expand_attrs=False)
xr.set_options(display_expand_data=True)
np.set_printoptions(precision=2, suppress=True, edgeitems=1)

# %%
# client.close()

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1, n_workers=6) #n_workers=2
# Scale the client to have n workers workers
# client.cluster.scale(28)
client
# Out:
#  - State start
#  -   Scheduler at:     tcp://127.0.0.1:34871
#  -   dashboard at:         /proxy/8787/status
#  - Registering Worker plugin shuffle
#  -         Start Nanny at: 'tcp://127.0.0.1:45015'
#  -         Start Nanny at: 'tcp://127.0.0.1:36551'
#  -         Start Nanny at: 'tcp://127.0.0.1:45691'
#  -         Start Nanny at: 'tcp://127.0.0.1:37841'
#  -         Start Nanny at: 'tcp://127.0.0.1:43071'
#  -         Start Nanny at: 'tcp://127.0.0.1:37005'
#  - Register worker <WorkerState 'tcp://127.0.0.1:38913', name: 2, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:38913
#  - Starting established connection to tcp://127.0.0.1:46046
#  - Register worker <WorkerState 'tcp://127.0.0.1:33591', name: 5, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:33591
#  - Starting established connection to tcp://127.0.0.1:46032
#  - Register worker <WorkerState 'tcp://127.0.0.1:45947', name: 4, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45947
#  - Starting established connection to tcp://127.0.0.1:46010
#  - Register worker <WorkerState 'tcp://127.0.0.1:46207', name: 1, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46207
#  - Starting established connection to tcp://127.0.0.1:46056
#  - Register worker <WorkerState 'tcp://127.0.0.1:41309', name: 0, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41309
#  - Starting established connection to tcp://127.0.0.1:46062
#  - Register worker <WorkerState 'tcp://127.0.0.1:43075', name: 3, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43075
#  - Starting established connection to tcp://127.0.0.1:46020
#  - Receive client connection: Client-2d08f522-1643-11ef-bcd0-000007abfe80
#  - Starting established connection to tcp://127.0.0.1:46072
# <Client: 'tcp://127.0.0.1:34871' processes=6 threads=6, memory=251.18 GiB>

# %%
ROOT_DIR = '/g/data/w40/ab2313/PhD/time_of_emergence'
os.listdir(os.path.join(ROOT_DIR, 'best'))
# Out:
# ['Complete_TAVG_LatLong1.nc',
#  'best_mask_old.zarr',
#  'best_mask.zarr',
#  'Land_and_Ocean_LatLong1_time_chunk.zarr',
#  'Land_and_Ocean_LatLong1.zarr',
#  'Land_and_Ocean_LatLong1.nc',
#  '.ipynb_checkpoints']

# %%
best_ds_raw = xr.open_dataset(os.path.join(ROOT_DIR, 'best', 'Land_and_Ocean_LatLong1_time_chunk.zarr'), 
                    chunks={'time':-1, 'latitude': 90, 'longitude': 120},
                    use_cftime=True)

best_ds_raw['time'] = xr.cftime_range(start='1850-01-01', freq='M', periods=len(best_ds_raw.time.values))
best_ds = best_ds_raw.copy(deep=True)['temperature']
best_ds = best_ds.resample(time='Y').mean()
best_ds = best_ds.compute()
# Out:
# 0.3.0

# %%
# Create a data set for the base period used as the pre-industrial climate 
start_end_tuple = (1850, 1900)#(1900, 1931)

base_period_ds = best_ds.where(best_ds.time.dt.year.isin(np.arange(*start_end_tuple)), drop=True)
base_period_ds
# Out:
# <xarray.DataArray 'temperature' (time: 50, lat: 180, lon: 360)>
# array([[[  nan, ...,   nan],
#         ...,
#         [  nan, ...,   nan]],
#
#        ...,
#
#        [[  nan, ...,   nan],
#         ...,
#         [-0.03, ..., -0.03]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
#   * time     (time) object 1850-12-31 00:00:00 ... 1899-12-31 00:00:00
# Attributes: (5)

# %%
base_period_ds_count = base_period_ds.count(dim='time')

# %%
# Create a mask that removes any grid celss where there are less than 40 point in the base period
data_availability_mask = xr.where(base_period_ds_count>=40, 1, 0)
data_availability_mask
# Out:
# <xarray.DataArray 'temperature' (lat: 180, lon: 360)>
# array([[0, ..., 0],
#        ...,
#        [0, ..., 0]])
# Coordinates:
#   * lat      (lat) float32 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5

# %%
# Apply the mask to both the base period and the full dataset
best_ds = best_ds.where(data_availability_mask)
base_period_ds = base_period_ds.where(data_availability_mask)

# %%
# Resetting the anomlies to 1850
best_ds = best_ds - base_period_ds.mean(dim='time')
base_period_ds = base_period_ds - base_period_ds.mean(dim='time')

# %% [markdown]
# # Sample Calculation

# %%
selection_dict = dict(lat=-38, lon=145, method='nearest')

# %%
base_period_ds
# Out:
# <xarray.DataArray 'temperature' (time: 50, lat: 180, lon: 360)>
# array([[[nan, ..., nan],
#         ...,
#         [nan, ..., nan]],
#
#        ...,
#
#        [[nan, ..., nan],
#         ...,
#         [nan, ..., nan]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
#   * time     (time) object 1850-12-31 00:00:00 ... 1899-12-31 00:00:00

# %%
base_arr = base_period_ds.sel(**selection_dict).squeeze()#.values

# %%
arr_best =  best_ds.sel(**selection_dict).squeeze()
arr_best = arr_best.isel(time=slice(130, 160))
# arr_best = arr_best.isel(time=slice(None, 50))

# %%
np.take(arr_best.time.values, [0, -1])
# Out:
# array([cftime.DatetimeGregorian(1980, 12, 31, 0, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(2009, 12, 31, 0, 0, 0, 0, has_year_zero=False)],
#       dtype=object)

# %%
np.take(base_arr.time.values, [0, -1])
# Out:
# array([cftime.DatetimeGregorian(1850, 12, 31, 0, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(1899, 12, 31, 0, 0, 0, 0, has_year_zero=False)],
#       dtype=object)

# %%
arr_best = arr_best.values
base_arr = base_arr.values

# %% [markdown]
# ## Perkins Skill Score

# %%
arr_best
# Out:
# array([ 0.78,  0.92,  0.71,  0.48, -0.15,  0.34, -0.16,  0.14,  1.19,
#         0.51,  0.83,  0.54, -0.02,  0.45,  0.21, -0.13, -0.25,  0.7 ,
#         0.5 ,  0.96,  0.94,  0.91,  0.87,  0.73,  0.52,  1.02,  0.79,
#         1.63,  0.75,  1.36], dtype=float32)

# %%
# np.testing.assert_equal(arr_best, base_arr)

# %%
np.nanmin(arr_best), np.nanmin(base_arr)
# Out:
# (-0.25295871, -0.43993783)

# %%
np.nanmax(arr_best), np.nanmax(base_arr)
# Out:
# (1.6317903, 0.6432928)

# %%
step = 0.5

# %%
bins = np.arange(-3, 3+step, step)

# %%
def get_rel_freq(arr, bins):
    arr = arr[np.isfinite(arr)]
    counts, _ = np.histogram(arr, bins=bins, density=False)
    rel_freq = counts/len(arr)
    return rel_freq

# %%
rel_freq_base = get_rel_freq(base_arr, bins)
rel_freq_best = get_rel_freq(arr_best, bins)

# %%
np.sum(rel_freq_base)
# Out:
# 1.0

# %%
plt.plot(rel_freq_base)
plt.plot(rel_freq_best)

# %%
rel_freq_base == rel_freq_best
# Out:
# array([ True,  True,  True,  True,  True, False, False, False, False,
#        False,  True,  True])

# %%
# plot the relative frequency
plt.bar(bins[:-1], rel_freq_base, alpha=0.5, width=step)
plt.bar(bins[:-1], rel_freq_best, alpha=0.5, width=step)

plt.xlabel('Bin')
plt.ylabel('Relative Frequency')
plt.title('Relative Frequency Plot')
# plt.xticks(range(len(rel_freq)), ['[0, 2)', '[2, 4)', '[4, 6)'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
freq_stack =np.array([rel_freq_base, rel_freq_best]) 
freq_stack.shape
# Out:
# (2, 12)

# %%
freq_stack = freq_stack.transpose()

# %%
freq_min = np.nanmin(freq_stack, axis=1)

# %%
freq_min_sum_percent = np.sum(freq_min) * 100

# %%
freq_min_sum_percent
# Out:
# 38.88888888888889

# %% [markdown]
# ## Fractional Geometric Area

# %%
from scipy.stats import gaussian_kde

# %%
bmax = np.nanmax(np.concatenate([base_arr, arr_best]))
bmin = np.nanmin(np.concatenate([base_arr, arr_best]))
bmin,  bmax = -3, 3

# %%
x = np.linspace(bmin, bmax, 100)

# %%
base_arr = base_arr[np.isfinite(base_arr)]
arr_best = arr_best[np.isfinite(arr_best)]

# %%
kde1 = gaussian_kde(base_arr)
kde2 = gaussian_kde(arr_best)

# %%
kde_vals1 = kde1(x)
kde_vals2 = kde2(x)

# %%
plt.plot(x, kde_vals1, 'k', linewidth=2)
plt.plot(x, kde_vals2, 'orange', linewidth=2)

plt.hist(base_arr, bins=np.arange(bmin, bmax, 0.15), density=True);
plt.hist(arr_best, bins=np.arange(bmin, bmax, 0.15), density=True);

# %%
overlap_shape = np.min(np.vstack([kde_vals2,kde_vals1]), axis=0)

# %%
overlap_area = np.trapz(overlap_shape, x)

# %%
overlap_percent = overlap_area * 100
overlap_percent
# Out:
# 35.56348457715971

# %% [markdown]
# # Apply As ufunc

# %%
CHUNKS_FOR_PVALUE_TESTS =  {'lat':30, 'lon':30, 'time':-1}

# %%
window=50

# %%
# Creting new datasets that has windown dimnsion for the rolling calculation
best_ds_window = (best_ds
                  .chunk(CHUNKS_FOR_PVALUE_TESTS)
                  .rolling(time=window, center=True, min_periods=window)
                  .construct('window_dim')
                  .persist()) 

base_period_window_ds = (base_period_ds
                         .chunk(CHUNKS_FOR_PVALUE_TESTS)
                         .rename({'time':'window_dim'})
                         .persist())

# %%
def get_rel_freq(arr, bins):
    arr = arr[np.isfinite(arr)]
    counts, _ = np.histogram(arr, bins=bins, density=False)
    rel_freq = counts/len(arr)
    return rel_freq

# %%
# The arguements needed for all of the calculations
rolling_window_kwargs = dict(
    input_core_dims=[['window_dim'], ['window_dim']],
    exclude_dims={'window_dim'},
    vectorize=True,
    dask='parallelized')

# %%
client.cluster.scale(18)
sleep(7)
# Out:
#  -         Start Nanny at: 'tcp://127.0.0.1:35643'
#  -         Start Nanny at: 'tcp://127.0.0.1:32775'
#  -         Start Nanny at: 'tcp://127.0.0.1:46315'
#  -         Start Nanny at: 'tcp://127.0.0.1:34301'
#  -         Start Nanny at: 'tcp://127.0.0.1:40175'
#  -         Start Nanny at: 'tcp://127.0.0.1:45953'
#  -         Start Nanny at: 'tcp://127.0.0.1:43795'
#  -         Start Nanny at: 'tcp://127.0.0.1:40917'
#  -         Start Nanny at: 'tcp://127.0.0.1:45739'
#  -         Start Nanny at: 'tcp://127.0.0.1:40817'
#  -         Start Nanny at: 'tcp://127.0.0.1:39409'
#  -         Start Nanny at: 'tcp://127.0.0.1:37219'
#  - Register worker <WorkerState 'tcp://127.0.0.1:36519', name: 20, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36519
#  - Starting established connection to tcp://127.0.0.1:48722
#  - Register worker <WorkerState 'tcp://127.0.0.1:43957', name: 26, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:43957
#  - Starting established connection to tcp://127.0.0.1:48712
#  - Register worker <WorkerState 'tcp://127.0.0.1:45663', name: 21, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:45663
#  - Starting established connection to tcp://127.0.0.1:48778
#  - Register worker <WorkerState 'tcp://127.0.0.1:34681', name: 27, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:34681
#  - Starting established connection to tcp://127.0.0.1:48696
#  - Register worker <WorkerState 'tcp://127.0.0.1:36983', name: 24, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36983
#  - Starting established connection to tcp://127.0.0.1:48740
#  - Register worker <WorkerState 'tcp://127.0.0.1:36033', name: 18, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:36033
#  - Starting established connection to tcp://127.0.0.1:48742
#  - Register worker <WorkerState 'tcp://127.0.0.1:40333', name: 17, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:40333
#  - Starting established connection to tcp://127.0.0.1:48738
#  - Register worker <WorkerState 'tcp://127.0.0.1:35193', name: 25, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:35193
#  - Starting established connection to tcp://127.0.0.1:48758
#  - Register worker <WorkerState 'tcp://127.0.0.1:39309', name: 19, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39309
#  - Starting established connection to tcp://127.0.0.1:48796
#  - Register worker <WorkerState 'tcp://127.0.0.1:39445', name: 23, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:39445
#  - Starting established connection to tcp://127.0.0.1:48780
#  - Register worker <WorkerState 'tcp://127.0.0.1:41463', name: 22, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:41463
#  - Starting established connection to tcp://127.0.0.1:48724
#  - Register worker <WorkerState 'tcp://127.0.0.1:46037', name: 28, status: init, memory: 0, processing: 0>
#  - Starting worker compute stream, tcp://127.0.0.1:46037
#  - Starting established connection to tcp://127.0.0.1:48772

# %%
def farctional_geometric_area(arr_best, base_arr):
    if np.all(np.isnan(arr_best)) or np.all(np.isnan(base_arr)): return np.nan
    bmax = np.nanmax(np.concatenate([base_arr, arr_best]))
    bmin = np.nanmin(np.concatenate([base_arr, arr_best]))
    x = np.linspace(bmin, bmax, 1000)
    
    base_arr = base_arr[np.isfinite(base_arr)]
    arr_best = arr_best[np.isfinite(arr_best)]
    kde1 = gaussian_kde(base_arr)
    kde2 = gaussian_kde(arr_best)
    kde_vals1 = kde1(x)
    kde_vals2 = kde2(x)
    overlap_shape = np.min(np.vstack([kde_vals2,kde_vals1]), axis=0)
    overlap_area = np.trapz(overlap_shape, x)
    overlap_percent = overlap_area * 100
    return overlap_percent

# %%
def perkins_skill_score(arr_best, base_arr):
    if np.all(np.isnan(arr_best)) or np.all(np.isnan(base_arr)): return np.nan
    bmax = np.nanmax(np.concatenate([base_arr, arr_best]))
    bmin = np.nanmin(np.concatenate([base_arr, arr_best]))
    #print(bmin, bmax)
    step = 0.5
    bins = np.arange(bmin, bmax+step, step)
    
    rel_freq_base = get_rel_freq(base_arr, bins)
    rel_freq_best = get_rel_freq(arr_best, bins)
    freq_stack = np.vstack([rel_freq_base, rel_freq_best])
    
    freq_min = np.nanmin(freq_stack, axis=0)
    
    freq_min_sum_percent = np.sum(freq_min) * 100
    return float(freq_min_sum_percent)

# %%
# %%time
perkins_ds = xr.apply_ufunc(
    perkins_skill_score,
    best_ds_window,
    base_period_window_ds,
    output_dtypes=float,
    **rolling_window_kwargs
    ).compute()
# Out:
# CPU times: user 22.5 s, sys: 3.51 s, total: 26.1 s
# Wall time: 2min 6s

# %%
client.cluster.scale(6)
sleep(7)
# Out:
#  - Closing Nanny at 'tcp://127.0.0.1:35643'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:32775'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:46315'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:34301'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:40175'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:45953'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:43795'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:40917'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:45739'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:40817'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:39409'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Closing Nanny at 'tcp://127.0.0.1:37219'. Reason: nanny-close
#  - Nanny asking worker to close. Reason: nanny-close
#  - Received 'close-stream' from tcp://127.0.0.1:48738; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48742; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48796; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48722; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48778; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48724; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48780; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48740; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48758; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48712; closing.
#  - Remove worker <WorkerState 'tcp://127.0.0.1:40333', name: 17, status: closing, memory: 6, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.1415117')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:36033', name: 18, status: closing, memory: 6, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.1490855')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:39309', name: 19, status: closing, memory: 10, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.1560707')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:36519', name: 20, status: closing, memory: 6, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.1603723')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:45663', name: 21, status: closing, memory: 7, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.1627214')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:41463', name: 22, status: closing, memory: 6, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.1654174')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:39445', name: 23, status: closing, memory: 6, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.167935')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:36983', name: 24, status: closing, memory: 7, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.1701417')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:35193', name: 25, status: closing, memory: 8, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.172465')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:43957', name: 26, status: closing, memory: 6, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.1751926')
#  - Received 'close-stream' from tcp://127.0.0.1:48696; closing.
#  - Received 'close-stream' from tcp://127.0.0.1:48772; closing.
#  - Remove worker <WorkerState 'tcp://127.0.0.1:34681', name: 27, status: closing, memory: 7, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.1817853')
#  - Remove worker <WorkerState 'tcp://127.0.0.1:46037', name: 28, status: closing, memory: 7, processing: 0> (stimulus_id='handle-worker-cleanup-1716170557.184473')
#  - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:45353 remote=tcp://127.0.0.1:48696>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
#  - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:45353 remote=tcp://127.0.0.1:48772>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError

# %%
# %%time
frac_geom_ds = xr.apply_ufunc(
    farctional_geometric_area,
    best_ds_window,
    base_period_window_ds,
    output_dtypes=float,
    **rolling_window_kwargs
    ).compute()
# Out:
#  - Connection to tcp://127.0.0.1:49740 has been closed.
#  - Remove worker <WorkerState 'tcp://127.0.0.1:40895', name: 3, status: running, memory: 40, processing: 8> (stimulus_id='handle-worker-cleanup-1716166298.9380822')
#  - Connection to tcp://127.0.0.1:49750 has been closed.
#  - Remove worker <WorkerState 'tcp://127.0.0.1:40355', name: 1, status: running, memory: 46, processing: 17> (stimulus_id='handle-worker-cleanup-1716166298.9731996')
#  - Connection to tcp://127.0.0.1:49726 has been closed.
#  - Remove worker <WorkerState 'tcp://127.0.0.1:41177', name: 5, status: running, memory: 47, processing: 14> (stimulus_id='handle-worker-cleanup-1716166298.9809494')
#  - Connection to tcp://127.0.0.1:49730 has been closed.
#  - Remove worker <WorkerState 'tcp://127.0.0.1:33815', name: 2, status: running, memory: 60, processing: 32> (stimulus_id='handle-worker-cleanup-1716166298.9904368')
#  - Connection to tcp://127.0.0.1:49780 has been closed.
#  - Remove worker <WorkerState 'tcp://127.0.0.1:45619', name: 0, status: running, memory: 49, processing: 24> (stimulus_id='handle-worker-cleanup-1716166299.0196517')
#  - Closing Nanny gracefully at 'tcp://127.0.0.1:38435'. Reason: worker-close
#  - Closing Nanny gracefully at 'tcp://127.0.0.1:42995'. Reason: worker-close
#  - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:36799 remote=tcp://127.0.0.1:49750>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
#  - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:36799 remote=tcp://127.0.0.1:49730>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
#  - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:36799 remote=tcp://127.0.0.1:49726>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
#  - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:36799 remote=tcp://127.0.0.1:49780>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
#  - Closing Nanny gracefully at 'tcp://127.0.0.1:44281'. Reason: worker-close
#  - Closing Nanny gracefully at 'tcp://127.0.0.1:34401'. Reason: worker-close
#  - Closing Nanny gracefully at 'tcp://127.0.0.1:44421'. Reason: worker-close
# 2024-05-20 10:51:38,930 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('vectorize_farctional_geometric_area-vectorize_farctional_geometric_area_0-transpose-23d8a244a6a111c2abdac3fabdf2ec9--44b', 0, 4, 5))" coro=<Worker.execute() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-05-20 10:51:38,931 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('vectorize_farctional_geometric_area-vectorize_farctional_geometric_area_0-transpose-23d8a244a6a111c2abdac3fabdf2ec9--44b', 0, 5, 2))" coro=<Worker.execute() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-05-20 10:51:38,932 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('vectorize_farctional_geometric_area-vectorize_farctional_geometric_area_0-transpose-23d8a244a6a111c2abdac3fabdf2ec9--44b', 0, 5, 4))" coro=<Worker.execute() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-05-20 10:51:38,932 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('vectorize_farctional_geometric_area-vectorize_farctional_geometric_area_0-transpose-23d8a244a6a111c2abdac3fabdf2ec9--44b', 0, 5, 8))" coro=<Worker.execute() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-05-20 10:51:38,934 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('vectorize_farctional_geometric_area-vectorize_farctional_geometric_area_0-transpose-23d8a244a6a111c2abdac3fabdf2ec9--44b', 0, 5, 9))" coro=<Worker.execute() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-05-20 10:51:39,097 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/compatibility.py", line 239, in asyncio_run
#     _cancel_all_tasks(loop)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/compatibility.py", line 255, in _cancel_all_tasks
#     loop.run_until_complete(asyncio.gather(*to_cancel, return_exceptions=True))
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/ioloop.py", line 685, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/ioloop.py", line 762, in _discard_future_result
#     future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/ioloop.py", line 925, in _run
#     self._schedule_next()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/ioloop.py", line 929, in _schedule_next
#     self._update_next(self.io_loop.time())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in time
#     def time(self) -> float:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/nanny.py", line 988, in _run
#     with contextlib.ExitStack() as stack:
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
#
# KeyboardInterrupt

# %%
perkins_ds.isel(time=[0, 100, 160]).plot(col='time', levels=np.arange(0, 110, 10))

# %%
(xr.where(perkins_ds < 66, 1, 0)
 .where(data_availability_mask)
 .isel(time=np.arange(0, 160, 20))
 .plot(col='time', col_wrap=3))

# %%
xr.where(perkins_ds.isel(time=0) < 66, 1, 0).where(data_availability_mask).plot()

# %%
perkins_toe_ds = toe.get_permanent_exceedance(perkins_ds, threshold=62, comparison_func=np.less_equal)

# %%
frac_geom_toe_ds = toe.get_permanent_exceedance(frac_geom_ds, threshold=62, comparison_func=np.less_equal)

# %%
perkins_does_not_emerge = (perkins_ds.isel(time=-1) >= 62)

# %%
frac_geom_ds_does_not_emerge = (frac_geom_ds.isel(time=-1) >= 62)

# %%
import matplotlib.colors as mcolors

# %%
# Create a custom colormap with two colors: gray and transparent
colors = [(0, 0, 0, 0), (0.5, 0.5, 0.5, 1)]  # (R, G, B, Alpha)
cmap_binary = mcolors.LinearSegmentedColormap.from_list("binary_no_color", colors)

# %%
not_stable_kwargs2 = dict(cmap=cmap_binary, add_colorbar=False)
not_stable_kwargs = dict(add_colorbar=False, hatches=['', '////'], alpha=0, colors=None)

# %%
def hatch(ax, ds, **kwargs):
    LON, LAT = np.meshgrid(ds.lon.values, ds.lat.values)
    ax.contourf(LON, LAT, ds.values, **kwargs)

# %%
data_unavailability_mask = xr.where(data_availability_mask, False, True)

# %%
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(projection=ccrs.PlateCarree())
perkins_toe_ds.plot(ax=ax, cmap='RdYlBu', add_colorbar=False)#, levels=np.arange(1860, 2030, 10))


perkins_does_not_emerge.plot(ax=ax, **not_stable_kwargs2)
hatch(ax, data_unavailability_mask, **not_stable_kwargs)
ax.coastlines()

ax.set_title('Perkins Skill Score (<62%)')
# Out:
# Text(0.5, 1.0, 'Perkins Skill Score (<62%)')

# %%
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(projection=ccrs.PlateCarree())
frac_geom_toe_ds.plot(ax=ax, cmap='RdYlBu', add_colorbar=False)#, levels=np.arange(1860, 2030, 10))


frac_geom_ds_does_not_emerge.plot(ax=ax, **not_stable_kwargs2)
hatch(ax, data_unavailability_mask, **not_stable_kwargs)
ax.coastlines()

ax.set_title('Fractional Gemoetric Ratio (<62%)')
# Out:
# Text(0.5, 1.0, 'Fractional Gemoetric Ratio (<62%)')

# %% [markdown]
# # Local ToE
#
# - In this version I have added in the other tests (KS, Anerson Darling)

# %%
# Standard Library Imports
import os
import sys
from importlib import reload
from functools import partial
from itertools import groupby

# Third-Party Library Imports
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.colors as mcolors
import cartopy.crs as ccrs

from numpy.
# My imports
import os, sys
sys.path.append(os.path.join(os.getcwd(), 'Documents', 'PhD'))
import constants
sys.path.append(constants.MODULE_DIR)
               
import utils
import signal_to_noise as sn
import plotting_functions
import xarray_extender as xe
import stats
import time_of_emrgence_calc as toe
# Suppress Warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# Matplotlib created a temporary config/cache directory at /jobfs/111866954.gadi-pbs/matplotlib-41p3vh1a because the default path (/home/563/ab2313/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Matplotlib is building the font cache; this may take a moment.

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
# Scale the client to have n workers workers
client.cluster.scale(6)
client
# Out:
# - State start
# -   Scheduler at:     tcp://127.0.0.1:43839
# -   dashboard at:         /proxy/8787/status
# - Registering Worker plugin shuffle
# -         Start Nanny at: 'tcp://127.0.0.1:36785'
# -         Start Nanny at: 'tcp://127.0.0.1:33787'
# -         Start Nanny at: 'tcp://127.0.0.1:38453'
# -         Start Nanny at: 'tcp://127.0.0.1:37171'
# -         Start Nanny at: 'tcp://127.0.0.1:43911'
# -         Start Nanny at: 'tcp://127.0.0.1:46013'
# -         Start Nanny at: 'tcp://127.0.0.1:39795'
# -         Start Nanny at: 'tcp://127.0.0.1:44661'
# -         Start Nanny at: 'tcp://127.0.0.1:35253'
# -         Start Nanny at: 'tcp://127.0.0.1:37903'
# -         Start Nanny at: 'tcp://127.0.0.1:45305'
# -         Start Nanny at: 'tcp://127.0.0.1:38579'
# -         Start Nanny at: 'tcp://127.0.0.1:34463'
# -         Start Nanny at: 'tcp://127.0.0.1:38867'
# -         Start Nanny at: 'tcp://127.0.0.1:39135'
# -         Start Nanny at: 'tcp://127.0.0.1:45077'
# -         Start Nanny at: 'tcp://127.0.0.1:45357'
# -         Start Nanny at: 'tcp://127.0.0.1:45269'
# -         Start Nanny at: 'tcp://127.0.0.1:36611'
# -         Start Nanny at: 'tcp://127.0.0.1:33715'
# -         Start Nanny at: 'tcp://127.0.0.1:45829'
# -         Start Nanny at: 'tcp://127.0.0.1:46817'
# -         Start Nanny at: 'tcp://127.0.0.1:39447'
# -         Start Nanny at: 'tcp://127.0.0.1:41223'
# -         Start Nanny at: 'tcp://127.0.0.1:44243'
# -         Start Nanny at: 'tcp://127.0.0.1:33245'
# -         Start Nanny at: 'tcp://127.0.0.1:45915'
# -         Start Nanny at: 'tcp://127.0.0.1:42917'
# - Register worker <WorkerState 'tcp://127.0.0.1:34717', name: 10, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:34717
# - Starting established connection to tcp://127.0.0.1:60910
# - Register worker <WorkerState 'tcp://127.0.0.1:45871', name: 6, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:45871
# - Starting established connection to tcp://127.0.0.1:60942
# - Register worker <WorkerState 'tcp://127.0.0.1:38363', name: 2, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:38363
# - Starting established connection to tcp://127.0.0.1:60962
# - Register worker <WorkerState 'tcp://127.0.0.1:45447', name: 13, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:45447
# - Starting established connection to tcp://127.0.0.1:60800
# - Register worker <WorkerState 'tcp://127.0.0.1:40187', name: 24, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:40187
# - Starting established connection to tcp://127.0.0.1:60782
# - Register worker <WorkerState 'tcp://127.0.0.1:41703', name: 26, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:41703
# - Starting established connection to tcp://127.0.0.1:60916
# - Register worker <WorkerState 'tcp://127.0.0.1:34707', name: 18, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:34707
# - Starting established connection to tcp://127.0.0.1:60836
# - Register worker <WorkerState 'tcp://127.0.0.1:39151', name: 16, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:39151
# - Starting established connection to tcp://127.0.0.1:60856
# - Register worker <WorkerState 'tcp://127.0.0.1:46371', name: 7, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:46371
# - Starting established connection to tcp://127.0.0.1:60926
# - Register worker <WorkerState 'tcp://127.0.0.1:45755', name: 22, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:45755
# - Starting established connection to tcp://127.0.0.1:60968
# - Register worker <WorkerState 'tcp://127.0.0.1:37029', name: 23, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:37029
# - Starting established connection to tcp://127.0.0.1:32772
# - Register worker <WorkerState 'tcp://127.0.0.1:33097', name: 27, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:33097
# - Starting established connection to tcp://127.0.0.1:60960
# - Register worker <WorkerState 'tcp://127.0.0.1:41537', name: 25, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:41537
# - Starting established connection to tcp://127.0.0.1:60868
# - Register worker <WorkerState 'tcp://127.0.0.1:45219', name: 1, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:45219
# - Starting established connection to tcp://127.0.0.1:60950
# - Register worker <WorkerState 'tcp://127.0.0.1:44319', name: 11, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:44319
# - Starting established connection to tcp://127.0.0.1:60928
# - Register worker <WorkerState 'tcp://127.0.0.1:44137', name: 8, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:44137
# - Starting established connection to tcp://127.0.0.1:60992
# - Register worker <WorkerState 'tcp://127.0.0.1:42617', name: 12, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:42617
# - Starting established connection to tcp://127.0.0.1:60898
# - Register worker <WorkerState 'tcp://127.0.0.1:43619', name: 3, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:43619
# - Starting established connection to tcp://127.0.0.1:60840
# - Register worker <WorkerState 'tcp://127.0.0.1:44713', name: 5, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:44713
# - Starting established connection to tcp://127.0.0.1:60918
# - Register worker <WorkerState 'tcp://127.0.0.1:35721', name: 9, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:35721
# - Starting established connection to tcp://127.0.0.1:60820
# - Register worker <WorkerState 'tcp://127.0.0.1:44395', name: 20, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:44395
# - Starting established connection to tcp://127.0.0.1:60794
# - Register worker <WorkerState 'tcp://127.0.0.1:42719', name: 17, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:42719
# - Starting established connection to tcp://127.0.0.1:32774
# - Register worker <WorkerState 'tcp://127.0.0.1:35189', name: 4, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:35189
# - Starting established connection to tcp://127.0.0.1:60808
# - Register worker <WorkerState 'tcp://127.0.0.1:34663', name: 14, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:34663
# - Starting established connection to tcp://127.0.0.1:60944
# - Register worker <WorkerState 'tcp://127.0.0.1:45319', name: 21, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:45319
# - Starting established connection to tcp://127.0.0.1:60980
# - Register worker <WorkerState 'tcp://127.0.0.1:41985', name: 0, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:41985
# - Starting established connection to tcp://127.0.0.1:60922
# - Register worker <WorkerState 'tcp://127.0.0.1:44479', name: 15, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:44479
# - Starting established connection to tcp://127.0.0.1:60798
# - Register worker <WorkerState 'tcp://127.0.0.1:38249', name: 19, status: init, memory: 0, processing: 0>
# - Starting worker compute stream, tcp://127.0.0.1:38249
# - Starting established connection to tcp://127.0.0.1:60884
# - Receive client connection: Client-4f24f31c-ebcb-11ee-bde5-000007b0fe80
# - Starting established connection to tcp://127.0.0.1:32780
# - Closing Nanny at 'tcp://127.0.0.1:39795'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:44661'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:35253'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:37903'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:45305'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:38579'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:34463'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:38867'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:39135'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:45077'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:45357'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:45269'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:36611'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:33715'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:45829'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:46817'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:39447'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:41223'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:44243'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# <Client: 'tcp://127.0.0.1:43839' processes=28 threads=28, memory=251.18 GiB>
# - Closing Nanny at 'tcp://127.0.0.1:33245'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:45915'. Reason: nanny-close
# - Nanny asking worker to close. Reason: nanny-close
# - Closing Nanny at 'tcp://127.0.0.1:42917'. Reason: nanny-close

# %%
xr.set_options(display_expand_attrs=False)
xr.set_options(display_expand_data=True)
np.set_printoptions(precision=2, suppress=True, edgeitems=1)
# Out:
# - Nanny asking worker to close. Reason: nanny-close

# %% [markdown]
# # Opening Best

# %%
ROOT_DIR = '/g/data/w40/ab2313/PhD/time_of_emergence'

os.listdir(os.path.join(ROOT_DIR, 'best'))
# Out:
# - Received 'close-stream' from tcp://127.0.0.1:60942; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60926; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60992; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60820; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60910; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60928; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60898; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60800; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60944; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60798; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60856; closing.
# - Received 'close-stream' from tcp://127.0.0.1:32774; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60836; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60884; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60794; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60980; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60968; closing.
# - Received 'close-stream' from tcp://127.0.0.1:32772; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60782; closing.
# - Received 'close-stream' from tcp://127.0.0.1:60868; closing.
# ['Land_and_Ocean_LatLong1.zarr',
#  'Land_and_Ocean_LatLong1.nc',
#  '.ipynb_checkpoints']
# - Received 'close-stream' from tcp://127.0.0.1:60916; closing.

# %%
best_ds = xr.open_dataset(os.path.join(ROOT_DIR, 'best', 'Land_and_Ocean_LatLong1.zarr'), 
                    chunks={'time':-1, 'latitude': 90, 'longitude': 120},
                    use_cftime=True)['temperature']

best_ds = best_ds.rename({'latitude':'lat', 'longitude': 'lon'})
best_ds['time'] = xr.cftime_range(start='1850-01-01', freq='M', periods=len(best_ds.time.values))
best_ds = best_ds.resample(time='Y').mean()
# Out:
# - Remove worker <WorkerState 'tcp://127.0.0.1:45871', name: 6, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.974152')
# - Remove worker <WorkerState 'tcp://127.0.0.1:46371', name: 7, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.9784026')
# - Remove worker <WorkerState 'tcp://127.0.0.1:44137', name: 8, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.980697')
# - Remove worker <WorkerState 'tcp://127.0.0.1:35721', name: 9, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.9829895')
# - Remove worker <WorkerState 'tcp://127.0.0.1:34717', name: 10, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.9854965')
# - Remove worker <WorkerState 'tcp://127.0.0.1:44319', name: 11, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.988284')
# - Remove worker <WorkerState 'tcp://127.0.0.1:42617', name: 12, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.9907553')
# - Remove worker <WorkerState 'tcp://127.0.0.1:45447', name: 13, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.9924264')
# - Remove worker <WorkerState 'tcp://127.0.0.1:34663', name: 14, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.9941943')
# - Remove worker <WorkerState 'tcp://127.0.0.1:44479', name: 15, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.9956064')
# - Remove worker <WorkerState 'tcp://127.0.0.1:39151', name: 16, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.9966846')
# - Remove worker <WorkerState 'tcp://127.0.0.1:42719', name: 17, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.9978998')
# - Remove worker <WorkerState 'tcp://127.0.0.1:34707', name: 18, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496902.999512')
# - Remove worker <WorkerState 'tcp://127.0.0.1:38249', name: 19, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496903.0007281')
# - Remove worker <WorkerState 'tcp://127.0.0.1:44395', name: 20, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496903.0021203')
# - Remove worker <WorkerState 'tcp://127.0.0.1:45319', name: 21, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496903.003459')
# - Remove worker <WorkerState 'tcp://127.0.0.1:45755', name: 22, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496903.0049667')
# - Remove worker <WorkerState 'tcp://127.0.0.1:37029', name: 23, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496903.0068038')
# - Remove worker <WorkerState 'tcp://127.0.0.1:40187', name: 24, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496903.0077705')
# - Remove worker <WorkerState 'tcp://127.0.0.1:41537', name: 25, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496903.0090585')
# - Remove worker <WorkerState 'tcp://127.0.0.1:41703', name: 26, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496903.0102649')
# - Received 'close-stream' from tcp://127.0.0.1:60960; closing.
# - Remove worker <WorkerState 'tcp://127.0.0.1:33097', name: 27, status: closing, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711496903.0158045')
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:60960>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# 0.3.0

# %%
# Only 43MB - load into memory
best_ds = best_ds.compute()

# %%
best_ds.isel(time=[0, 30, 100]).plot(col='time')

# %%
# Create a data set for the base period used as the pre-industrial climate 
start_end_tuple = (1850, 1900)#(1900, 1931)

base_period_ds = best_ds.where(best_ds.time.dt.year.isin(np.arange(*start_end_tuple)), drop=True)
base_period_ds
# Out:
# <xarray.DataArray 'temperature' (time: 50, lat: 180, lon: 360)>
# array([[[  nan, ...,   nan],
#         ...,
#         [  nan, ...,   nan]],
#
#        ...,
#
#        [[  nan, ...,   nan],
#         ...,
#         [-0.03, ..., -0.03]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
#   * time     (time) object 1850-12-31 00:00:00 ... 1899-12-31 00:00:00
# Attributes: (5)

# %%
best_ds = best_ds - base_period_ds.mean(dim='time')

# %%
base_period_ds_count = base_period_ds.count(dim='time')

# %%
data_availability_levels = np.arange(0, 61, 10)

base_period_ds_count.plot(levels=data_availability_levels)

# %%
# Create a mask that removes any grid celss where there are less than 40 point in the base period
data_availability_mask = xr.where(base_period_ds_count>=40, 1, 0)
data_availability_mask
# Out:
# <xarray.DataArray 'temperature' (lat: 180, lon: 360)>
# array([[0, ..., 0],
#        ...,
#        [0, ..., 0]])
# Coordinates:
#   * lat      (lat) float32 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5

# %%
data_availability_mask.plot()

# %%
# Apply the mask to both the base period and the full dataset
best_ds = best_ds.where(data_availability_mask)

base_period_ds = base_period_ds.where(data_availability_mask)

# %% [markdown]
# # Calculations

# %%
window = 20

# %% [markdown]
# ## Signal-to-Noise

# %% [markdown]
# ### Trend Fit

# %%
# best_ds_no_base = best_ds.sel(time=best_ds.time.dt.year>1900)
# best_ds_no_base

# %%
import statsmodels.api as sm 
lowess = sm.nonparametric.lowess

# %%
def apply_lowess(arr):
    if all(np.isnan(arr)): return arr

    x = np.arange(arr.shape[0])
    yhat = lowess(arr,x, return_sorted=False)
    return yhat

# %%
best_ds_smean = best_ds.clima.space_mean()#.plot()
best_ds_smean
# Out:
# <xarray.DataArray 'temperature' (time: 175)>
# array([-0.08, -0.01,  0.04,  0.02,  0.01,  0.03, -0.09, -0.21, -0.04,
#         0.08, -0.07, -0.15, -0.22, -0.07, -0.02,  0.06,  0.1 ,  0.12,
#         0.11,  0.04,  0.01, -0.01,  0.02,  0.05, -0.03, -0.02, -0.04,
#         0.33,  0.4 ,  0.09,  0.02,  0.13,  0.07,  0.01, -0.15, -0.12,
#        -0.15, -0.18,  0.01,  0.14, -0.15, -0.01, -0.09, -0.07, -0.06,
#         0.  ,  0.1 ,  0.1 , -0.1 ,  0.06,  0.17,  0.09, -0.07, -0.17,
#        -0.22, -0.04,  0.04, -0.12, -0.16, -0.22, -0.18, -0.19, -0.11,
#        -0.09,  0.09,  0.15, -0.08, -0.23, -0.06, -0.01,  0.07,  0.12,
#         0.02,  0.06,  0.05,  0.09,  0.23,  0.11,  0.12, -0.05,  0.17,
#         0.22,  0.18, -0.01,  0.14,  0.08,  0.15,  0.3 ,  0.31,  0.29,
#         0.38,  0.33,  0.35,  0.4 ,  0.51,  0.36,  0.21,  0.27,  0.18,
#         0.19,  0.11,  0.28,  0.36,  0.43,  0.24,  0.16,  0.08,  0.31,
#         0.35,  0.31,  0.28,  0.32,  0.3 ,  0.32,  0.06,  0.17,  0.23,
#         0.25,  0.19,  0.33,  0.27,  0.15,  0.26,  0.41,  0.18,  0.26,
#         0.17,  0.5 ,  0.37,  0.47,  0.55,  0.62,  0.42,  0.6 ,  0.4 ,
#         0.42,  0.47,  0.61,  0.63,  0.54,  0.72,  0.69,  0.5 ,  0.58,
#         0.63,  0.78,  0.63,  0.82,  0.96,  0.72,  0.71,  0.85,  0.92,
#         0.92,  0.84,  0.99,  0.95,  0.94,  0.83,  0.95,  1.05,  0.91,
#         0.96,  0.96,  1.05,  1.22,  1.33,  1.23,  1.13,  1.28,  1.31,
#         1.17,  1.19,  1.5 ,  1.64], dtype=float32)
# Coordinates:
#   * time     (time) object 1850-12-31 00:00:00 ... 2024-12-31 00:00:00

# %%
best_ds_smean_lowess = xr.zeros_like(best_ds_smean) + apply_lowess(best_ds_smean.values)

# %%
best_ds_smean_lowess.plot()
best_ds_smean.plot()

# %%
np.all(np.isnan([np.nan]))
# Out:
# True

# %%
def return_hawkins_signal_and_noise(lt:ArrayLike, gt:ArrayLike) -> tuple[ArrayLike, ArrayLike]:

    if np.all(np.isnan(lt)) or np.all(np.isnan(gt)): return lt, lt
    
    # Remove nan's from both time series
    # non_nan_locs = np.isfinite(gt) & np.isfinite(lt)
    # gt = gt[non_nan_locs]
    # lt = lt[non_nan_locs]
    number_nans_at_start = np.where(~np.isnan(lt))[0][0]
    number_nans_at_end = np.where(~np.isnan(lt[::-1]))[0][0] # This is done same as above,just invet first

    # Remove start nans (this can be zero and doesn't break)
    lt = lt[number_nans_at_start:] 
    gt = gt[number_nans_at_start:]
    if number_nans_at_end > 0:# If number_nans_at_end is then this removes all values
        lt = lt[:-number_nans_at_end] 
        gt = gt[:-number_nans_at_end] 

    # Calcualte gra
    grad, yint = np.polyfit(gt, lt, deg=1)
    signal = grad * gt
    #noise = np.std(lt - grad * gt)
    noise = np.std(lt - grad * gt)

    retu
    #noise = np.concatenate([[np.nan]*number_nans_at_start, noise, [np.nan] *number_nans_at_end])
    #signal = np.concatenate([[np.nan]*number_nans_at_start, signal, [np.nan] *number_nans_at_end])
    
    #return signal, noise

# %%
reload(toe)
# Out:
# <module 'time_of_emrgence_calc' from '/home/563/ab2313/Documents/PhD/modules/time_of_emrgence_calc.py'>

# %%
return_hawkins_signal_and_noise_partial = partial(toe.return_hawkins_signal_and_noise, gt=best_ds_smean_lowess.values)

# %%
ds_best_signal, ds_best_noise_series = xr.apply_ufunc(
    return_hawkins_signal_and_noise_partial,
    best_ds,
    input_core_dims=[['time']], 
    output_core_dims=[['time'], ['time']], 
    dask='parallelized', 
    vectorize=True
)
# Out:
# - Connection to tcp://127.0.0.1:37530 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:42637', name: 4, status: running, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711505039.897546')
# - Worker process 722138 was killed by signal 15
# - Worker process 722131 was killed by signal 15
# - Worker process 722126 was killed by signal 15
# - Worker process 722142 was killed by signal 15
# - Worker process 722135 was killed by signal 15
# - Worker process 722122 was killed by signal 15
# - Connection to tcp://127.0.0.1:37512 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:41839', name: 0, status: running, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711505039.9227922')
# - Connection to tcp://127.0.0.1:37542 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:32987', name: 3, status: running, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711505039.9251084')
# - Connection to tcp://127.0.0.1:37558 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:45453', name: 5, status: running, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711505039.9270613')
# - Connection to tcp://127.0.0.1:37552 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:40131', name: 1, status: running, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711505039.9292543')
# - Connection to tcp://127.0.0.1:37520 has been closed.
# - Remove worker <WorkerState 'tcp://127.0.0.1:44915', name: 2, status: running, memory: 0, processing: 0> (stimulus_id='handle-worker-cleanup-1711505039.9313378')
# - Lost all workers
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37542>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37542>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37552>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37552>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37512>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37512>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37520>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37520>: Stream is closed
# - Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37558>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 298, in write
#     raise StreamClosedError()
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/tornado/gen.py", line 767, in run
#     value = future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 309, in write
#     convert_stream_closed_error(self, e)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:43839 remote=tcp://127.0.0.1:37558>: Stream is closed
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Worker process 726842 was killed by signal 15
# - Worker process 726845 was killed by signal 15
# - Worker process 726849 was killed by signal 15
# - Worker process 726854 was killed by signal 15
# - Worker process 726858 was killed by signal 15
# - Worker process 726861 was killed by signal 15
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Worker process 726866 was killed by signal 15
# - Worker process 726870 was killed by signal 15
# - Worker process 726881 was killed by signal 15
# - Worker process 726874 was killed by signal 15
# - Worker process 726885 was killed by signal 15
# - Worker process 726877 was killed by signal 15
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Worker process 726889 was killed by signal 15
# - Worker process 726893 was killed by signal 15
# - Worker process 726897 was killed by signal 15
# - Worker process 726909 was killed by signal 15
# - Worker process 726902 was killed by signal 15
# - Worker process 726907 was killed by signal 15
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker
# - Restarting worker

# %%
ds_best_noise = ds_best_noise_series.std(dim='time')

# %%
ds_best_sn = ds_best_signal/ds_best_noise

# %%
ds_best_noise.plot()

# %%
sel_dict = dict(lat=-38, lon=144, method='nearest')

# %%
ds_best_signal.sel(**sel_dict).plot()
ds_best_sn.sel(**sel_dict).plot()
# Out:
# - full garbage collection released 23.20 MiB from 9408 reference cycles (threshold: 9.54 MiB)

# %%
lt = best_ds.sel(lat=-38, lon=144, method='nearest').values

# %%
gt = best_ds_smean_lowess.values

# %%
non_nan_locs = np.isfinite(gt) & np.isfinite(lt)

# %%
gt = gt[non_nan_locs]
lt = lt[non_nan_locs]

# %%
grad, yint = np.polyfit(gt, lt, deg=1)

# %%
lt_out = grad * gt + yint

# %%
signal = grad * gt

# %%
plt.plot(lt - grad * gt)

# %%
noise = np.std(lt - grad * gt)
noise
# Out:
# 0.3627804004131642

# %%
plt.plot(signal/noise)

# %%
plt.plot(signal)

# %%
plt.plot(lt)
plt.plot(lt_out)

# %%
polynomial_fit_global_mean = partial(stats.polynomial_fit, x=best_ds_smean_lowess.values, order=1)

# %%
best_ds = best_ds.chunk({'time':-1, 'lat':60, 'lon':-1})

# %%
ds_best_signal = xr.apply_ufunc(
    polynomial_fit_global_mean,
    best_ds,
    input_core_dims=[['time']], 
    output_core_dims=[['time']], 
    dask='parallelized', 
    vectorize=True
)

# %%
ds_best_signal = signal_ds.compute()

# %%
ds_best_signal.isel(time=[0, 30, 100]).plot(col='time', robust=True)

# %%
best_ds.sel(lat=-38, lon=144, method='nearest').plot()
signal_ds.sel(lat=-38, lon=144, method='nearest').plot()

# %%
noise_ds = base_period_ds.std(dim='time')

# %%
noise_ds.plot(robust=True)

# %%
base_period_ds_average = base_period_ds.mean(dim='time').fillna(0)
base_period_ds_average
# Out:
# <xarray.DataArray 'temperature' (lat: 180, lon: 360)>
# array([[0., ..., 0.],
#        ...,
#        [0., ..., 0.]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5

# %%
ds_best_sn = ds_best_signal/noise_ds

# %%
ds_best_sn.isel(time=[0, 30, 100]).plot(col='time', robust=True)
